# %% [markdown]
# # **Coordinator Task 1**
#
# Welcome to the first coordinator task bois!!
#
# This time we have a task tailored specifically for you guys, not a house price prediction task, not a cat-dog classification task but something much more interesting!
#
# ## **IPL result prediction task!**
#
# Yes, you are right. Predict the *scripted* IPL matches using your ML skills! We have shared the IPL dataset spanning from the year 2008-2021. You are expected to predict the results for the year 2022.
#
# **Task** : Predict the winner of every match conducted in 2023 based on the dataset that we have shared. The coordinator(s) whose model predicts with highest accuracy will be given a treat.
#
# **Instructions**
#
#
# *   The coordinator task has two sub-parts:
#
#       1.   EDA (Exploratory Data Analysis)
#       2. Data preprocessing
#       3.   Model building and training
#
#
# *   The notebook is designed and categorized accordingly to help you throughout this task
# *   For EDA you are expected to use Pandas, Numpy, Matplotlib, Seaborn wherever neccessary. (you are free to use any other Python libraries as well)
# *   For the model building, use only linear/logistic regression
# *   You are not allowed to use Pytorch. Build the model from scratch using Numpy
#
#
# **Note**: We don't expect you to check the 2022 IPL results, be fair and submit your model predictions.
#
# Be as creative as possible, guys; we have given you a raw dataset, as you will have much more scope in exploring the problem statement. Enjoy the task!

# %% [markdown]
# # Downloading the dataset
#
# The dataset is a CSV file. First download it onto your local system and upload it on your colab notebook. Use Pandas to open the CSV file and study the dataset.

# %%
import pandas as pd

# %%
raw_df = pd.read_csv('/content/IPL_train_ dataset 2008-2021.csv')

# %% [markdown]
# # Data Analysis
#
# Analyze the raw_df. Use Pandas to make observations. Feel free to use Google or Chatgpt for the same. So many functions can be performed using Pandas and remembering them isn't possible. So give the right prompt as you require and use those commands.
#
# The next few cells are left for you guys to experiment
#
# We have coded a few cells to give you an idea.

# %%
raw_df.head(10)
# Out:
#    year                         team1                        team2  \
# 0   2021               Mumbai Indians  Royal Challengers Bangalore
# 1   2021          Chennai Super Kings               Delhi Capitals
# 2   2021        Kolkata Knight Riders          Sunrisers Hyderabad
# 3   2021                 Punjab Kings             Rajasthan Royals
# 4   2021               Mumbai Indians        Kolkata Knight Riders
# 5   2021  Royal Challengers Bangalore          Sunrisers Hyderabad
# 6   2021               Delhi Capitals             Rajasthan Royals
# 7   2021                 Punjab Kings          Chennai Super Kings
# 8   2021               Mumbai Indians          Sunrisers Hyderabad
# 9   2021  Royal Challengers Bangalore        Kolkata Knight Riders
#
#    team1_score  team2_score                  toss_winner toss_choice  \
# 0        159.0        160.0  Royal Challengers Bangalore       Field
# 1        188.0        190.0               Delhi Capitals       Field
# 2        187.0        177.0          Sunrisers Hyderabad       Field
# 3        221.0        217.0             Rajasthan Royals       Field
# 4        152.0        142.0        Kolkata Knight Riders       Field
# 5        149.0        143.0          Sunrisers Hyderabad       Field
# 6        147.0        150.0             Rajasthan Royals       Field
# 7        106.0        107.0          Chennai Super Kings       Field
# 8        150.0        137.0               Mumbai Indians         Bat
# 9        204.0        166.0  Royal Challengers Bangalore         Bat
#
#      winner     margin man_of_the_match                 stadium    place
# 0       RCB  2 wickets    Harshal Patel  MA Chidambaram Stadium  Chepauk
# 1  Capitals  7 wickets   Shikhar Dhawan        Wankhede Stadium   Mumbai
# 2       KKR    10 runs      Nitish Rana  MA Chidambaram Stadium  Chepauk
# 3    Punjab     4 runs     Sanju Samson        Wankhede Stadium   Mumbai
# 4    Mumbai    10 runs     Rahul Chahar  MA Chidambaram Stadium  Chepauk
# 5       RCB     6 runs    Glenn Maxwell  MA Chidambaram Stadium  Chepauk
# 6    Royals  3 wickets   Jaydev Unadkat        Wankhede Stadium   Mumbai
# 7     Super  6 wickets    Deepak Chahar        Wankhede Stadium   Mumbai
# 8    Mumbai    13 runs   Kieron Pollard  MA Chidambaram Stadium  Chepauk
# 9       RCB    38 runs   AB de Villiers  MA Chidambaram Stadium  Chepauk

# %%
raw_df.winner.unique()
# Out:
# array(['RCB', 'Capitals', 'KKR', 'Punjab', 'Mumbai', 'Royals', 'Super',
#        'Sunrisers', 'Tied', 'Kings', 'No', 'Daredevils', 'Supergiant',
#        'Guj', 'Match', 'Supergiants', 'Warriors', 'Chargers', 'Kochi'],
#       dtype=object)

# %% [markdown]
# Notice that in the winners column, the team names aren't appropriately mentioned. Lets change them as follows:
# replace
#
# *   RCB with Royal Challengers Bangalore
# *   Capitals with Delhi Capitals
# *   KKR with Kolkata Knight Riders
# *   Punjab with Punjab Kings
# *   Mumbai with Mumbai Indians
# *   Royals with Rajasthan Royals
# *   Super with Chennai Super Kings
# *   Sunrisers with Sunrisers Hyderabad
# *   Kings with Kings XI Punjab
# *   Daredevils with Delhi Daredevils
# *   Supergiant with Rising Pune Supergiants
# *   Guj with Gujarat Lions
# *   Supergiants with Rising Pune Supergiants
# *   Warriors with Pune Warriors
# *   Chargers with Deccan Chargers
# *   Kochi with Kochi Tuskers Kerala

# %%
raw_df.replace(to_replace="RCB", value="Royal Challengers Bangalore",inplace=True)
raw_df.replace(to_replace="Capitals", value="Delhi Capitals",inplace=True)
raw_df.replace(to_replace="KKR", value="Kolkata Knight Riders",inplace=True)
raw_df.replace(to_replace="Punjab", value="Punjab Kings",inplace=True)
raw_df.replace(to_replace="Mumbai", value="Mumbai Indians",inplace=True)
raw_df.replace(to_replace="Royals", value="Rajasthan Royals",inplace=True)
raw_df.replace(to_replace="Super", value="Chennai Super Kings",inplace=True)
raw_df.replace(to_replace="Sunrisers", value="Sunrisers Hyderabad",inplace=True)
raw_df.replace(to_replace="Kings", value="Kings XI Punjab",inplace=True)
raw_df.replace(to_replace="Daredevils", value="Delhi Daredevils",inplace=True)
raw_df.replace(to_replace=["Supergiant","Supergiants"], value="Rising Pune Supergiant",inplace=True)
raw_df.replace(to_replace="Guj", value="Gujarat Lions",inplace=True)
raw_df.replace(to_replace="Warriors", value="Pune Warriors",inplace=True)
raw_df.replace(to_replace="Chargers", value="Deccan Chargers",inplace=True)
raw_df.replace(to_replace="Kochi", value="Kochi Tuskers Kerala",inplace=True)

raw_df.replace(["Rising Pune Supergiants"], "Rising Pune Supergiant", inplace = True)


raw_df['place'].replace(["Mumbai Indians"], "Mumbai",inplace=True)

# %%
raw_df.sample(10)
# Out:
#      year                         team1                  team2  team1_score  \
# 786   2009              Deccan Chargers       Delhi Daredevils        148.0
# 619   2012              Kings XI Punjab       Delhi Daredevils        136.0
# 674   2011             Rajasthan Royals    Chennai Super Kings        147.0
# 189   2018        Kolkata Knight Riders    Sunrisers Hyderabad        138.0
# 5     2021  Royal Challengers Bangalore    Sunrisers Hyderabad        149.0
# 555   2013               Mumbai Indians    Chennai Super Kings        148.0
# 730   2010               Mumbai Indians        Deccan Chargers        172.0
# 494   2013               Mumbai Indians          Pune Warriors        183.0
# 818   2009             Rajasthan Royals  Kolkata Knight Riders        101.0
# 785   2009              Kings XI Punjab         Mumbai Indians        119.0
#
#      team2_score            toss_winner toss_choice  \
# 786        150.0       Delhi Daredevils       Field
# 619        140.0        Kings XI Punjab         Bat
# 674        149.0       Rajasthan Royals         Bat
# 189        139.0    Sunrisers Hyderabad       Field
# 5          143.0    Sunrisers Hyderabad       Field
# 555        125.0         Mumbai Indians         Bat
# 730        131.0        Deccan Chargers       Field
# 494        142.0         Mumbai Indians         Bat
# 818        102.0  Kolkata Knight Riders       Field
# 785        116.0        Kings XI Punjab         Bat
#
#                           winner     margin  man_of_the_match  \
# 786             Delhi Daredevils  6 wickets       Dirk Nannes
# 619             Delhi Daredevils  5 wickets       Umesh Yadav
# 674          Chennai Super Kings  8 wickets    Michael Hussey
# 189          Sunrisers Hyderabad  5 wickets    Billy Stanlake
# 5    Royal Challengers Bangalore     6 runs     Glenn Maxwell
# 555               Mumbai Indians    23 runs    Kieron Pollard
# 730               Mumbai Indians    41 runs   Harbhajan Singh
# 494               Mumbai Indians    41 runs      Rohit Sharma
# 818        Kolkata Knight Riders  4 wickets      Laxmi Shukla
# 785              Kings XI Punjab     3 runs  Kumar Sangakkara
#
#                         stadium      place
# 786             SuperSport Park  Centurion
# 619            Feroz Shah Kotla      Delhi
# 674      MA Chidambaram Stadium    Chepauk
# 189                Eden Gardens    Kolkata
# 5        MA Chidambaram Stadium    Chepauk
# 555                Eden Gardens    Kolkata
# 730  Dr DY Patil Sports Academy     Mumbai
# 494            Wankhede Stadium     Mumbai
# 818                   Kingsmead     Durban
# 785                   Kingsmead     Durban

# %% [markdown]
# You can also discard the matches which were tied/abandoned

# %%
raw_df.place.unique()
# Out:
# array(['Chepauk', 'Mumbai', 'Ahmedabad', 'Delhi', nan, 'Abu Dhabi',
#        'Kolkata', 'Jaipur', 'Bangalore', 'Uppal', 'Mohali',
#        'Visakhapatnam', 'Bengaluru', 'Pune', 'Indore', 'Rajkot', 'Kanpur',
#        'Raipur', 'Motera', 'Ranchi', 'Cuttack', 'Dharamsala',
#        'Kochi Tuskers Kerala', 'Jamtha', 'Cape Town', 'Port Elizabeth',
#        'Durban', 'Centurion', 'East London', 'Johannesburg', 'Kimberley',
#        'Bloemfontein'], dtype=object)

# %%
raw_df.stadium.unique()
# Out:
# array(['MA Chidambaram Stadium', 'Wankhede Stadium',
#        'Narendra Modi Stadium', 'Arun Jaitley Stadium',
#        'Dubai International Cricket Stadium', 'Zayed Cricket Stadium',
#        'Sharjah Cricket Stadium', 'Sheikh Zayed Stadium', 'Eden Gardens',
#        'Sawai Mansingh Stadium', 'Feroz Shah Kotla',
#        'M Chinnaswamy Stadium', 'Rajiv Gandhi International Stadium',
#        'Punjab Cricket Association IS Bindra Stadium',
#        'Andhra Cricket Association-Visakhapatnam District Cricket Association Stadium',
#        'Maharashtra Cricket Association Stadium',
#        'Holkar Cricket Stadium', 'Saurashtra Cricket Association Stadium',
#        nan, 'Green Park',
#        'Dr. Y.S. Rajasekhara Reddy ACA-VDCA Cricket Stadium',
#        'Shaheed Veer Narayan Singh International Stadium',
#        'Sardar Patel Stadium', 'Punjab Cricket Association Stadium',
#        'PLAYER NAMEOMRWEcon', 'Brabourne Stadium',
#        'JSCA International Stadium Complex', 'Barabati Stadium',
#        'Subrata Roy Sahara Stadium',
#        'Himachal Pradesh Cricket Association Stadium', 'Nehru Stadium',
#        'Dr DY Patil Sports Academy',
#        'Vidarbha Cricket Association Stadium', 'Newlands',
#        "St George's Park", 'Kingsmead', 'SuperSport Park', 'Buffalo Park',
#        'New Wanderers Stadium', 'De Beers Diamond Oval',
#        'OUTsurance Oval'], dtype=object)

# %%
raw_df.place.unique()
# Out:
# array(['Chepauk', 'Mumbai', 'Ahmedabad', 'Delhi', nan, 'Abu Dhabi',
#        'Kolkata', 'Jaipur', 'Bangalore', 'Uppal', 'Mohali',
#        'Visakhapatnam', 'Bengaluru', 'Pune', 'Indore', 'Rajkot', 'Kanpur',
#        'Raipur', 'Motera', 'Ranchi', 'Cuttack', 'Dharamsala',
#        'Kochi Tuskers Kerala', 'Jamtha', 'Cape Town', 'Port Elizabeth',
#        'Durban', 'Centurion', 'East London', 'Johannesburg', 'Kimberley',
#        'Bloemfontein'], dtype=object)

# %%
raw_df.drop(raw_df[raw_df.winner == 'Tied'].index, inplace=True)
raw_df.drop(raw_df[raw_df.winner == 'No'].index, inplace=True)
raw_df.drop(raw_df[raw_df.winner == 'Match'].index, inplace=True)

# %%
raw_df.rename(columns = {'year ':'year'}, inplace = True)
raw_df.reset_index(drop = True, inplace = True)

# %% [markdown]
# #Data Visualization
#
# Use Matplotlib and Seaborn to plot graphs to visualize the dataset. Plot pie charts, histograms, and scatterplots to analyze and present the data understandably.
#
# Take help of this notebook to proceed ahead
# https://www.kaggle.com/code/razamh/eda-ipl-dataset
#
# Using the plots answer the following questions:
#
#
# 1.   Number of matches won by each team
# 2.   Percentage of matches in which first batting and second batting team has won
# 3.   Number of man of the matches won per player (plot for first 10 players)
# 4.   Number of matches conducted in each year
# 5.   Number of matches in each venue
# 6.   Number of champions won per team (hint: the last match of every season is the final)
# 7. Average score of the first batting team in each venue
#
#
#   We have helped you with the first question, answer the remaining the questions.

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
raw_df.winner.unique()
# Out:
# array(['Royal Challengers Bangalore', 'Delhi Capitals',
#        'Kolkata Knight Riders', 'Punjab Kings', 'Mumbai Indians',
#        'Rajasthan Royals', 'Chennai Super Kings', 'Sunrisers Hyderabad',
#        'Kings XI Punjab', 'Delhi Daredevils', 'Rising Pune Supergiant',
#        'Gujarat Lions', 'Pune Warriors', 'Deccan Chargers',
#        'Kochi Tuskers Kerala'], dtype=object)

# %%
plt.figure(figsize=(12,6))
data = raw_df.winner.value_counts()
sns.barplot(y = data.index, x = data, orient='h')
plt.show()

del data

# %% [markdown]
# Check the above plot, It also has Tied, Match, No on the Y-axis which have to be removed. Plot the above graph again making the changes.
#
# Also clean the data similarly wherever required.

# %%
fwin = 0
swin = 0

for i in range(len(raw_df)):
  if raw_df.toss_winner[i] == raw_df.team1[i] and raw_df.toss_choice[i] == 'Bat' and raw_df.winner[i] == raw_df.team1[i]:
    fwin = fwin + 1
  elif raw_df.toss_winner[i] == raw_df.team2[i] and raw_df.toss_choice[i] == 'Bat' and raw_df.winner[i] == raw_df.team2[i]:
    fwin = fwin + 1
  elif raw_df.toss_winner[i] == raw_df.team1[i] and raw_df.toss_choice[i] == 'Field' and raw_df.winner[i] == raw_df.team2[i]:
    fwin = fwin + 1
  elif raw_df.toss_winner[i] == raw_df.team2[i] and raw_df.toss_choice[i] == 'Field' and raw_df.winner[i] == raw_df.team1[i]:
    fwin = fwin + 1
  else:
    swin = swin + 1

del i

plt.pie([fwin/(fwin+swin)*100, swin/(fwin+swin)*100], labels = ['First Batting Team Won', 'Second Batting Team Won'], colors = ['gold', 'red'], shadow = True, startangle = 90, autopct='%1.1f%%')
plt.show()

del fwin, swin

# %%
plt.subplots(figsize=(12,6))
data = raw_df.man_of_the_match.value_counts()[0:10]
sns.barplot(y = data, x = data.index, orient='v', palette='Blues')
plt.xlabel("Player Name")
plt.ylabel("Count")
plt.xticks(rotation='vertical')
plt.show()

del data

# %%
plt.figure(figsize=(12,6))
data = raw_df.year.value_counts()
sns.barplot(y = data, x = data.index, orient='v')
plt.xlabel("Year")
plt.ylabel("Count")
plt.show()

del data

# %%
plt.figure(figsize=(12,6))
data = raw_df.place.value_counts()
sns.barplot(y = data, x=data.index, orient = 'v')
plt.xlabel('Venue')
plt.ylabel('Count')
plt.xticks(rotation='vertical')
plt.show()

del data

# %%
lmn = pd.DataFrame()

for i in raw_df.year.unique():
  lmn = lmn.append(raw_df[raw_df.year == i].tail(1))

del i

plt.figure(figsize=(12,6))
data = lmn.winner.value_counts()
sns.barplot(y = data, x = data.index, orient = 'v')
plt.xlabel("Team")
plt.show()

del lmn, data
# Out:
# <ipython-input-157-ff47ddcdebc0>:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   lmn = lmn.append(raw_df[raw_df.year == i].tail(1))
# <ipython-input-157-ff47ddcdebc0>:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   lmn = lmn.append(raw_df[raw_df.year == i].tail(1))
# <ipython-input-157-ff47ddcdebc0>:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   lmn = lmn.append(raw_df[raw_df.year == i].tail(1))
# <ipython-input-157-ff47ddcdebc0>:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   lmn = lmn.append(raw_df[raw_df.year == i].tail(1))
# <ipython-input-157-ff47ddcdebc0>:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   lmn = lmn.append(raw_df[raw_df.year == i].tail(1))
# <ipython-input-157-ff47ddcdebc0>:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   lmn = lmn.append(raw_df[raw_df.year == i].tail(1))
# <ipython-input-157-ff47ddcdebc0>:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   lmn = lmn.append(raw_df[raw_df.year == i].tail(1))
# <ipython-input-157-ff47ddcdebc0>:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   lmn = lmn.append(raw_df[raw_df.year == i].tail(1))
# <ipython-input-157-ff47ddcdebc0>:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   lmn = lmn.append(raw_df[raw_df.year == i].tail(1))
# <ipython-input-157-ff47ddcdebc0>:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   lmn = lmn.append(raw_df[raw_df.year == i].tail(1))
# <ipython-input-157-ff47ddcdebc0>:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   lmn = lmn.append(raw_df[raw_df.year == i].tail(1))
# <ipython-input-157-ff47ddcdebc0>:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   lmn = lmn.append(raw_df[raw_df.year == i].tail(1))
# <ipython-input-157-ff47ddcdebc0>:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   lmn = lmn.append(raw_df[raw_df.year == i].tail(1))
# <ipython-input-157-ff47ddcdebc0>:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   lmn = lmn.append(raw_df[raw_df.year == i].tail(1))

# %%
pqr = pd.DataFrame()

for i in range(len(raw_df)):
  if raw_df.toss_winner[i] == raw_df.team1[i] and raw_df.toss_choice[i] == 'Bat':
    pqr = pqr.append(pd.DataFrame([[raw_df.team1_score[i], raw_df.place[i]]]))
  elif raw_df.toss_winner[i] == raw_df.team2[i] and raw_df.toss_choice[i] == 'Bat':
    pqr = pqr.append(pd.DataFrame([[raw_df.team2_score[i], raw_df.place[i]]]))
  elif raw_df.toss_winner[i] == raw_df.team1[i] and raw_df.toss_choice[i] == 'Field':
    pqr = pqr.append(pd.DataFrame([[raw_df.team2_score[i], raw_df.place[i]]]))
  elif raw_df.toss_winner[i] == raw_df.team2[i] and raw_df.toss_choice[i] == 'Field':
    pqr = pqr.append(pd.DataFrame([[raw_df.team1_score[i], raw_df.place[i]]]))

del i

pqr.rename(columns = {0:'score', 1:'venue'}, inplace = True)
data = pqr.groupby(['venue'])['score'].mean()
plt.figure(figsize=(12,6))
sns.barplot(y =data, x= data.index, orient='v')
plt.title = 'Average score of the first batting team in each venue'
plt.xticks(rotation='vertical')
plt.show()

del pqr, data
# Out:
# <ipython-input-158-d9617d4d6a50>:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pqr = pqr.append(pd.DataFrame([[raw_df.team1_score[i], raw_df.place[i]]]))
# <ipython-input-158-d9617d4d6a50>:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pqr = pqr.append(pd.DataFrame([[raw_df.team1_score[i], raw_df.place[i]]]))
# <ipython-input-158-d9617d4d6a50>:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pqr = pqr.append(pd.DataFrame([[raw_df.team1_score[i], raw_df.place[i]]]))
# <ipython-input-158-d9617d4d6a50>:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pqr = pqr.append(pd.DataFrame([[raw_df.team1_score[i], raw_df.place[i]]]))
# <ipython-input-158-d9617d4d6a50>:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pqr = pqr.append(pd.DataFrame([[raw_df.team1_score[i], raw_df.place[i]]]))
# <ipython-input-158-d9617d4d6a50>:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pqr = pqr.append(pd.DataFrame([[raw_df.team1_score[i], raw_df.place[i]]]))
# <ipython-input-158-d9617d4d6a50>:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pqr = pqr.append(pd.DataFrame([[raw_df.team1_score[i], raw_df.place[i]]]))
# <ipython-input-158-d9617d4d6a50>:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pqr = pqr.append(pd.DataFrame([[raw_df.team1_score[i], raw_df.place[i]]]))
# <ipython-input-158-d9617d4d6a50>:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pqr = pqr.append(pd.DataFrame([[raw_df.team1_score[i], raw_df.place[i]]]))
# <ipython-input-158-d9617d4d6a50>:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pqr = pqr.append(pd.DataFrame([[raw_df.team1_score[i], raw_df.place[i]]]))
# <ipython-input-158-d9617d4d6a50>:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pqr = pqr.append(pd.DataFrame([[raw_df.team1_score[i], raw_df.place[i]]]))
# <ipython-input-158-d9617d4d6a50>:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pqr = pqr.append(pd.DataFrame([[raw_df.team1_score[i], raw_df.place[i]]]))
# <ipython-input-158-d9617d4d6a50>:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pqr = pqr.append(pd.DataFrame([[raw_df.team1_score[i], raw_df.place[i]]]))
# <ipython-input-158-d9617d4d6a50>:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pqr = pqr.append(pd.DataFrame([[raw_df.team1_score[i], raw_df.place[i]]]))
# <ipython-input-158-d9617d4d6a50>:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pqr = pqr.append(pd.DataFrame([[raw_df.team1_score[i], raw_df.place[i]]]))
# <ipython-input-158-d9617d4d6a50>:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pqr = pqr.append(pd.DataFrame([[raw_df.team1_score[i], raw_df.place[i]]]))
# <ipython-input-158-d9617d4d6a50>:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pqr = pqr.append(pd.DataFrame([[raw_df.team1_score[i], raw_df.place[i]]]))
# <ipython-input-158-d9617d4d6a50>:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pqr = pqr.append(pd.DataFrame([[raw_df.team1_score[i], raw_df.place[i]]]))
# <ipython-input-158-d9617d4d6a50>:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pqr = pqr.append(pd.DataFrame([[raw_df.team1_score[i], raw_df.place[i]]]))
# <ipython-input-158-d9617d4d6a50>:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pqr = pqr.append(pd.DataFrame([[raw_df.team1_score[i], raw_df.place[i]]]))
# <ipython-input-158-d9617d4d6a50>:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pqr = pqr.append(pd.DataFrame([[raw_df.team1_score[i], raw_df.place[i]]]))
# <ipython-input-158-d9617d4d6a50>:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pqr = pqr.append(pd.DataFrame([[raw_df.team1_score[i], raw_df.place[i]]]))
# <ipython-input-158-d9617d4d6a50>:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pqr = pqr.append(pd.DataFrame([[raw_df.team1_score[i], raw_df.place[i]]]))
# <ipython-input-158-d9617d4d6a50>:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pqr = pqr.append(pd.DataFrame([[raw_df.team1_score[i], raw_df.place[i]]]))
# <ipython-input-158-d9617d4d6a50>:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pqr = pqr.append(pd.DataFrame([[raw_df.team1_score[i], raw_df.place[i]]]))
# <ipython-input-158-d9617d4d6a50>:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pqr = pqr.append(pd.DataFrame([[raw_df.team1_score[i], raw_df.place[i]]]))
# <ipython-input-158-d9617d4d6a50>:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pqr = pqr.append(pd.DataFrame([[raw_df.team1_score[i], raw_df.place[i]]]))
# <ipython-input-158-d9617d4d6a50>:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pqr = pqr.append(pd.DataFrame([[raw_df.team1_score[i], raw_df.place[i]]]))
# <ipython-input-158-d9617d4d6a50>:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pqr = pqr.append(pd.DataFrame([[raw_df.team1_score[i], raw_df.place[i]]]))
# <ipython-input-158-d9617d4d6a50>:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pqr = pqr.append(pd.DataFrame([[raw_df.team1_score[i], raw_df.place[i]]]))
# <ipython-input-158-d9617d4d6a50>:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pqr = pqr.append(pd.DataFrame([[raw_df.team1_score[i], raw_df.place[i]]]))
# <ipython-input-158-d9617d4d6a50>:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pqr = pqr.append(pd.DataFrame([[raw_df.team1_score[i], raw_df.place[i]]]))
# <ipython-input-158-d9617d4d6a50>:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pqr = pqr.append(pd.DataFrame([[raw_df.team1_score[i], raw_df.place[i]]]))
# <ipython-input-158-d9617d4d6a50>:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pqr = pqr.append(pd.DataFrame([[raw_df.team1_score[i], raw_df.place[i]]]))
# <ipython-input-158-d9617d4d6a50>:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pqr = pqr.append(pd.DataFrame([[raw_df.team1_score[i], raw_df.place[i]]]))
# <ipython-input-158-d9617d4d6a50>:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pqr = pqr.append(pd.DataFrame([[raw_df.team1_score[i], raw_df.place[i]]]))
# <ipython-input-158-d9617d4d6a50>:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pqr = pqr.append(pd.DataFrame([[raw_df.team1_score[i], raw_df.place[i]]]))
# <ipython-input-158-d9617d4d6a50>:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pqr = pqr.append(pd.DataFrame([[raw_df.team1_score[i], raw_df.place[i]]]))
# <ipython-input-158-d9617d4d6a50>:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pqr = pqr.append(pd.DataFrame([[raw_df.team1_score[i], raw_df.place[i]]]))
# <ipython-input-158-d9617d4d6a50>:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pqr = pqr.append(pd.DataFrame([[raw_df.team1_score[i], raw_df.place[i]]]))
# <ipython-input-158-d9617d4d6a50>:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pqr = pqr.append(pd.DataFrame([[raw_df.team1_score[i], raw_df.place[i]]]))
# <ipython-input-158-d9617d4d6a50>:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pqr = pqr.append(pd.DataFrame([[raw_df.team1_score[i], raw_df.place[i]]]))
# <ipython-input-158-d9617d4d6a50>:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pqr = pqr.append(pd.DataFrame([[raw_df.team1_score[i], raw_df.place[i]]]))
# <ipython-input-158-d9617d4d6a50>:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pqr = pqr.append(pd.DataFrame([[raw_df.team1_score[i], raw_df.place[i]]]))
# <ipython-input-158-d9617d4d6a50>:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pqr = pqr.append(pd.DataFrame([[raw_df.team1_score[i], raw_df.place[i]]]))
# <ipython-input-158-d9617d4d6a50>:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pqr = pqr.append(pd.DataFrame([[raw_df.team1_score[i], raw_df.place[i]]]))
# <ipython-input-158-d9617d4d6a50>:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pqr = pqr.append(pd.DataFrame([[raw_df.team1_score[i], raw_df.place[i]]]))
# <ipython-input-158-d9617d4d6a50>:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pqr = pqr.append(pd.DataFrame([[raw_df.team1_score[i], raw_df.place[i]]]))
# <ipython-input-158-d9617d4d6a50>:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pqr = pqr.append(pd.DataFrame([[raw_df.team1_score[i], raw_df.place[i]]]))
# <ipython-input-158-d9617d4d6a50>:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pqr = pqr.append(pd.DataFrame([[raw_df.team1_score[i], raw_df.place[i]]]))
# <ipython-input-158-d9617d4d6a50>:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pqr = pqr.append(pd.DataFrame([[raw_df.team1_score[i], raw_df.place[i]]]))
# <ipython-input-158-d9617d4d6a50>:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pqr = pqr.append(pd.DataFrame([[raw_df.team1_score[i], raw_df.place[i]]]))
# <ipython-input-158-d9617d4d6a50>:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pqr = pqr.append(pd.DataFrame([[raw_df.team1_score[i], raw_df.place[i]]]))
# <ipython-input-158-d9617d4d6a50>:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pqr = pqr.append(pd.DataFrame([[raw_df.team1_score[i], raw_df.place[i]]]))
# <ipython-input-158-d9617d4d6a50>:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pqr = pqr.append(pd.DataFrame([[raw_df.team1_score[i], raw_df.place[i]]]))
# <ipython-input-158-d9617d4d6a50>:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pqr = pqr.append(pd.DataFrame([[raw_df.team1_score[i], raw_df.place[i]]]))
# <ipython-input-158-d9617d4d6a50>:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pqr = pqr.append(pd.DataFrame([[raw_df.team1_score[i], raw_df.place[i]]]))
# <ipython-input-158-d9617d4d6a50>:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pqr = pqr.append(pd.DataFrame([[raw_df.team1_score[i], raw_df.place[i]]]))
# <ipython-input-158-d9617d4d6a50>:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pqr = pqr.append(pd.DataFrame([[raw_df.team1_score[i], raw_df.place[i]]]))
# <ipython-input-158-d9617d4d6a50>:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pqr = pqr.append(pd.DataFrame([[raw_df.team1_score[i], raw_df.place[i]]]))
# <ipython-input-158-d9617d4d6a50>:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pqr = pqr.append(pd.DataFrame([[raw_df.team1_score[i], raw_df.place[i]]]))
# <ipython-input-158-d9617d4d6a50>:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pqr = pqr.append(pd.DataFrame([[raw_df.team1_score[i], raw_df.place[i]]]))
# <ipython-input-158-d9617d4d6a50>:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pqr = pqr.append(pd.DataFrame([[raw_df.team1_score[i], raw_df.place[i]]]))
# <ipython-input-158-d9617d4d6a50>:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pqr = pqr.append(pd.DataFrame([[raw_df.team1_score[i], raw_df.place[i]]]))
# <ipython-input-158-d9617d4d6a50>:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pqr = pqr.append(pd.DataFrame([[raw_df.team1_score[i], raw_df.place[i]]]))
# <ipython-input-158-d9617d4d6a50>:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pqr = pqr.append(pd.DataFrame([[raw_df.team1_score[i], raw_df.place[i]]]))
# <ipython-input-158-d9617d4d6a50>:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pqr = pqr.append(pd.DataFrame([[raw_df.team1_score[i], raw_df.place[i]]]))
# <ipython-input-158-d9617d4d6a50>:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pqr = pqr.append(pd.DataFrame([[raw_df.team1_score[i], raw_df.place[i]]]))
# <ipython-input-158-d9617d4d6a50>:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pqr = pqr.append(pd.DataFrame([[raw_df.team1_score[i], raw_df.place[i]]]))
# <ipython-input-158-d9617d4d6a50>:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pqr = pqr.append(pd.DataFrame([[raw_df.team1_score[i], raw_df.place[i]]]))
# <ipython-input-158-d9617d4d6a50>:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pqr = pqr.append(pd.DataFrame([[raw_df.team1_score[i], raw_df.place[i]]]))
# <ipython-input-158-d9617d4d6a50>:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pqr = pqr.append(pd.DataFrame([[raw_df.team1_score[i], raw_df.place[i]]]))
# <ipython-input-158-d9617d4d6a50>:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pqr = pqr.append(pd.DataFrame([[raw_df.team1_score[i], raw_df.place[i]]]))
# <ipython-input-158-d9617d4d6a50>:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pqr = pqr.append(pd.DataFrame([[raw_df.team1_score[i], raw_df.place[i]]]))
# <ipython-input-158-d9617d4d6a50>:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pqr = pqr.append(pd.DataFrame([[raw_df.team1_score[i], raw_df.place[i]]]))
# <ipython-input-158-d9617d4d6a50>:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pqr = pqr.append(pd.DataFrame([[raw_df.team1_score[i], raw_df.place[i]]]))
# <ipython-input-158-d9617d4d6a50>:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pqr = pqr.append(pd.DataFrame([[raw_df.team1_score[i], raw_df.place[i]]]))
# <ipython-input-158-d9617d4d6a50>:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pqr = pqr.append(pd.DataFrame([[raw_df.team1_score[i], raw_df.place[i]]]))
# <ipython-input-158-d9617d4d6a50>:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pqr = pqr.append(pd.DataFrame([[raw_df.team1_score[i], raw_df.place[i]]]))
# <ipython-input-158-d9617d4d6a50>:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pqr = pqr.append(pd.DataFrame([[raw_df.team1_score[i], raw_df.place[i]]]))
# <ipython-input-158-d9617d4d6a50>:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pqr = pqr.append(pd.DataFrame([[raw_df.team1_score[i], raw_df.place[i]]]))
# <ipython-input-158-d9617d4d6a50>:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pqr = pqr.append(pd.DataFrame([[raw_df.team1_score[i], raw_df.place[i]]]))
# <ipython-input-158-d9617d4d6a50>:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pqr = pqr.append(pd.DataFrame([[raw_df.team1_score[i], raw_df.place[i]]]))
# <ipython-input-158-d9617d4d6a50>:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pqr = pqr.append(pd.DataFrame([[raw_df.team1_score[i], raw_df.place[i]]]))
# <ipython-input-158-d9617d4d6a50>:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pqr = pqr.append(pd.DataFrame([[raw_df.team1_score[i], raw_df.place[i]]]))
# <ipython-input-158-d9617d4d6a50>:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pqr = pqr.append(pd.DataFrame([[raw_df.team1_score[i], raw_df.place[i]]]))
# <ipython-input-158-d9617d4d6a50>:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pqr = pqr.append(pd.DataFrame([[raw_df.team1_score[i], raw_df.place[i]]]))
# <ipython-input-158-d9617d4d6a50>:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pqr = pqr.append(pd.DataFrame([[raw_df.team1_score[i], raw_df.place[i]]]))
# <ipython-input-158-d9617d4d6a50>:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pqr = pqr.append(pd.DataFrame([[raw_df.team1_score[i], raw_df.place[i]]]))
# <ipython-input-158-d9617d4d6a50>:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pqr = pqr.append(pd.DataFrame([[raw_df.team1_score[i], raw_df.place[i]]]))
# <ipython-input-158-d9617d4d6a50>:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pqr = pqr.append(pd.DataFrame([[raw_df.team1_score[i], raw_df.place[i]]]))
# <ipython-input-158-d9617d4d6a50>:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pqr = pqr.append(pd.DataFrame([[raw_df.team1_score[i], raw_df.place[i]]]))
# <ipython-input-158-d9617d4d6a50>:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pqr = pqr.append(pd.DataFrame([[raw_df.team1_score[i], raw_df.place[i]]]))
# <ipython-input-158-d9617d4d6a50>:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pqr = pqr.append(pd.DataFrame([[raw_df.team1_score[i], raw_df.place[i]]]))
# <ipython-input-158-d9617d4d6a50>:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pqr = pqr.append(pd.DataFrame([[raw_df.team1_score[i], raw_df.place[i]]]))
# <ipython-input-158-d9617d4d6a50>:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pqr = pqr.append(pd.DataFrame([[raw_df.team1_score[i], raw_df.place[i]]]))
# <ipython-input-158-d9617d4d6a50>:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pqr = pqr.append(pd.DataFrame([[raw_df.team1_score[i], raw_df.place[i]]]))
# <ipython-input-158-d9617d4d6a50>:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pqr = pqr.append(pd.DataFrame([[raw_df.team1_score[i], raw_df.place[i]]]))
# <ipython-input-158-d9617d4d6a50>:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pqr = pqr.append(pd.DataFrame([[raw_df.team1_score[i], raw_df.place[i]]]))
# <ipython-input-158-d9617d4d6a50>:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pqr = pqr.append(pd.DataFrame([[raw_df.team1_score[i], raw_df.place[i]]]))
# <ipython-input-158-d9617d4d6a50>:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pqr = pqr.append(pd.DataFrame([[raw_df.team1_score[i], raw_df.place[i]]]))
# <ipython-input-158-d9617d4d6a50>:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pqr = pqr.append(pd.DataFrame([[raw_df.team1_score[i], raw_df.place[i]]]))
# <ipython-input-158-d9617d4d6a50>:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pqr = pqr.append(pd.DataFrame([[raw_df.team1_score[i], raw_df.place[i]]]))
# <ipython-input-158-d9617d4d6a50>:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pqr = pqr.append(pd.DataFrame([[raw_df.team1_score[i], raw_df.place[i]]]))
# <ipython-input-158-d9617d4d6a50>:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pqr = pqr.append(pd.DataFrame([[raw_df.team1_score[i], raw_df.place[i]]]))
# <ipython-input-158-d9617d4d6a50>:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pqr = pqr.append(pd.DataFrame([[raw_df.team1_score[i], raw_df.place[i]]]))
# <ipython-input-158-d9617d4d6a50>:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pqr = pqr.append(pd.DataFrame([[raw_df.team1_score[i], raw_df.place[i]]]))
# <ipython-input-158-d9617d4d6a50>:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pqr = pqr.append(pd.DataFrame([[raw_df.team1_score[i], raw_df.place[i]]]))
# <ipython-input-158-d9617d4d6a50>:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pqr = pqr.append(pd.DataFrame([[raw_df.team1_score[i], raw_df.place[i]]]))
# <ipython-input-158-d9617d4d6a50>:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pqr = pqr.append(pd.DataFrame([[raw_df.team1_score[i], raw_df.place[i]]]))
# <ipython-input-158-d9617d4d6a50>:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pqr = pqr.append(pd.DataFrame([[raw_df.team1_score[i], raw_df.place[i]]]))
# <ipython-input-158-d9617d4d6a50>:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pqr = pqr.append(pd.DataFrame([[raw_df.team1_score[i], raw_df.place[i]]]))
# <ipython-input-158-d9617d4d6a50>:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pqr = pqr.append(pd.DataFrame([[raw_df.team1_score[i], raw_df.place[i]]]))
# <ipython-input-158-d9617d4d6a50>:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pqr = pqr.append(pd.DataFrame([[raw_df.team1_score[i], raw_df.place[i]]]))
# <ipython-input-158-d9617d4d6a50>:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pqr = pqr.append(pd.DataFrame([[raw_df.team1_score[i], raw_df.place[i]]]))
# <ipython-input-158-d9617d4d6a50>:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pqr = pqr.append(pd.DataFrame([[raw_df.team1_score[i], raw_df.place[i]]]))
# <ipython-input-158-d9617d4d6a50>:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pqr = pqr.append(pd.DataFrame([[raw_df.team1_score[i], raw_df.place[i]]]))
# <ipython-input-158-d9617d4d6a50>:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pqr = pqr.append(pd.DataFrame([[raw_df.team1_score[i], raw_df.place[i]]]))
# <ipython-input-158-d9617d4d6a50>:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pqr = pqr.append(pd.DataFrame([[raw_df.team1_score[i], raw_df.place[i]]]))
# <ipython-input-158-d9617d4d6a50>:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pqr = pqr.append(pd.DataFrame([[raw_df.team1_score[i], raw_df.place[i]]]))
# <ipython-input-158-d9617d4d6a50>:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pqr = pqr.append(pd.DataFrame([[raw_df.team1_score[i], raw_df.place[i]]]))
# <ipython-input-158-d9617d4d6a50>:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pqr = pqr.append(pd.DataFrame([[raw_df.team1_score[i], raw_df.place[i]]]))
# <ipython-input-158-d9617d4d6a50>:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pqr = pqr.append(pd.DataFrame([[raw_df.team1_score[i], raw_df.place[i]]]))
# <ipython-input-158-d9617d4d6a50>:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pqr = pqr.append(pd.DataFrame([[raw_df.team1_score[i], raw_df.place[i]]]))
# <ipython-input-158-d9617d4d6a50>:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pqr = pqr.append(pd.DataFrame([[raw_df.team1_score[i], raw_df.place[i]]]))
# <ipython-input-158-d9617d4d6a50>:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pqr = pqr.append(pd.DataFrame([[raw_df.team1_score[i], raw_df.place[i]]]))
# <ipython-input-158-d9617d4d6a50>:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pqr = pqr.append(pd.DataFrame([[raw_df.team1_score[i], raw_df.place[i]]]))
# <ipython-input-158-d9617d4d6a50>:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pqr = pqr.append(pd.DataFrame([[raw_df.team1_score[i], raw_df.place[i]]]))
# <ipython-input-158-d9617d4d6a50>:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pqr = pqr.append(pd.DataFrame([[raw_df.team1_score[i], raw_df.place[i]]]))
# <ipython-input-158-d9617d4d6a50>:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pqr = pqr.append(pd.DataFrame([[raw_df.team1_score[i], raw_df.place[i]]]))
# <ipython-input-158-d9617d4d6a50>:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pqr = pqr.append(pd.DataFrame([[raw_df.team1_score[i], raw_df.place[i]]]))
# <ipython-input-158-d9617d4d6a50>:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pqr = pqr.append(pd.DataFrame([[raw_df.team1_score[i], raw_df.place[i]]]))
# <ipython-input-158-d9617d4d6a50>:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pqr = pqr.append(pd.DataFrame([[raw_df.team1_score[i], raw_df.place[i]]]))
# <ipython-input-158-d9617d4d6a50>:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pqr = pqr.append(pd.DataFrame([[raw_df.team1_score[i], raw_df.place[i]]]))
# <ipython-input-158-d9617d4d6a50>:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pqr = pqr.append(pd.DataFrame([[raw_df.team1_score[i], raw_df.place[i]]]))
# <ipython-input-158-d9617d4d6a50>:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pqr = pqr.append(pd.DataFrame([[raw_df.team1_score[i], raw_df.place[i]]]))
# <ipython-input-158-d9617d4d6a50>:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pqr = pqr.append(pd.DataFrame([[raw_df.team1_score[i], raw_df.place[i]]]))
# <ipython-input-158-d9617d4d6a50>:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pqr = pqr.append(pd.DataFrame([[raw_df.team1_score[i], raw_df.place[i]]]))
# <ipython-input-158-d9617d4d6a50>:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pqr = pqr.append(pd.DataFrame([[raw_df.team1_score[i], raw_df.place[i]]]))
# <ipython-input-158-d9617d4d6a50>:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pqr = pqr.append(pd.DataFrame([[raw_df.team1_score[i], raw_df.place[i]]]))
# <ipython-input-158-d9617d4d6a50>:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pqr = pqr.append(pd.DataFrame([[raw_df.team1_score[i], raw_df.place[i]]]))
# <ipython-input-158-d9617d4d6a50>:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pqr = pqr.append(pd.DataFrame([[raw_df.team1_score[i], raw_df.place[i]]]))
# <ipython-input-158-d9617d4d6a50>:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pqr = pqr.append(pd.DataFrame([[raw_df.team1_score[i], raw_df.place[i]]]))
# <ipython-input-158-d9617d4d6a50>:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pqr = pqr.append(pd.DataFrame([[raw_df.team1_score[i], raw_df.place[i]]]))
# <ipython-input-158-d9617d4d6a50>:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pqr = pqr.append(pd.DataFrame([[raw_df.team1_score[i], raw_df.place[i]]]))
# <ipython-input-158-d9617d4d6a50>:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pqr = pqr.append(pd.DataFrame([[raw_df.team1_score[i], raw_df.place[i]]]))
# <ipython-input-158-d9617d4d6a50>:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pqr = pqr.append(pd.DataFrame([[raw_df.team1_score[i], raw_df.place[i]]]))
# <ipython-input-158-d9617d4d6a50>:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pqr = pqr.append(pd.DataFrame([[raw_df.team1_score[i], raw_df.place[i]]]))
# <ipython-input-158-d9617d4d6a50>:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pqr = pqr.append(pd.DataFrame([[raw_df.team1_score[i], raw_df.place[i]]]))
# <ipython-input-158-d9617d4d6a50>:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pqr = pqr.append(pd.DataFrame([[raw_df.team1_score[i], raw_df.place[i]]]))
# <ipython-input-158-d9617d4d6a50>:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pqr = pqr.append(pd.DataFrame([[raw_df.team1_score[i], raw_df.place[i]]]))
# <ipython-input-158-d9617d4d6a50>:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pqr = pqr.append(pd.DataFrame([[raw_df.team1_score[i], raw_df.place[i]]]))
# <ipython-input-158-d9617d4d6a50>:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pqr = pqr.append(pd.DataFrame([[raw_df.team1_score[i], raw_df.place[i]]]))
# <ipython-input-158-d9617d4d6a50>:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pqr = pqr.append(pd.DataFrame([[raw_df.team1_score[i], raw_df.place[i]]]))
# <ipython-input-158-d9617d4d6a50>:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pqr = pqr.append(pd.DataFrame([[raw_df.team1_score[i], raw_df.place[i]]]))
# <ipython-input-158-d9617d4d6a50>:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pqr = pqr.append(pd.DataFrame([[raw_df.team1_score[i], raw_df.place[i]]]))
# <ipython-input-158-d9617d4d6a50>:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pqr = pqr.append(pd.DataFrame([[raw_df.team1_score[i], raw_df.place[i]]]))
# <ipython-input-158-d9617d4d6a50>:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pqr = pqr.append(pd.DataFrame([[raw_df.team1_score[i], raw_df.place[i]]]))
# <ipython-input-158-d9617d4d6a50>:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pqr = pqr.append(pd.DataFrame([[raw_df.team1_score[i], raw_df.place[i]]]))
# <ipython-input-158-d9617d4d6a50>:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pqr = pqr.append(pd.DataFrame([[raw_df.team1_score[i], raw_df.place[i]]]))
# <ipython-input-158-d9617d4d6a50>:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pqr = pqr.append(pd.DataFrame([[raw_df.team1_score[i], raw_df.place[i]]]))
# <ipython-input-158-d9617d4d6a50>:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pqr = pqr.append(pd.DataFrame([[raw_df.team1_score[i], raw_df.place[i]]]))
# <ipython-input-158-d9617d4d6a50>:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pqr = pqr.append(pd.DataFrame([[raw_df.team1_score[i], raw_df.place[i]]]))
# <ipython-input-158-d9617d4d6a50>:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pqr = pqr.append(pd.DataFrame([[raw_df.team1_score[i], raw_df.place[i]]]))
# <ipython-input-158-d9617d4d6a50>:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pqr = pqr.append(pd.DataFrame([[raw_df.team1_score[i], raw_df.place[i]]]))
# <ipython-input-158-d9617d4d6a50>:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pqr = pqr.append(pd.DataFrame([[raw_df.team1_score[i], raw_df.place[i]]]))
# <ipython-input-158-d9617d4d6a50>:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pqr = pqr.append(pd.DataFrame([[raw_df.team1_score[i], raw_df.place[i]]]))
# <ipython-input-158-d9617d4d6a50>:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pqr = pqr.append(pd.DataFrame([[raw_df.team1_score[i], raw_df.place[i]]]))
# <ipython-input-158-d9617d4d6a50>:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pqr = pqr.append(pd.DataFrame([[raw_df.team1_score[i], raw_df.place[i]]]))
# <ipython-input-158-d9617d4d6a50>:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pqr = pqr.append(pd.DataFrame([[raw_df.team1_score[i], raw_df.place[i]]]))
# <ipython-input-158-d9617d4d6a50>:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pqr = pqr.append(pd.DataFrame([[raw_df.team1_score[i], raw_df.place[i]]]))
# <ipython-input-158-d9617d4d6a50>:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pqr = pqr.append(pd.DataFrame([[raw_df.team1_score[i], raw_df.place[i]]]))
# <ipython-input-158-d9617d4d6a50>:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pqr = pqr.append(pd.DataFrame([[raw_df.team1_score[i], raw_df.place[i]]]))
# <ipython-input-158-d9617d4d6a50>:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pqr = pqr.append(pd.DataFrame([[raw_df.team1_score[i], raw_df.place[i]]]))
# <ipython-input-158-d9617d4d6a50>:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pqr = pqr.append(pd.DataFrame([[raw_df.team1_score[i], raw_df.place[i]]]))
# <ipython-input-158-d9617d4d6a50>:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pqr = pqr.append(pd.DataFrame([[raw_df.team1_score[i], raw_df.place[i]]]))
# <ipython-input-158-d9617d4d6a50>:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pqr = pqr.append(pd.DataFrame([[raw_df.team1_score[i], raw_df.place[i]]]))
# <ipython-input-158-d9617d4d6a50>:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pqr = pqr.append(pd.DataFrame([[raw_df.team1_score[i], raw_df.place[i]]]))
# <ipython-input-158-d9617d4d6a50>:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pqr = pqr.append(pd.DataFrame([[raw_df.team1_score[i], raw_df.place[i]]]))
# <ipython-input-158-d9617d4d6a50>:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pqr = pqr.append(pd.DataFrame([[raw_df.team1_score[i], raw_df.place[i]]]))
# <ipython-input-158-d9617d4d6a50>:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pqr = pqr.append(pd.DataFrame([[raw_df.team1_score[i], raw_df.place[i]]]))
# <ipython-input-158-d9617d4d6a50>:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pqr = pqr.append(pd.DataFrame([[raw_df.team1_score[i], raw_df.place[i]]]))
# <ipython-input-158-d9617d4d6a50>:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pqr = pqr.append(pd.DataFrame([[raw_df.team1_score[i], raw_df.place[i]]]))
# <ipython-input-158-d9617d4d6a50>:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pqr = pqr.append(pd.DataFrame([[raw_df.team1_score[i], raw_df.place[i]]]))
# <ipython-input-158-d9617d4d6a50>:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pqr = pqr.append(pd.DataFrame([[raw_df.team1_score[i], raw_df.place[i]]]))
# <ipython-input-158-d9617d4d6a50>:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pqr = pqr.append(pd.DataFrame([[raw_df.team1_score[i], raw_df.place[i]]]))
# <ipython-input-158-d9617d4d6a50>:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pqr = pqr.append(pd.DataFrame([[raw_df.team1_score[i], raw_df.place[i]]]))
# <ipython-input-158-d9617d4d6a50>:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pqr = pqr.append(pd.DataFrame([[raw_df.team1_score[i], raw_df.place[i]]]))
# <ipython-input-158-d9617d4d6a50>:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pqr = pqr.append(pd.DataFrame([[raw_df.team1_score[i], raw_df.place[i]]]))
# <ipython-input-158-d9617d4d6a50>:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pqr = pqr.append(pd.DataFrame([[raw_df.team1_score[i], raw_df.place[i]]]))
# <ipython-input-158-d9617d4d6a50>:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pqr = pqr.append(pd.DataFrame([[raw_df.team1_score[i], raw_df.place[i]]]))
# <ipython-input-158-d9617d4d6a50>:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pqr = pqr.append(pd.DataFrame([[raw_df.team1_score[i], raw_df.place[i]]]))
# <ipython-input-158-d9617d4d6a50>:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pqr = pqr.append(pd.DataFrame([[raw_df.team1_score[i], raw_df.place[i]]]))
# <ipython-input-158-d9617d4d6a50>:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pqr = pqr.append(pd.DataFrame([[raw_df.team1_score[i], raw_df.place[i]]]))
# ...
#   pqr = pqr.append(pd.DataFrame([[raw_df.team1_score[i], raw_df.place[i]]]))
# <ipython-input-158-d9617d4d6a50>:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pqr = pqr.append(pd.DataFrame([[raw_df.team1_score[i], raw_df.place[i]]]))
# <ipython-input-158-d9617d4d6a50>:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pqr = pqr.append(pd.DataFrame([[raw_df.team1_score[i], raw_df.place[i]]]))
# <ipython-input-158-d9617d4d6a50>:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pqr = pqr.append(pd.DataFrame([[raw_df.team1_score[i], raw_df.place[i]]]))
# <ipython-input-158-d9617d4d6a50>:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pqr = pqr.append(pd.DataFrame([[raw_df.team1_score[i], raw_df.place[i]]]))
# <ipython-input-158-d9617d4d6a50>:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pqr = pqr.append(pd.DataFrame([[raw_df.team1_score[i], raw_df.place[i]]]))
# <ipython-input-158-d9617d4d6a50>:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pqr = pqr.append(pd.DataFrame([[raw_df.team1_score[i], raw_df.place[i]]]))
# <ipython-input-158-d9617d4d6a50>:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pqr = pqr.append(pd.DataFrame([[raw_df.team1_score[i], raw_df.place[i]]]))
# <ipython-input-158-d9617d4d6a50>:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pqr = pqr.append(pd.DataFrame([[raw_df.team1_score[i], raw_df.place[i]]]))
# <ipython-input-158-d9617d4d6a50>:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pqr = pqr.append(pd.DataFrame([[raw_df.team1_score[i], raw_df.place[i]]]))
# <ipython-input-158-d9617d4d6a50>:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pqr = pqr.append(pd.DataFrame([[raw_df.team1_score[i], raw_df.place[i]]]))
# <ipython-input-158-d9617d4d6a50>:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pqr = pqr.append(pd.DataFrame([[raw_df.team1_score[i], raw_df.place[i]]]))
# <ipython-input-158-d9617d4d6a50>:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pqr = pqr.append(pd.DataFrame([[raw_df.team1_score[i], raw_df.place[i]]]))
# <ipython-input-158-d9617d4d6a50>:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pqr = pqr.append(pd.DataFrame([[raw_df.team1_score[i], raw_df.place[i]]]))
# <ipython-input-158-d9617d4d6a50>:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pqr = pqr.append(pd.DataFrame([[raw_df.team1_score[i], raw_df.place[i]]]))
# <ipython-input-158-d9617d4d6a50>:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pqr = pqr.append(pd.DataFrame([[raw_df.team1_score[i], raw_df.place[i]]]))
# <ipython-input-158-d9617d4d6a50>:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pqr = pqr.append(pd.DataFrame([[raw_df.team1_score[i], raw_df.place[i]]]))
# <ipython-input-158-d9617d4d6a50>:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pqr = pqr.append(pd.DataFrame([[raw_df.team1_score[i], raw_df.place[i]]]))
# <ipython-input-158-d9617d4d6a50>:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pqr = pqr.append(pd.DataFrame([[raw_df.team1_score[i], raw_df.place[i]]]))
# <ipython-input-158-d9617d4d6a50>:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pqr = pqr.append(pd.DataFrame([[raw_df.team1_score[i], raw_df.place[i]]]))
# <ipython-input-158-d9617d4d6a50>:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pqr = pqr.append(pd.DataFrame([[raw_df.team1_score[i], raw_df.place[i]]]))
# <ipython-input-158-d9617d4d6a50>:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pqr = pqr.append(pd.DataFrame([[raw_df.team1_score[i], raw_df.place[i]]]))
# <ipython-input-158-d9617d4d6a50>:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pqr = pqr.append(pd.DataFrame([[raw_df.team1_score[i], raw_df.place[i]]]))
# <ipython-input-158-d9617d4d6a50>:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pqr = pqr.append(pd.DataFrame([[raw_df.team1_score[i], raw_df.place[i]]]))
# <ipython-input-158-d9617d4d6a50>:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pqr = pqr.append(pd.DataFrame([[raw_df.team1_score[i], raw_df.place[i]]]))
# <ipython-input-158-d9617d4d6a50>:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pqr = pqr.append(pd.DataFrame([[raw_df.team1_score[i], raw_df.place[i]]]))
# <ipython-input-158-d9617d4d6a50>:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pqr = pqr.append(pd.DataFrame([[raw_df.team1_score[i], raw_df.place[i]]]))
# <ipython-input-158-d9617d4d6a50>:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pqr = pqr.append(pd.DataFrame([[raw_df.team1_score[i], raw_df.place[i]]]))
# <ipython-input-158-d9617d4d6a50>:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pqr = pqr.append(pd.DataFrame([[raw_df.team1_score[i], raw_df.place[i]]]))
# <ipython-input-158-d9617d4d6a50>:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pqr = pqr.append(pd.DataFrame([[raw_df.team1_score[i], raw_df.place[i]]]))
# <ipython-input-158-d9617d4d6a50>:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pqr = pqr.append(pd.DataFrame([[raw_df.team1_score[i], raw_df.place[i]]]))
# <ipython-input-158-d9617d4d6a50>:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pqr = pqr.append(pd.DataFrame([[raw_df.team1_score[i], raw_df.place[i]]]))
# <ipython-input-158-d9617d4d6a50>:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pqr = pqr.append(pd.DataFrame([[raw_df.team1_score[i], raw_df.place[i]]]))
# <ipython-input-158-d9617d4d6a50>:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pqr = pqr.append(pd.DataFrame([[raw_df.team1_score[i], raw_df.place[i]]]))
# <ipython-input-158-d9617d4d6a50>:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pqr = pqr.append(pd.DataFrame([[raw_df.team1_score[i], raw_df.place[i]]]))
# <ipython-input-158-d9617d4d6a50>:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pqr = pqr.append(pd.DataFrame([[raw_df.team1_score[i], raw_df.place[i]]]))
# <ipython-input-158-d9617d4d6a50>:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pqr = pqr.append(pd.DataFrame([[raw_df.team1_score[i], raw_df.place[i]]]))
# <ipython-input-158-d9617d4d6a50>:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pqr = pqr.append(pd.DataFrame([[raw_df.team1_score[i], raw_df.place[i]]]))
# <ipython-input-158-d9617d4d6a50>:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pqr = pqr.append(pd.DataFrame([[raw_df.team1_score[i], raw_df.place[i]]]))
# <ipython-input-158-d9617d4d6a50>:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pqr = pqr.append(pd.DataFrame([[raw_df.team1_score[i], raw_df.place[i]]]))
# <ipython-input-158-d9617d4d6a50>:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pqr = pqr.append(pd.DataFrame([[raw_df.team1_score[i], raw_df.place[i]]]))
# <ipython-input-158-d9617d4d6a50>:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pqr = pqr.append(pd.DataFrame([[raw_df.team1_score[i], raw_df.place[i]]]))
# <ipython-input-158-d9617d4d6a50>:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pqr = pqr.append(pd.DataFrame([[raw_df.team1_score[i], raw_df.place[i]]]))
# <ipython-input-158-d9617d4d6a50>:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pqr = pqr.append(pd.DataFrame([[raw_df.team1_score[i], raw_df.place[i]]]))
# <ipython-input-158-d9617d4d6a50>:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pqr = pqr.append(pd.DataFrame([[raw_df.team1_score[i], raw_df.place[i]]]))
# <ipython-input-158-d9617d4d6a50>:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pqr = pqr.append(pd.DataFrame([[raw_df.team1_score[i], raw_df.place[i]]]))
# <ipython-input-158-d9617d4d6a50>:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pqr = pqr.append(pd.DataFrame([[raw_df.team1_score[i], raw_df.place[i]]]))
# <ipython-input-158-d9617d4d6a50>:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pqr = pqr.append(pd.DataFrame([[raw_df.team1_score[i], raw_df.place[i]]]))
# <ipython-input-158-d9617d4d6a50>:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pqr = pqr.append(pd.DataFrame([[raw_df.team1_score[i], raw_df.place[i]]]))
# <ipython-input-158-d9617d4d6a50>:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pqr = pqr.append(pd.DataFrame([[raw_df.team1_score[i], raw_df.place[i]]]))
# <ipython-input-158-d9617d4d6a50>:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pqr = pqr.append(pd.DataFrame([[raw_df.team1_score[i], raw_df.place[i]]]))
# <ipython-input-158-d9617d4d6a50>:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pqr = pqr.append(pd.DataFrame([[raw_df.team1_score[i], raw_df.place[i]]]))
# <ipython-input-158-d9617d4d6a50>:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pqr = pqr.append(pd.DataFrame([[raw_df.team1_score[i], raw_df.place[i]]]))
# <ipython-input-158-d9617d4d6a50>:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pqr = pqr.append(pd.DataFrame([[raw_df.team1_score[i], raw_df.place[i]]]))
# <ipython-input-158-d9617d4d6a50>:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pqr = pqr.append(pd.DataFrame([[raw_df.team1_score[i], raw_df.place[i]]]))
# <ipython-input-158-d9617d4d6a50>:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pqr = pqr.append(pd.DataFrame([[raw_df.team1_score[i], raw_df.place[i]]]))
# <ipython-input-158-d9617d4d6a50>:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pqr = pqr.append(pd.DataFrame([[raw_df.team1_score[i], raw_df.place[i]]]))
# <ipython-input-158-d9617d4d6a50>:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pqr = pqr.append(pd.DataFrame([[raw_df.team1_score[i], raw_df.place[i]]]))
# <ipython-input-158-d9617d4d6a50>:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pqr = pqr.append(pd.DataFrame([[raw_df.team1_score[i], raw_df.place[i]]]))
# <ipython-input-158-d9617d4d6a50>:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pqr = pqr.append(pd.DataFrame([[raw_df.team1_score[i], raw_df.place[i]]]))
# <ipython-input-158-d9617d4d6a50>:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pqr = pqr.append(pd.DataFrame([[raw_df.team1_score[i], raw_df.place[i]]]))
# <ipython-input-158-d9617d4d6a50>:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pqr = pqr.append(pd.DataFrame([[raw_df.team1_score[i], raw_df.place[i]]]))
# <ipython-input-158-d9617d4d6a50>:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pqr = pqr.append(pd.DataFrame([[raw_df.team1_score[i], raw_df.place[i]]]))
# <ipython-input-158-d9617d4d6a50>:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pqr = pqr.append(pd.DataFrame([[raw_df.team1_score[i], raw_df.place[i]]]))
# <ipython-input-158-d9617d4d6a50>:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pqr = pqr.append(pd.DataFrame([[raw_df.team1_score[i], raw_df.place[i]]]))

# %% [markdown]
# #Data Preprocessing
#
# We have to clean the data and preprocess it to convert it into a trainable format.
#
# For that you have to get rid of the NaN values, remove the un-neccesary parameters and also use feature engineering wherever required.
#
# Data preprocessing is essential for the performance of the model, the better parameters you define/retain the better model can learn and hence perform.

# %% [markdown]
# We will help you with one team. Suppose lets take RCB. We have to predict the score of RCB using the parameters: team against which it is playing, did it win the toss, stadium, place.

# %%
raw_df.dropna(inplace = True)

# %% [markdown]
# Now we got the team score of RCB in all of its matches. This will be our target dataset.

# %% [markdown]
# Encoding the toss winner column. If RCB won the toss then 1 else 0

# %% [markdown]
# Similarly encode the other columns. Machine Learning models don't understand words/text so you have to encode the text to numbers.
#
# Check different techniques of encoding: one-hot encoding and number encoding and use either one to encode the columns: toss_choice, opponent team and stadium
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Now it's time for you to take up! All the best
#
# Prepare similar data frames for other teams. Predict the scores of the team based on the parameters.
#
# Suppose say you have to predict who will win RCB vs CSK, predict the score of RCB considering CSK as opponent. Then predict score of CSK with RCB as opponent. Then compare both scores, whoever scores higher will be the winner of the match.

# %%
teams = list(enumerate(('Mumbai Indians', 'Sunrisers Hyderabad', 'Kolkata Knight Riders',
       'Rajasthan Royals', 'Chennai Super Kings', 'Delhi Capitals',
       'Punjab Kings', 'Kings XI Punjab', 'Delhi Daredevils',
       'Rising Pune Supergiant', 'Gujarat Lions',
       'Rising Pune Supergiants', 'Pune Warriors', 'Deccan Chargers',
       'Kochi Tuskers Kerala', 'Royal Challengers Bangalore')))

teams = dict((j,i) for i,j in teams)

stadiums = list(enumerate(('MA Chidambaram Stadium', 'Wankhede Stadium',
       'Narendra Modi Stadium', 'Arun Jaitley Stadium',
       'Zayed Cricket Stadium', 'Sheikh Zayed Stadium', 'Eden Gardens',
       'Sawai Mansingh Stadium', 'Feroz Shah Kotla',
       'M Chinnaswamy Stadium', 'Rajiv Gandhi International Stadium',
       'Punjab Cricket Association IS Bindra Stadium',
       'Andhra Cricket Association-Visakhapatnam District Cricket Association Stadium',
       'Maharashtra Cricket Association Stadium',
       'Holkar Cricket Stadium', 'Saurashtra Cricket Association Stadium',
       'Green Park',
       'Dr. Y.S. Rajasekhara Reddy ACA-VDCA Cricket Stadium',
       'Shaheed Veer Narayan Singh International Stadium',
       'Sardar Patel Stadium', 'Punjab Cricket Association Stadium',
       'Brabourne Stadium', 'JSCA International Stadium Complex',
       'Barabati Stadium', 'Subrata Roy Sahara Stadium',
       'Himachal Pradesh Cricket Association Stadium', 'Nehru Stadium',
       'Dr DY Patil Sports Academy',
       'Vidarbha Cricket Association Stadium', 'Newlands',
       "St George's Park", 'Kingsmead', 'SuperSport Park', 'Buffalo Park',
       'New Wanderers Stadium', 'De Beers Diamond Oval',
       'OUTsurance Oval')))

stadiums = dict((j,i) for i,j in stadiums)

# %%
class databuilder:
  def __init__ (self,dfname,team):
    self.team = team

    self.dfname = raw_df.loc[((raw_df['team1'] == f'{team}') | (raw_df['team2'] == f'{team}'))]
    self.dfname.drop(columns =['margin','man_of_the_match','winner','place'], axis=1, inplace=True)
    self.dfname.reset_index(inplace = True)

    team_score = []
    opponent_team_score = []

    for i in range(len(self.dfname)):
      if self.dfname['team1'].values[i] == f'{team}':
        team_score.append(self.dfname['team1_score'].values[i])
        opponent_team_score.append(self.dfname['team2_score'].values[i])
      else:
        team_score.append(self.dfname['team2_score'].values[i])
        opponent_team_score.append(self.dfname['team1_score'].values[i])

    self.dfname.drop(columns =['team1_score','team2_score','index'], axis=1, inplace=True)

    for i in range(len(self.dfname)):
      if self.dfname['toss_winner'].values[i] == f'{team}':
        self.dfname['toss_winner'].values[i] = 1
      else:
        self.dfname['toss_winner'].values[i] = 0

    opponent_team = []

    for i in range(len(self.dfname)):
      if self.dfname['team1'].values[i] != f'{team}':
        opponent_team.append(self.dfname['team1'].values[i])
      else:
        opponent_team.append(self.dfname['team2'].values[i])

    self.dfname['Opponent_Team'] = opponent_team

    self.dfname.drop(columns =['team1','team2'], axis=1, inplace=True)

    self.dfname['score'] = team_score
    self.dfname['Opponent_Team_score'] = opponent_team_score

    self.dfname.dropna(inplace = True)

    for i in range(len(self.dfname)):
      if self.dfname['toss_choice'].values[i] == 'Bat':
        self.dfname['toss_choice'].values[i] = 1
      else:
        self.dfname['toss_choice'].values[i] = 0

    for i in range(len(self.dfname)):
      self.dfname['Opponent_Team'].values[i] = teams[self.dfname['Opponent_Team'].values[i]]
      self.dfname['stadium'].values[i] = stadiums[self.dfname['stadium'].values[i]]



  def print(self):
    return self.dfname

# %%
CSK = databuilder('df1', 'Chennai Super Kings')
MI = databuilder('df2', 'Mumbai Indians')
KKR = databuilder('df3', 'Kolkata Knight Riders')
PK = databuilder('df4', 'Punjab Kings')
DC = databuilder('df5', 'Delhi Capitals')
RR = databuilder('df6', 'Rajasthan Royals')
SRH = databuilder('df7', 'Sunrisers Hyderabad')
KXIP = databuilder('df8', 'Kings XI Punjab')
DD = databuilder('df9', 'Delhi Daredevils')
GL = databuilder('df10', 'Gujarat Lions')
RPS = databuilder('df11', 'Rising Pune Supergiant')
PW = databuilder('df12', 'Pune Warriors')
KTK = databuilder('df14', 'Kochi Tuskers Kerala')
RCB = databuilder('df15', 'Royal Challengers Bangalore')

# %%
CSK.print()
# Out:
#      year toss_winner toss_choice stadium Opponent_Team  score  \
# 0    2021           0           0       1             5  188.0
# 1    2021           1           0       1             6  107.0
# 2    2021           0           0       1             3  188.0
# 3    2021           0           0       1             2  220.0
# 4    2021           1           1       1            15  191.0
# ..    ...         ...         ...     ...           ...    ...
# 164  2008           0           1       0            15  112.0
# 165  2008           0           1       0             3  201.0
# 166  2008           0           1      10            13  148.0
# 167  2008           0           1       1             7  116.0
# 168  2008           0           0      27             3  163.0
#
#      Opponent_Team_score
# 0                  190.0
# 1                  106.0
# 2                  143.0
# 3                  202.0
# 4                  122.0
# ..                   ...
# 164                126.0
# 165                211.0
# 166                147.0
# 167                112.0
# 168                164.0
#
# [169 rows x 7 columns]

# %% [markdown]
# #Model building and training
#
# The dataset given is only for training. After training your model a testing dataset will be shared on which your model is expected to predict outputs.
#
# The task is to predict the winners of the matches given the two teams, venue, and toss_winner. Accordingly, you have to decide the parameters to be taken into consideration for training the model.
#
# The training dataset is IPL dataset for 2008-2021. A general practice while Training is splitting your dataset into training and validation datasets.
#
# You can use only numpy, build a linear/logistic regression from scratch and train it.
#
# An idea to get started is to fit a linear regressor to predict the score of both the teams and the team with greater score will win.
#
# You can come up with any other idea as well.
#
# For reference check this article https://medium.com/analytics-vidhya/simple-linear-regression-with-example-using-numpy-e7b984f0d15e
#
# Another reference article which you guys can look into:
#
#
# https://www.analyticsvidhya.com/blog/2021/10/building-an-ipl-score-predictor-end-to-end-ml-project/

# %%
import numpy as np

# %%
param = {
    ('Chennai Super Kings') :[]
    ,('Mumbai Indians') :[]
    ,('Kolkata Knight Riders') :[]
    ,('Punjab Kings') :[]
    ,('Delhi Capitals') :[]
    ,('Rajasthan Royals') :[]
    ,('Sunrisers Hyderabad') :[]
    ,('Kings XI Punjab') :[]
    ,('Delhi Daredevils') :[]
    ,( 'Gujarat Lions') :[]
    ,( 'Rising Pune Supergiant') :[]
    ,( 'Pune Warriors') :[]
    ,( 'Kochi Tuskers Kerala') :[]
    ,( 'Royal Challengers Bangalore') :[]
}

modelacc = {
    ('Chennai Super Kings') :[]
    ,('Mumbai Indians') :[]
    ,('Kolkata Knight Riders') :[]
    ,('Punjab Kings') :[]
    ,('Delhi Capitals') :[]
    ,('Rajasthan Royals') :[]
    ,('Sunrisers Hyderabad') :[]
    ,('Kings XI Punjab') :[]
    ,('Delhi Daredevils') :[]
    ,( 'Gujarat Lions') :[]
    ,( 'Rising Pune Supergiant') :[]
    ,( 'Pune Warriors') :[]
    ,( 'Kochi Tuskers Kerala') :[]
    ,( 'Royal Challengers Bangalore') :[]
}

# %%
class iterator:
  def __init__(self, dfname, team):
    self.team = team
    self.dfname = dfname

  def train(self, epoch):

    w = np.random.rand(5,2)

    b = np.array([0.0,0.0], ndmin=2)

    learning_rate = 0.001

    for j in range(epoch):

       for i in range(int(0.9*len(self.dfname.print()))):

        input = np.array([teams[self.team], self.dfname.print().Opponent_Team[i], self.dfname.print().toss_winner[i],  self.dfname.print().toss_choice[i], self.dfname.print().stadium[i]], ndmin=2)
        y = np.array([self.dfname.print().score[i], self.dfname.print().Opponent_Team_score[i]], ndmin=2)

        output = np.matmul(input, w) + b
        
        mse = (y-output)**2

        dw = -2*(np.matmul(np.transpose(input),(y-output))) 
      
        db = -2*(y-output)
      
        w -= learning_rate*dw
      
        b -= learning_rate*db

    param[self.team] = [w, b]

  def validate(self):

    acc = 0

    for i in range(int(0.8*len(self.dfname.print())), len(self.dfname.print())):

      input = np.array([teams[self.team], self.dfname.print().Opponent_Team[i], self.dfname.print().toss_winner[i],  self.dfname.print().toss_choice[i], self.dfname.print().stadium[i]], ndmin=2)
      y = np.array([self.dfname.print().score[i], self.dfname.print().Opponent_Team_score[i]], ndmin=2)

      w, b = param[self.team]

      output = np.matmul(input,w) + b
      
      mse = (y-output)**2

      if self.dfname.print().score[i] > self.dfname.print().Opponent_Team_score[i] and output[0][0] > output[0][1]:
        acc = acc + 1
      elif self.dfname.print().score[i] < self.dfname.print().Opponent_Team_score[i] and output[0][0] < output[0][1]:
        acc = acc + 1
  
    numtotal = int(0.2*len(self.dfname.print())) 
    acc = (acc/numtotal)*100 
    print('Accuracy =',acc,'%')
    modelacc[self.team] = acc

# %%
def test(testds, param):
  
  for i in range(len(testds)):

      if testds.toss_choice[i] == 'Bat':
        choice = 1
      else:
        choice = 0

      input = np.array([teams[testds.team1[i]], teams[testds.team2[i]], teams[testds.toss_winner[i]], choice, stadiums[testds.stadium[i]]])
      
      if modelacc[testds.team1[i]] >= modelacc[testds.team2[i]]:
        w , b = param[testds.team1[i]]
      elif modelacc[testds.team1[i]] < modelacc[testds.team2[i]]:
        w , b = param[testds.team2[i]]
    
      output = np.matmul(input,w) + b

      if output[0][0] > output[0][1] :
        print(1)
      elif output[0][1] > output[0][0] :
        print(2)
      else:
        print(0) #Tie

# %%
csk = iterator(CSK, 'Chennai Super Kings')
mi = iterator(MI, 'Mumbai Indians')
kkr = iterator(KKR, 'Kolkata Knight Riders')
pk = iterator(PK, 'Punjab Kings')
dc = iterator(DC, 'Delhi Capitals')
rr = iterator(RR, 'Rajasthan Royals')
srh = iterator(SRH, 'Sunrisers Hyderabad')
kxip = iterator(KXIP, 'Kings XI Punjab')
dd = iterator(DD, 'Delhi Daredevils')
gl = iterator(GL, 'Gujarat Lions')
rps = iterator(RPS, 'Rising Pune Supergiant')
pw = iterator(PW, 'Pune Warriors')
ktk = iterator(KTK, 'Kochi Tuskers Kerala')
rcb = iterator(RCB, 'Royal Challengers Bangalore')

# %%
csk.train(5)
mi.train(5)
kkr.train(5)
pk.train(5)
dc.train(5)
rr.train(5)
srh.train(5)
kxip.train(5)
dd.train(5)
gl.train(5)
rps.train(5)
pw.train(5)
ktk.train(5)
rcb.train(5)


csk.validate()
mi.validate()
kkr.validate()
pk.validate()
dc.validate()
rr.validate()
srh.validate()
kxip.validate()
dd.validate()
gl.validate()
rps.validate()
pw.validate()
ktk.validate()
rcb.validate()
# Out:
# Accuracy = 69.6969696969697 %
# Accuracy = 51.28205128205128 %
# Accuracy = 58.333333333333336 %
# Accuracy = 100.0 %
# Accuracy = 40.0 %
# Accuracy = 40.0 %
# Accuracy = 72.72727272727273 %
# Accuracy = 61.76470588235294 %
# Accuracy = 44.827586206896555 %
# Accuracy = 60.0 %
# Accuracy = 80.0 %
# Accuracy = 44.44444444444444 %
# Accuracy = 100.0 %
# Accuracy = 57.14285714285714 %

# %%
test_df = pd.read_csv('/content/Test_dataset.csv')

# %%
test(test_df, param)
# Out:
# 1
# 2
# 1
# 2
# 2
# 1
# 2
# 1
# 1
# 2
# 1
# 2
# 2
# 1
# 1
# 1
# 2
# 1
# 2
# 1
# 1
# 2
# 2
# 1
# 2
# 2
# 2
# 2
# 2
# 1
# 1
# 1
# 2
# 1
# 2
# 1
# 1
# 1
# 2
# 1
# 2
# 1
# 2
# 1
# 2
