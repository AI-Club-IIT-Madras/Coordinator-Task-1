# %% [markdown]
# <a href="https://colab.research.google.com/github/Mith-Jain/Coordinator-Task-1/blob/main/Copy_of_Coordinator_Task_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Coordinator Task 1**
#
# Welcome to the first coordinator task bois!!
#
# This time we have a task tailored specifically for you guys, not a house price prediction task, not a cat-dog classification task but something much more interesting!
#
# ## **IPL result prediction task!**
#
# Yes, you are right. Predict the *scripted* IPL matches using your ML skills! We have shared the IPL dataset spanning from the year 2008-2021. You are expected to predict the results for the year 2022.
#
# **Task** : Predict the winner of every match conducted in 2023 based on the dataset that we have shared. The coordinator(s) whose model predicts with highest accuracy will be given a treat.
#
# **Instructions**
#
#
# *   The coordinator task has two sub-parts:
#
#       1.   EDA (Exploratory Data Analysis)
#       2. Data preprocessing
#       3.   Model building and training
#
#
# *   The notebook is designed and categorized accordingly to help you throughout this task
# *   For EDA you are expected to use Pandas, Numpy, Matplotlib, Seaborn wherever neccessary. (you are free to use any other Python libraries as well)
# *   For the model building, use only linear/logistic regression
# *   You are not allowed to use Pytorch. Build the model from scratch using Numpy
#
#
# **Note**: We don't expect you to check the 2022 IPL results, be fair and submit your model predictions.
#
# Be as creative as possible, guys; we have given you a raw dataset, as you will have much more scope in exploring the problem statement. Enjoy the task!

# %% [markdown]
# # Downloading the dataset
#
# The dataset is a CSV file. First download it onto your local system and upload it on your colab notebook. Use Pandas to open the CSV file and study the dataset.

# %%
import pandas as pd

# %%
raw_df = pd.read_csv('/content/IPL_train_ dataset 2008-2021.csv') #the path of the csv file may be different for you change it accordingly

# %% [markdown]
# # Data Analysis
#
# Analyze the raw_df. Use Pandas to make observations. Feel free to use Google or Chatgpt for the same. So many functions can be performed using Pandas and remembering them isn't possible. So give the right prompt as you require and use those commands.
#
# The next few cells are left for you guys to experiment
#
# We have coded a few cells to give you an idea.

# %%
raw_df.head(10)

# %%
raw_df.winner.unique()
# Out:
# array(['RCB', 'Capitals', 'KKR', 'Punjab', 'Mumbai', 'Royals', 'Super',
#        'Sunrisers', 'Tied', 'Kings', 'No', 'Daredevils', 'Supergiant',
#        'Guj', 'Match', 'Supergiants', 'Warriors', 'Chargers', 'Kochi'],
#       dtype=object)

# %% [markdown]
# Notice that in the winners column, the team names aren't appropriately mentioned. Lets change them as follows:
# replace
#
# *   RCB with Royal Challengers Bangalore
# *   Capitals with Delhi Capitals
# *   KKR with Kolkata Knight Riders
# *   Punjab with Punjab Kings
# *   Mumbai with Mumbai Indians
# *   Royals with Rajasthan Royals
# *   Super with Chennai Super Kings
# *   Sunrisers with Sunrisers Hyderabad
# *   Kings with Kings XI Punjab
# *   Daredevils with Delhi Daredevils
# *   Supergiant with Rising Pune Supergiants
# *   Guj with Gujarat Lions
# *   Supergiants with Rising Pune Supergiants
# *   Warriors with Pune Warriors
# *   Chargers with Deccan Chargers
# *   Kochi with Kochi Tuskers Kerala

# %%
raw_df.replace(to_replace="RCB", value="Royal Challengers Bangalore",inplace=True)
raw_df.replace(to_replace="Capitals", value="Delhi Capitals",inplace=True)
raw_df.replace(to_replace="KKR", value="Kolkata Knight Riders",inplace=True)
raw_df.replace(to_replace="Punjab Kings", value="Kings XI Punjab",inplace=True)
raw_df.replace(to_replace="Punjab", value="Kings XI Punjab",inplace=True)
raw_df.replace(to_replace="Mumbai", value="Mumbai Indians",inplace=True)
raw_df.replace(to_replace="Royals", value="Rajasthan Royals",inplace=True)
raw_df.replace(to_replace="Super", value="Chennai Super Kings",inplace=True)
raw_df.replace(to_replace="Sunrisers", value="Sunrisers Hyderabad",inplace=True)
raw_df.replace(to_replace="Kings", value="Kings XI Punjab",inplace=True)
raw_df.replace(to_replace="Daredevils", value="Delhi Capitals",inplace=True)
raw_df.replace(to_replace="Delhi Daredevils", value="Delhi Capitals",inplace=True)
raw_df.replace(to_replace=["Supergiant","Supergiants"], value="Rising Pune Supergiants",inplace=True)
raw_df.replace(to_replace="Guj", value="Gujarat Lions",inplace=True)
raw_df.replace(to_replace="Warriors", value="Pune Warriors",inplace=True)
raw_df.replace(to_replace="Chargers", value="Deccan Chargers",inplace=True)
raw_df.replace(to_replace="Kochi", value="Kochi Tuskers Kerala",inplace=True)

# %%
sorted_df = raw_df.sort_values('team2')
print(len(sorted_df))
# Out:
# 884

# %% [markdown]
# You can also discard the matches which were tied/abandoned

# %%
raw_df.dropna(inplace = True)

# %%
raw_df = raw_df[raw_df['winner'] != 'No']

# %%
raw_df = raw_df[raw_df['winner'] != 'Tied']

# %%
print(len(raw_df))
# Out:
# 770

# %% [markdown]
# #Data Visualization
#
# Use Matplotlib and Seaborn to plot graphs to visualize the dataset. Plot pie charts, histograms, and scatterplots to analyze and present the data understandably.
#
# Take help of this notebook to proceed ahead
# https://www.kaggle.com/code/razamh/eda-ipl-dataset
#
# Using the plots answer the following questions:
#
#
# 1.   Number of matches won by each team
# 2.   Percentage of matches in which first batting and second batting team has won
# 3.   Number of man of the matches won per player (plot for first 10 players)
# 4.   Number of matches conducted in each year
# 5.   Number of matches in each venue
# 6.   Number of champions won per team (hint: the last match of every season is the final)
# 7. Average score of the first batting team in each venue
#
#
#   We have helped you with the first question, answer the remaining the questions.

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
raw_df.winner.unique()
# Out:
# array(['Royal Challengers Bangalore', 'Delhi Capitals',
#        'Kolkata Knight Riders', 'Kings XI Punjab', 'Mumbai Indians',
#        'Rajasthan Royals', 'Chennai Super Kings', 'Sunrisers Hyderabad'],
#       dtype=object)

# %%
raw_df.head(25)

# %%
plt.figure(figsize=(12,6))
data = raw_df.winner.value_counts()
pdata = raw_df.winner.value_counts(normalize = True)*100
print('Actaul values:\n',data)
print('\nPercentage:\n',pdata)
sns.barplot(y = data.index, x = data)
plt.show()

# %% [markdown]
# Check the above plot, It also has Tied, Match, No on the Y-axis which have to be removed. Plot the above graph again making the changes.
#
# Also clean the data similarly wherever required.

# %%
win1 = 0
win2 = 0
for index,row in raw_df.iterrows():
  if row['winner'] == row['team1']:
    win1 += 1 
  else:
    win2 += 1
d = {'Team': ['Team 1', 'Team 2'], 'Number of wins': [win1, win2]}
d = pd.DataFrame(d)
plt.figure(figsize=(12,1))
sns.barplot(data=d, x='Number of wins', y='Team')
plt.show()
print('Percentage of matches won by team 1:', win1 * 100/(win1 + win2), '\nPercentage of matches won by team 2:', win2 * 100/(win1 + win2))

# %%
plt.figure(figsize=(12,6))
data = raw_df.man_of_the_match.value_counts()
print('Men of the matches and their corresponding frequencies:\n',data.to_string())
sns.barplot(y = data[:10].index, x = data[:10])
plt.show()

# %%
plt.figure(figsize=(12,6))
raw_df = raw_df.rename(columns={'year ': 'year'})
data = raw_df.year.value_counts()
print('Number of matches each year:\n',data.to_string())
sns.barplot(x = data.index, y = data)
plt.xlabel('Year')
plt.ylabel('Number of matches')
plt.show()

# %%
plt.figure(figsize=(12,15))
data = raw_df.stadium.value_counts()
print('Venues and the number of matches played there:\n',data.to_string())
sns.barplot(y = data.index, x = data)
plt.xlabel('Stadium')
plt.ylabel('Number of matches')
plt.show()

# %%
d = {} 
plt.figure(figsize=(12,6))
num = len(raw_df)
for index,row in raw_df.iterrows():
  if index:
    if row['year'] != previous_row['year'] or index == num:
      if previous_row['winner'] in d:
        d[previous_row['winner']] += 1
      else:
        d[previous_row['winner']] = 1
  previous_row = row
df = pd.DataFrame.from_dict(d,orient='index',columns = ['Values'])
df.reset_index(inplace=True)
df.columns = ['Team', 'Win count']
print('\n',df.to_string(index=False))
sns.barplot(df, y = 'Win count', x = 'Team')
plt.xlabel('Team')
plt.ylabel('Number of times they were the champions')
plt.show()

# %%
plt.figure(figsize=(12,15))
d = {}
for index,row in raw_df.iterrows():
  if row['stadium'] in d:
    d[row['stadium']].append(row['team1_score'])
  else:
    d[row['stadium']] = [row['team1_score']]
for i in d:
  d[i] = sum(d[i])/len(d[i])
df = pd.DataFrame.from_dict(d,orient='index',columns = ['Values'])
df.reset_index(inplace=True)
df.columns = ['Venue', 'Average score']
print('\n',df.to_string(index=False))
sns.barplot(df, y = 'Venue', x = 'Average score')
plt.xlabel('Average score')
plt.ylabel('Venue')
plt.show()

# %% [markdown]
# #Data Preprocessing
#
# We have to clean the data and preprocess it to convert it into a trainable format.
#
# For that you have to get rid of the NaN values, remove the un-neccesary parameters and also use feature engineering wherever required.
#
# Data preprocessing is essential for the performance of the model, the better parameters you define/retain the better model can learn and hence perform.

# %% [markdown]
# We will help you with one team. Suppose lets take RCB. We have to predict the score of RCB using the parameters: team against which it is playing, did it win the toss, stadium, place.

# %%
raw_df.team1.unique()
# Out:
# array(['Mumbai Indians', 'Chennai Super Kings', 'Kolkata Knight Riders',
#        'Kings XI Punjab', 'Royal Challengers Bangalore', 'Delhi Capitals',
#        'Rajasthan Royals', 'Sunrisers Hyderabad'], dtype=object)

# %%
raw_df = raw_df[raw_df['team1'] != 'Gujarat Lions']
raw_df = raw_df[raw_df['team1'] != 'Rising Pune Supergiant']
raw_df = raw_df[raw_df['team1'] != 'Rising Pune Supergiants']
raw_df = raw_df[raw_df['team1'] != 'Pune Warriors']
raw_df = raw_df[raw_df['team1'] != 'Deccan Chargers']
raw_df = raw_df[raw_df['team1'] != 'Kochi Tuskers Kerala']
raw_df = raw_df[raw_df['team2'] != 'Gujarat Lions']
raw_df = raw_df[raw_df['team2'] != 'Rising Pune Supergiant']
raw_df = raw_df[raw_df['team2'] != 'Rising Pune Supergiants']
raw_df = raw_df[raw_df['team2'] != 'Pune Warriors']
raw_df = raw_df[raw_df['team2'] != 'Delhi Daredevils']
raw_df = raw_df[raw_df['team2'] != 'Deccan Chargers']
raw_df = raw_df[raw_df['team2'] != 'Kochi Tuskers Kerala']

# %%
RCB_df = raw_df.loc[((raw_df['team1'] == 'Royal Challengers Bangalore') | (raw_df['team2'] == 'Royal Challengers Bangalore'))]

# %%
print(len(raw_df))
sorted_df = raw_df.sort_values('team2')
print(sorted_df.to_string())

# %%
RCB_df.drop(columns =['margin','man_of_the_match','winner','place'], axis=1, inplace=True)
# Out:
# <ipython-input-36-95c086e647ce>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   RCB_df.drop(columns =['margin','man_of_the_match','winner','place'], axis=1, inplace=True)

# %%
RCB_df.reset_index(inplace = True)

# %%
print(RCB_df.to_string())

# %%
team_score = []
for i in range(len(RCB_df)):
  if RCB_df['team1'].values[i] == 'Royal Challengers Bangalore':
    team_score.append(RCB_df['team1_score'].values[i])
  else:
    team_score.append(RCB_df['team2_score'].values[i])

# %% [markdown]
# Now we got the team score of RCB in all of its matches. This will be our target dataset.

# %%
len(team_score)
# Out:
# 132

# %%
RCB_df.drop(columns =['team1_score','team2_score','index'], axis=1, inplace=True)

# %%
RCB_df

# %% [markdown]
# Encoding the toss winner column. If RCB won the toss then 1 else 0

# %%
for i in range(len(RCB_df)):
  if RCB_df['toss_winner'].values[i] == 'Royal Challengers Bangalore':
    RCB_df['toss_winner'].values[i] = 1
  else:
    RCB_df['toss_winner'].values[i] = 0

# %%
RCB_df

# %%
opponent_team = []
for i in range(len(RCB_df)):
  if RCB_df['team1'].values[i] != 'Royal Challengers Bangalore':
    opponent_team.append(RCB_df['team1'].values[i])
  else:
    opponent_team.append(RCB_df['team2'].values[i])

# %%
RCB_df['Opponent_Team'] = opponent_team
# Out:
# <ipython-input-24-04689642e00b>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   RCB_df['Opponent_Team'] = opponent_team

# %%
RCB_df.drop(columns =['team1','team2'], axis=1, inplace=True)
# Out:
# <ipython-input-25-853f4b1173dd>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   RCB_df.drop(columns =['team1','team2'], axis=1, inplace=True)

# %%
RCB_df

# %%
RCB_df['RCB score'] = team_score

# %% [markdown]
# Similarly encode the other columns. Machine Learning models don't understand words/text so you have to encode the text to numbers.
#
# Check different techniques of encoding: one-hot encoding and number encoding and use either one to encode the columns: toss_choice, opponent team and stadium
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Now it's time for you to take up! All the best
#
# Prepare similar data frames for other teams. Predict the scores of the team based on the parameters.
#
# Suppose say you have to predict who will win RCB vs CSK, predict the score of RCB considering CSK as opponent. Then predict score of CSK with RCB as opponent. Then compare both scores, whoever scores higher will be the winner of the match.

# %%
from sklearn.preprocessing import OneHotEncoder
encoder = OneHotEncoder()
one_hot_encoded = encoder.fit_transform(RCB_df[['toss_choice']]).toarray()
RCB_df = pd.concat([RCB_df, pd.DataFrame(one_hot_encoded, columns=encoder.get_feature_names_out(['toss_choice']))], axis=1)

# %%
RCB_df

# %%
from sklearn.preprocessing import OneHotEncoder
encoder = OneHotEncoder()
one_hot_encoded = encoder.fit_transform(RCB_df[['Opponent_Team']]).toarray()
RCB_df = pd.concat([RCB_df, pd.DataFrame(one_hot_encoded, columns=encoder.get_feature_names_out(['Opponent_Team']))], axis=1)
RCB_df.drop(columns = ['Opponent_Team'], axis = 1, inplace = True)

# %%
from sklearn.preprocessing import OneHotEncoder
encoder = OneHotEncoder()
one_hot_encoded = encoder.fit_transform(RCB_df[['stadium']]).toarray()
RCB_df = pd.concat([RCB_df, pd.DataFrame(one_hot_encoded, columns=encoder.get_feature_names_out(['stadium']))], axis=1)
RCB_df.drop(columns = ['stadium'], axis = 1, inplace = True)

# %%
RCB_df

# %%
CSK_df = raw_df.loc[((raw_df['team1'] == 'Chennai Super Kings') | (raw_df['team2'] == 'Chennai Super Kings'))]
CSK_df.drop(columns =['margin','man_of_the_match','winner','place'], axis=1, inplace=True)
CSK_df.reset_index(inplace = True)
team_score = []
for i in range(len(CSK_df)):
  if CSK_df['team1'].values[i] == 'Chennai Super Kings':
    team_score.append(CSK_df['team1_score'].values[i])
  else:
    team_score.append(CSK_df['team2_score'].values[i])
CSK_df.drop(columns =['team1_score','team2_score','index'], axis=1, inplace=True)
for i in range(len(CSK_df)):
  if CSK_df['toss_winner'].values[i] == 'Chennai Super Kings':
    CSK_df['toss_winner'].values[i] = 1
  else:
    CSK_df['toss_winner'].values[i] = 0
opponent_team = []
for i in range(len(CSK_df)):
  if CSK_df['team1'].values[i] != 'Chennai Super Kings':
    opponent_team.append(CSK_df['team1'].values[i])
  else:
    opponent_team.append(CSK_df['team2'].values[i])
CSK_df['Opponent_Team'] = opponent_team
CSK_df.drop(columns =['team1','team2'], axis=1, inplace=True)
CSK_df['CSK score'] = team_score
from sklearn.preprocessing import OneHotEncoder
encoder = OneHotEncoder()
one_hot_encoded = encoder.fit_transform(CSK_df[['toss_choice']]).toarray()
CSK_df = pd.concat([CSK_df, pd.DataFrame(one_hot_encoded, columns=encoder.get_feature_names_out(['toss_choice']))], axis=1)
CSK_df.drop(columns = ['toss_choice'], axis = 1, inplace = True)
from sklearn.preprocessing import OneHotEncoder
encoder = OneHotEncoder()
one_hot_encoded = encoder.fit_transform(CSK_df[['Opponent_Team']]).toarray()
CSK_df = pd.concat([CSK_df, pd.DataFrame(one_hot_encoded, columns=encoder.get_feature_names_out(['Opponent_Team']))], axis=1)
CSK_df.drop(columns = ['Opponent_Team'], axis = 1, inplace = True)
from sklearn.preprocessing import OneHotEncoder
encoder = OneHotEncoder()
one_hot_encoded = encoder.fit_transform(CSK_df[['stadium']]).toarray()
CSK_df = pd.concat([CSK_df, pd.DataFrame(one_hot_encoded, columns=encoder.get_feature_names_out(['stadium']))], axis=1)
CSK_df.drop(columns = ['stadium'], axis = 1, inplace = True)
# Out:
# <ipython-input-8-4662d041d940>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   CSK_df.drop(columns =['margin','man_of_the_match','winner','place'], axis=1, inplace=True)
# <ipython-input-8-4662d041d940>:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   CSK_df.drop(columns =['team1_score','team2_score','index'], axis=1, inplace=True)
# <ipython-input-8-4662d041d940>:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...

# %%
RCB_df = raw_df.loc[((raw_df['team1'] == 'Royal Challengers Bangalore') | (raw_df['team2'] == 'Royal Challengers Bangalore'))]
RCB_df.drop(columns =['margin','man_of_the_match','winner','place'], axis=1, inplace=True)
RCB_df.reset_index(inplace = True)
team_score = []
for i in range(len(RCB_df)):
  if RCB_df['team1'].values[i] == 'Royal Challengers Bangalore':
    team_score.append(RCB_df['team1_score'].values[i])
  else:
    team_score.append(RCB_df['team2_score'].values[i])
RCB_df.drop(columns =['team1_score','team2_score','index'], axis=1, inplace=True)
for i in range(len(RCB_df)):
  if RCB_df['toss_winner'].values[i] == 'Royal Challengers Bangalore':
    RCB_df['toss_winner'].values[i] = 1
  else:
    RCB_df['toss_winner'].values[i] = 0
opponent_team = []
for i in range(len(RCB_df)):
  if RCB_df['team1'].values[i] != 'Royal Challengers Bangalore':
    opponent_team.append(RCB_df['team1'].values[i])
  else:
    opponent_team.append(RCB_df['team2'].values[i])
RCB_df['Opponent_Team'] = opponent_team
RCB_df.drop(columns =['team1','team2'], axis=1, inplace=True)
RCB_df['RCB score'] = team_score
from sklearn.preprocessing import OneHotEncoder
encoder = OneHotEncoder()
one_hot_encoded = encoder.fit_transform(RCB_df[['toss_choice']]).toarray()
RCB_df = pd.concat([RCB_df, pd.DataFrame(one_hot_encoded, columns=encoder.get_feature_names_out(['toss_choice']))], axis=1)
RCB_df.drop(columns = ['toss_choice'], axis = 1, inplace = True)
from sklearn.preprocessing import OneHotEncoder
encoder = OneHotEncoder()
one_hot_encoded = encoder.fit_transform(RCB_df[['Opponent_Team']]).toarray()
RCB_df = pd.concat([RCB_df, pd.DataFrame(one_hot_encoded, columns=encoder.get_feature_names_out(['Opponent_Team']))], axis=1)
RCB_df.drop(columns = ['Opponent_Team'], axis = 1, inplace = True)
from sklearn.preprocessing import OneHotEncoder
encoder = OneHotEncoder()
one_hot_encoded = encoder.fit_transform(RCB_df[['stadium']]).toarray()
RCB_df = pd.concat([RCB_df, pd.DataFrame(one_hot_encoded, columns=encoder.get_feature_names_out(['stadium']))], axis=1)
RCB_df.drop(columns = ['stadium'], axis = 1, inplace = True)
# Out:
# <ipython-input-9-3da666920d24>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   RCB_df.drop(columns =['margin','man_of_the_match','winner','place'], axis=1, inplace=True)
# <ipython-input-9-3da666920d24>:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   RCB_df.drop(columns =['team1_score','team2_score','index'], axis=1, inplace=True)
# <ipython-input-9-3da666920d24>:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...

# %%
SRH_df = raw_df.loc[((raw_df['team1'] == 'Sunrisers Hyderabad') | (raw_df['team2'] == 'Sunrisers Hyderabad'))]
SRH_df.drop(columns =['margin','man_of_the_match','winner','place'], axis=1, inplace=True)
SRH_df.reset_index(inplace = True)
team_score = []
for i in range(len(SRH_df)):
  if SRH_df['team1'].values[i] == 'Sunrisers Hyderabad':
    team_score.append(SRH_df['team1_score'].values[i])
  else:
    team_score.append(SRH_df['team2_score'].values[i])
SRH_df.drop(columns =['team1_score','team2_score','index'], axis=1, inplace=True)
for i in range(len(SRH_df)):
  if SRH_df['toss_winner'].values[i] == 'Sunrisers Hyderabad':
    SRH_df['toss_winner'].values[i] = 1
  else:
    SRH_df['toss_winner'].values[i] = 0
opponent_team = []
for i in range(len(SRH_df)):
  if SRH_df['team1'].values[i] != 'Sunrisers Hyderabad':
    opponent_team.append(SRH_df['team1'].values[i])
  else:
    opponent_team.append(SRH_df['team2'].values[i])
SRH_df['Opponent_Team'] = opponent_team
SRH_df.drop(columns =['team1','team2'], axis=1, inplace=True)
SRH_df['SRH score'] = team_score
from sklearn.preprocessing import OneHotEncoder
encoder = OneHotEncoder()
one_hot_encoded = encoder.fit_transform(SRH_df[['toss_choice']]).toarray()
SRH_df = pd.concat([SRH_df, pd.DataFrame(one_hot_encoded, columns=encoder.get_feature_names_out(['toss_choice']))], axis=1)
SRH_df.drop(columns = ['toss_choice'], axis = 1, inplace = True)
from sklearn.preprocessing import OneHotEncoder
encoder = OneHotEncoder()
one_hot_encoded = encoder.fit_transform(SRH_df[['Opponent_Team']]).toarray()
SRH_df = pd.concat([SRH_df, pd.DataFrame(one_hot_encoded, columns=encoder.get_feature_names_out(['Opponent_Team']))], axis=1)
SRH_df.drop(columns = ['Opponent_Team'], axis = 1, inplace = True)
from sklearn.preprocessing import OneHotEncoder
encoder = OneHotEncoder()
one_hot_encoded = encoder.fit_transform(SRH_df[['stadium']]).toarray()
SRH_df = pd.concat([SRH_df, pd.DataFrame(one_hot_encoded, columns=encoder.get_feature_names_out(['stadium']))], axis=1)
SRH_df.drop(columns = ['stadium'], axis = 1, inplace = True)
# Out:
# <ipython-input-10-b910679875e9>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   SRH_df.drop(columns =['margin','man_of_the_match','winner','place'], axis=1, inplace=True)
# <ipython-input-10-b910679875e9>:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   SRH_df.drop(columns =['team1_score','team2_score','index'], axis=1, inplace=True)
# <ipython-input-10-b910679875e9>:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...

# %%
MI_df = raw_df.loc[((raw_df['team1'] == 'Mumbai Indians') | (raw_df['team2'] == 'Mumbai Indians'))]
MI_df.drop(columns =['margin','man_of_the_match','winner','place'], axis=1, inplace=True)
MI_df.reset_index(inplace = True)
team_score = []
for i in range(len(MI_df)):
  if MI_df['team1'].values[i] == 'Mumbai Indians':
    team_score.append(MI_df['team1_score'].values[i])
  else:
    team_score.append(MI_df['team2_score'].values[i])
MI_df.drop(columns =['team1_score','team2_score','index'], axis=1, inplace=True)
for i in range(len(MI_df)):
  if MI_df['toss_winner'].values[i] == 'Mumbai Indians':
    MI_df['toss_winner'].values[i] = 1
  else:
    MI_df['toss_winner'].values[i] = 0
opponent_team = []
for i in range(len(MI_df)):
  if MI_df['team1'].values[i] != 'Mumbai Indians':
    opponent_team.append(MI_df['team1'].values[i])
  else:
    opponent_team.append(MI_df['team2'].values[i])
MI_df['Opponent_Team'] = opponent_team
MI_df.drop(columns =['team1','team2'], axis=1, inplace=True)
MI_df['MI score'] = team_score
from sklearn.preprocessing import OneHotEncoder
encoder = OneHotEncoder()
one_hot_encoded = encoder.fit_transform(MI_df[['toss_choice']]).toarray()
MI_df = pd.concat([MI_df, pd.DataFrame(one_hot_encoded, columns=encoder.get_feature_names_out(['toss_choice']))], axis=1)
MI_df.drop(columns = ['toss_choice'], axis = 1, inplace = True)
from sklearn.preprocessing import OneHotEncoder
encoder = OneHotEncoder()
one_hot_encoded = encoder.fit_transform(MI_df[['Opponent_Team']]).toarray()
MI_df = pd.concat([MI_df, pd.DataFrame(one_hot_encoded, columns=encoder.get_feature_names_out(['Opponent_Team']))], axis=1)
MI_df.drop(columns = ['Opponent_Team'], axis = 1, inplace = True)
from sklearn.preprocessing import OneHotEncoder
encoder = OneHotEncoder()
one_hot_encoded = encoder.fit_transform(MI_df[['stadium']]).toarray()
MI_df = pd.concat([MI_df, pd.DataFrame(one_hot_encoded, columns=encoder.get_feature_names_out(['stadium']))], axis=1)
MI_df.drop(columns = ['stadium'], axis = 1, inplace = True)
# Out:
# <ipython-input-11-4684e62f754c>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   MI_df.drop(columns =['margin','man_of_the_match','winner','place'], axis=1, inplace=True)
# <ipython-input-11-4684e62f754c>:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   MI_df.drop(columns =['team1_score','team2_score','index'], axis=1, inplace=True)
# <ipython-input-11-4684e62f754c>:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...

# %%
DC_df = raw_df.loc[((raw_df['team1'] == 'Delhi Capitals') | (raw_df['team2'] == 'Delhi Capitals'))]
DC_df.drop(columns =['margin','man_of_the_match','winner','place'], axis=1, inplace=True)
DC_df.reset_index(inplace = True)
team_score = []
for i in range(len(DC_df)):
  if DC_df['team1'].values[i] == 'Delhi Capitals':
    team_score.append(DC_df['team1_score'].values[i])
  else:
    team_score.append(DC_df['team2_score'].values[i])
DC_df.drop(columns =['team1_score','team2_score','index'], axis=1, inplace=True)
for i in range(len(DC_df)):
  if DC_df['toss_winner'].values[i] == 'Delhi Capitals':
    DC_df['toss_winner'].values[i] = 1
  else:
    DC_df['toss_winner'].values[i] = 0
opponent_team = []
for i in range(len(DC_df)):
  if DC_df['team1'].values[i] != 'Delhi Capitals':
    opponent_team.append(DC_df['team1'].values[i])
  else:
    opponent_team.append(DC_df['team2'].values[i])
DC_df['Opponent_Team'] = opponent_team
DC_df.drop(columns =['team1','team2'], axis=1, inplace=True)
DC_df['DC score'] = team_score
from sklearn.preprocessing import OneHotEncoder
encoder = OneHotEncoder()
one_hot_encoded = encoder.fit_transform(DC_df[['toss_choice']]).toarray()
DC_df = pd.concat([DC_df, pd.DataFrame(one_hot_encoded, columns=encoder.get_feature_names_out(['toss_choice']))], axis=1)
DC_df.drop(columns = ['toss_choice'], axis = 1, inplace = True)
encoder = OneHotEncoder()
one_hot_encoded = encoder.fit_transform(DC_df[['Opponent_Team']]).toarray()
DC_df = pd.concat([DC_df, pd.DataFrame(one_hot_encoded, columns=encoder.get_feature_names_out(['Opponent_Team']))], axis=1)
DC_df.drop(columns = ['Opponent_Team'], axis = 1, inplace = True)
encoder = OneHotEncoder()
one_hot_encoded = encoder.fit_transform(DC_df[['stadium']]).toarray()
DC_df = pd.concat([DC_df, pd.DataFrame(one_hot_encoded, columns=encoder.get_feature_names_out(['stadium']))], axis=1)
DC_df.drop(columns = ['stadium'], axis = 1, inplace = True)
# Out:
# <ipython-input-12-936e03bbfcee>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   DC_df.drop(columns =['margin','man_of_the_match','winner','place'], axis=1, inplace=True)
# <ipython-input-12-936e03bbfcee>:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   DC_df.drop(columns =['team1_score','team2_score','index'], axis=1, inplace=True)
# <ipython-input-12-936e03bbfcee>:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...

# %%
RR_df = raw_df.loc[((raw_df['team1'] == 'Rajasthan Royals') | (raw_df['team2'] == 'Rajasthan Royals'))]
RR_df.drop(columns =['margin','man_of_the_match','winner','place'], axis=1, inplace=True)
RR_df.reset_index(inplace = True)
team_score = []
for i in range(len(RR_df)):
  if RR_df['team1'].values[i] == 'Rajasthan Royals':
    team_score.append(RR_df['team1_score'].values[i])
  else:
    team_score.append(RR_df['team2_score'].values[i])
RR_df.drop(columns =['team1_score','team2_score','index'], axis=1, inplace=True)
for i in range(len(RR_df)):
  if RR_df['toss_winner'].values[i] == 'Rajasthan Royals':
    RR_df['toss_winner'].values[i] = 1
  else:
    RR_df['toss_winner'].values[i] = 0
opponent_team = []
for i in range(len(RR_df)):
  if RR_df['team1'].values[i] != 'Rajasthan Royals':
    opponent_team.append(RR_df['team1'].values[i])
  else:
    opponent_team.append(RR_df['team2'].values[i])
RR_df['Opponent_Team'] = opponent_team
RR_df.drop(columns =['team1','team2'], axis=1, inplace=True)
RR_df['RR score'] = team_score
from sklearn.preprocessing import OneHotEncoder
encoder = OneHotEncoder()
one_hot_encoded = encoder.fit_transform(RR_df[['toss_choice']]).toarray()
RR_df = pd.concat([RR_df, pd.DataFrame(one_hot_encoded, columns=encoder.get_feature_names_out(['toss_choice']))], axis=1)
RR_df.drop(columns = ['toss_choice'], axis = 1, inplace = True)
from sklearn.preprocessing import OneHotEncoder
encoder = OneHotEncoder()
one_hot_encoded = encoder.fit_transform(RR_df[['Opponent_Team']]).toarray()
RR_df = pd.concat([RR_df, pd.DataFrame(one_hot_encoded, columns=encoder.get_feature_names_out(['Opponent_Team']))], axis=1)
RR_df.drop(columns = ['Opponent_Team'], axis = 1, inplace = True)
from sklearn.preprocessing import OneHotEncoder
encoder = OneHotEncoder()
one_hot_encoded = encoder.fit_transform(RR_df[['stadium']]).toarray()
RR_df = pd.concat([RR_df, pd.DataFrame(one_hot_encoded, columns=encoder.get_feature_names_out(['stadium']))], axis=1)
RR_df.drop(columns = ['stadium'], axis = 1, inplace = True)
# Out:
# <ipython-input-13-393006b11306>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   RR_df.drop(columns =['margin','man_of_the_match','winner','place'], axis=1, inplace=True)
# <ipython-input-13-393006b11306>:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   RR_df.drop(columns =['team1_score','team2_score','index'], axis=1, inplace=True)
# <ipython-input-13-393006b11306>:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...

# %%
KKR_df = raw_df.loc[((raw_df['team1'] == 'Kolkata Knight Riders') | (raw_df['team2'] == 'Kolkata Knight Riders'))]
KKR_df.drop(columns =['margin','man_of_the_match','winner','place'], axis=1, inplace=True)
KKR_df.reset_index(inplace = True)
team_score = []
for i in range(len(KKR_df)):
  if KKR_df['team1'].values[i] == 'Kolkata Knight Riders':
    team_score.append(KKR_df['team1_score'].values[i])
  else:
    team_score.append(KKR_df['team2_score'].values[i])
KKR_df.drop(columns =['team1_score','team2_score','index'], axis=1, inplace=True)
for i in range(len(KKR_df)):
  if KKR_df['toss_winner'].values[i] == 'Kolkata Knight Riders':
    KKR_df['toss_winner'].values[i] = 1
  else:
    KKR_df['toss_winner'].values[i] = 0
opponent_team = []
for i in range(len(KKR_df)):
  if KKR_df['team1'].values[i] != 'Kolkata Knight Riders':
    opponent_team.append(KKR_df['team1'].values[i])
  else:
    opponent_team.append(KKR_df['team2'].values[i])
KKR_df['Opponent_Team'] = opponent_team
KKR_df.drop(columns =['team1','team2'], axis=1, inplace=True)
KKR_df['KKR score'] = team_score
from sklearn.preprocessing import OneHotEncoder
encoder = OneHotEncoder()
one_hot_encoded = encoder.fit_transform(KKR_df[['toss_choice']]).toarray()
KKR_df = pd.concat([KKR_df, pd.DataFrame(one_hot_encoded, columns=encoder.get_feature_names_out(['toss_choice']))], axis=1)
KKR_df.drop(columns = ['toss_choice'], axis = 1, inplace = True)
from sklearn.preprocessing import OneHotEncoder
encoder = OneHotEncoder()
one_hot_encoded = encoder.fit_transform(KKR_df[['Opponent_Team']]).toarray()
KKR_df = pd.concat([KKR_df, pd.DataFrame(one_hot_encoded, columns=encoder.get_feature_names_out(['Opponent_Team']))], axis=1)
KKR_df.drop(columns = ['Opponent_Team'], axis = 1, inplace = True)
from sklearn.preprocessing import OneHotEncoder
encoder = OneHotEncoder()
one_hot_encoded = encoder.fit_transform(KKR_df[['stadium']]).toarray()
KKR_df = pd.concat([KKR_df, pd.DataFrame(one_hot_encoded, columns=encoder.get_feature_names_out(['stadium']))], axis=1)
KKR_df.drop(columns = ['stadium'], axis = 1, inplace = True)
# Out:
# <ipython-input-14-67f52c50afac>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   KKR_df.drop(columns =['margin','man_of_the_match','winner','place'], axis=1, inplace=True)
# <ipython-input-14-67f52c50afac>:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   KKR_df.drop(columns =['team1_score','team2_score','index'], axis=1, inplace=True)
# <ipython-input-14-67f52c50afac>:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...

# %%
KXIP_df = raw_df.loc[((raw_df['team1'] == 'Kings XI Punjab') | (raw_df['team2'] == 'Kings XI Punjab'))]
KXIP_df.drop(columns =['margin','man_of_the_match','winner','place'], axis=1, inplace=True)
KXIP_df.reset_index(inplace = True)
team_score = []
for i in range(len(KXIP_df)):
  if KXIP_df['team1'].values[i] == 'Kings XI Punjab':
    team_score.append(KXIP_df['team1_score'].values[i])
  else:
    team_score.append(KXIP_df['team2_score'].values[i])
KXIP_df.drop(columns =['team1_score','team2_score','index'], axis=1, inplace=True)
for i in range(len(KXIP_df)):
  if KXIP_df['toss_winner'].values[i] == 'Kings XI Punjab':
    KXIP_df['toss_winner'].values[i] = 1
  else:
    KXIP_df['toss_winner'].values[i] = 0
opponent_team = []
for i in range(len(KXIP_df)):
  if KXIP_df['team1'].values[i] != 'Kings XI Punjab':
    opponent_team.append(KXIP_df['team1'].values[i])
  else:
    opponent_team.append(KXIP_df['team2'].values[i])
KXIP_df['Opponent_Team'] = opponent_team
KXIP_df.drop(columns =['team1','team2'], axis=1, inplace=True)
KXIP_df['KXIP score'] = team_score
from sklearn.preprocessing import OneHotEncoder
encoder = OneHotEncoder()
one_hot_encoded = encoder.fit_transform(KXIP_df[['toss_choice']]).toarray()
KXIP_df = pd.concat([KXIP_df, pd.DataFrame(one_hot_encoded, columns=encoder.get_feature_names_out(['toss_choice']))], axis=1)
KXIP_df.drop(columns = ['toss_choice'], axis = 1, inplace = True)
from sklearn.preprocessing import OneHotEncoder
encoder = OneHotEncoder()
one_hot_encoded = encoder.fit_transform(KXIP_df[['Opponent_Team']]).toarray()
KXIP_df = pd.concat([KXIP_df, pd.DataFrame(one_hot_encoded, columns=encoder.get_feature_names_out(['Opponent_Team']))], axis=1)
KXIP_df.drop(columns = ['Opponent_Team'], axis = 1, inplace = True)
from sklearn.preprocessing import OneHotEncoder
encoder = OneHotEncoder()
one_hot_encoded = encoder.fit_transform(KXIP_df[['stadium']]).toarray()
KXIP_df = pd.concat([KXIP_df, pd.DataFrame(one_hot_encoded, columns=encoder.get_feature_names_out(['stadium']))], axis=1)
KXIP_df.drop(columns = ['stadium'], axis = 1, inplace = True)
# Out:
# <ipython-input-15-20b8ff72021e>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   KXIP_df.drop(columns =['margin','man_of_the_match','winner','place'], axis=1, inplace=True)
# <ipython-input-15-20b8ff72021e>:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   KXIP_df.drop(columns =['team1_score','team2_score','index'], axis=1, inplace=True)
# <ipython-input-15-20b8ff72021e>:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...

# %%
print(DC_df.to_string())

# %% [markdown]
# #Model building and training
#
# The dataset given is only for training. After training your model a testing dataset will be shared on which your model is expected to predict outputs.
#
# The task is to predict the winners of the matches given the two teams, venue, and toss_winner. Accordingly, you have to decide the parameters to be taken into consideration for training the model.
#
# The training dataset is IPL dataset for 2008-2021. A general practice while Training is splitting your dataset into training and validation datasets.
#
# You can use only numpy, build a linear/logistic regression from scratch and train it.
#
# An idea to get started is to fit a linear regressor to predict the score of both the teams and the team with greater score will win.
#
# You can come up with any other idea as well.
#
# For reference check this article https://medium.com/analytics-vidhya/simple-linear-regression-with-example-using-numpy-e7b984f0d15e
#
# Another reference article which you guys can look into:
#
#
# https://www.analyticsvidhya.com/blog/2021/10/building-an-ipl-score-predictor-end-to-end-ml-project/

# %%
weights = {}
biases = {}

# %%
import numpy as np
CSK_df.drop(columns = ['year '], axis = 1, inplace = True)
train_set_y_CSK = np.array(CSK_df['CSK score'])
CSK_df.drop(columns = ['CSK score'], axis = 1, inplace = True)

import numpy as np
RR_df.drop(columns = ['year '], axis = 1, inplace = True)
train_set_y_RR = np.array(RR_df['RR score'])
RR_df.drop(columns = ['RR score'], axis = 1, inplace = True)

import numpy as np
KXIP_df.drop(columns = ['year '], axis = 1, inplace = True)
train_set_y_KXIP = np.array(KXIP_df['KXIP score'])
KXIP_df.drop(columns = ['KXIP score'], axis = 1, inplace = True)

import numpy as np
KKR_df.drop(columns = ['year '], axis = 1, inplace = True)
train_set_y_KKR = np.array(KKR_df['KKR score'])
KKR_df.drop(columns = ['KKR score'], axis = 1, inplace = True)

import numpy as np
MI_df.drop(columns = ['year '], axis = 1, inplace = True)
train_set_y_MI = np.array(MI_df['MI score'])
MI_df.drop(columns = ['MI score'], axis = 1, inplace = True)

import numpy as np
DC_df.drop(columns = ['year '], axis = 1, inplace = True)
train_set_y_DC = np.array(DC_df['DC score'])
DC_df.drop(columns = ['DC score'], axis = 1, inplace = True)

import numpy as np
SRH_df.drop(columns = ['year '], axis = 1, inplace = True)
train_set_y_SRH = np.array(SRH_df['SRH score'])
SRH_df.drop(columns = ['SRH score'], axis = 1, inplace = True)

import numpy as np
RCB_df.drop(columns = ['year '], axis = 1, inplace = True)
train_set_y_RCB = np.array(RCB_df['RCB score'])
RCB_df.drop(columns = ['RCB score'], axis = 1, inplace = True)

# %%
lr = 0.001
train_set_x_KKR= KKR_df.values
train_set_y_KKR= np.reshape(train_set_y_KKR, (1, 161))
for i in train_set_x_KKR:
  mean = np.mean(i)
  i = i - mean
  std_dev = np.std(i)
  i = i / std_dev
w = np.random.randint(5,71,size=(1,36))
b = 120
for i in range(10000):
  k = np.dot(w,train_set_x_KKR.T) + b
  intermediate = k - train_set_y_KKR
  wgrad = 2*np.dot(train_set_x_KKR.T,intermediate.T)
  bgrad = 2*np.sum(intermediate)
  w = w - lr*wgrad.T
  b = b - lr*bgrad
  weights['KKR'] = w
  biases['KKR'] = b

# %%
lr = 0.001
train_set_x_CSK= CSK_df.values
train_set_y_CSK= np.reshape(train_set_y_CSK, (1, 152))
for i in train_set_x_CSK:
  mean = np.mean(i)
  i = i - mean
  std_dev = np.std(i)
  i = i / std_dev
w = np.random.randint(5,71,size=(1,37))
b = 120
for i in range(10000):
  k = np.dot(w,train_set_x_CSK.T) + b
  intermediate = k - train_set_y_CSK
  wgrad = 2*np.dot(train_set_x_CSK.T,intermediate.T)
  bgrad = 2*np.sum(intermediate)
  w = w - lr*wgrad.T
  b = b - lr*bgrad
  weights['CSK'] = w
  biases['CSK'] = b

# %%
lr = 0.001
train_set_x_RCB= RCB_df.values
train_set_y_RCB= np.reshape(train_set_y_RCB, (1, 150))
for i in train_set_x_RCB:
  mean = np.mean(i)
  i = i - mean
  std_dev = np.std(i)
  i = i / std_dev
w = np.random.randint(5,71,size=(1,35))
b = 120
for i in range(10000):
  k = np.dot(w,train_set_x_RCB.T) + b
  intermediate = k - train_set_y_RCB
  wgrad = 2*np.dot(train_set_x_RCB.T,intermediate.T)
  bgrad = 2*np.sum(intermediate)
  w = w - lr*wgrad.T
  b = b - lr*bgrad
  weights['RCB'] = w
  biases['RCB'] = b

# %%
lr = 0.001
train_set_x_SRH= SRH_df.values
train_set_y_SRH= np.reshape(train_set_y_SRH, (1, 102))
for i in train_set_x_SRH:
  mean = np.mean(i)
  i = i - mean
  std_dev = np.std(i)
  i = i / std_dev
w = np.random.randint(5,71,size=(1,29))
b = 120
for i in range(10000):
  k = np.dot(w,train_set_x_SRH.T) + b
  intermediate = k - train_set_y_SRH
  wgrad = 2*np.dot(train_set_x_SRH.T,intermediate.T)
  bgrad = 2*np.sum(intermediate)
  w = w - lr*wgrad.T
  b = b - lr*bgrad
  weights['SRH'] = w
  biases['SRH'] = b

# %%
lr = 0.001
train_set_x_MI= MI_df.values
train_set_y_MI= np.reshape(train_set_y_MI, (1, 172))
for i in train_set_x_MI:
  mean = np.mean(i)
  i = i - mean
  std_dev = np.std(i)
  i = i / std_dev
w = np.random.randint(5,71,size=(1,36))
b = 120
for i in range(10000):
  k = np.dot(w,train_set_x_MI.T) + b
  intermediate = k - train_set_y_MI
  wgrad = 2*np.dot(train_set_x_MI.T,intermediate.T)
  bgrad = 2*np.sum(intermediate)
  w = w - lr*wgrad.T
  b = b - lr*bgrad
  weights['MI'] = w
  biases['MI'] = b

# %%
lr = 0.001
train_set_x_KXIP= KXIP_df.values
train_set_y_KXIP= np.reshape(train_set_y_KXIP, (1, 154))
for i in train_set_x_KXIP:
  mean = np.mean(i)
  i = i - mean
  std_dev = np.std(i)
  i = i / std_dev
w = np.random.randint(5,71,size=(1,33))
b = 120
for i in range(10000):
  k = np.dot(w,train_set_x_KXIP.T) + b
  intermediate = k - train_set_y_KXIP
  wgrad = 2*np.dot(train_set_x_KXIP.T,intermediate.T)
  bgrad = 2*np.sum(intermediate)
  w = w - lr*wgrad.T
  b = b - lr*bgrad
  weights['KXIP'] = w
  biases['KXIP'] = b

# %%
lr = 0.001
train_set_x_DC= DC_df.values
train_set_y_DC= np.reshape(train_set_y_DC, (1, 151))
for i in train_set_x_DC:
  mean = np.mean(i)
  i = i - mean
  std_dev = np.std(i)
  i = i / std_dev
w = np.random.randint(5,71,size=(1,37))
b = 120
for i in range(10000):
  k = np.dot(w,train_set_x_DC.T) + b
  intermediate = k - train_set_y_DC
  wgrad = 2*np.dot(train_set_x_DC.T,intermediate.T)
  bgrad = 2*np.sum(intermediate)
  w = w - lr*wgrad.T
  b = b - lr*bgrad
  weights['DC'] = w
  biases['DC'] = b

# %%
lr = 0.001
train_set_x_RR= RR_df.values
train_set_y_RR= np.reshape(train_set_y_RR, (1,136))
for i in train_set_x_RR:
  mean = np.mean(i)
  i = i - mean
  std_dev = np.std(i)
  i = i / std_dev
w = np.random.randint(5,71,size=(1,34))
b = 120
for i in range(10000):
  k = np.dot(w,train_set_x_RR.T) + b
  intermediate = k - train_set_y_RR
  wgrad = 2*np.dot(train_set_x_RR.T,intermediate.T)
  bgrad = 2*np.sum(intermediate)
  w = w - lr*wgrad.T
  b = b - lr*bgrad
  weights['RR'] = w
  biases['RR'] = b

# %%
test_df = pd.read_csv('/content/Test_dataset.csv')

# %%
KXIP_params = {key: 0 for key in list(KXIP_df.columns)}
RCB_params = {key: 0 for key in list(RCB_df.columns)}
KKR_params = {key: 0 for key in list(KKR_df.columns)}
RR_params = {key: 0 for key in list(RR_df.columns)}
CSK_params = {key: 0 for key in list(CSK_df.columns)}
DC_params = {key: 0 for key in list(DC_df.columns)}
MI_params = {key: 0 for key in list(MI_df.columns)}
SRH_params = {key: 0 for key in list(SRH_df.columns)}

for index, row in test_df.iterrows():
  print(len(row['team1']), row['team2'])
  if row['team1'] == 'Punjab Kings' and row['team2'] == 'Royal Challengers Bangalore' or row['team2'] == 'Punjab Kings' and row['team1'] == 'Royal Challengers Bangalore':
    KXIP_params = {key: 0 for key in list(KXIP_df.columns)}
    RCB_params = {key: 0 for key in list(RCB_df.columns)}
    KXIP_params['Opponent_Team_Royal Challengers Bangalore'] = 1
    RCB_params['Opponent_Team_Kings XI Punjab'] = 1
    if row['toss_winner'] == 'Punjab Kings':
      KXIP_params['toss_winner'] = 1
      if row['toss_choice'] == 'Field':
        KXIP_params['toss_choice_Field'] = 1
        RCB_params['toss_choice_Bat'] = 1
      else:
        KXIP_params['toss_choice_Bat'] = 1
        RCB_params['toss_choice_Field'] = 1
    else:
      RCB_params['toss_winner'] = 1
      if row['toss_choice'] == 'Field':
        RCB_params['toss_choice_Field'] = 1
        KXIP_params['toss_choice_Bat'] = 1
      else:
        RCB_params['toss_choice_Bat'] = 1
        KXIP_params['toss_choice_Field'] = 1
    if 'stadium_' + str(row['stadium']) in RCB_params:
      RCB_params['stadium_' + str(row['stadium'])] = 1
    if 'stadium_' + str(row['stadium']) in KXIP_params:
      KXIP_params['stadium_'+ str(row['stadium'])] = 1
    KXIP_params = np.array(list(KXIP_params.values()))
    KXIP_params = np.reshape(KXIP_params, (len(KXIP_params),1))
    KXIP_score = np.dot(weights['KXIP'], KXIP_params) + biases['KXIP']
    print('KXIP_score:', KXIP_score)
    RCB_params = np.array(list(RCB_params.values()))
    RCB_params = np.reshape(RCB_params, (len(RCB_params),1))
    RCB_score = np.dot(weights['RCB'],RCB_params) + biases['RCB']
    print('RCB_score :', RCB_score)
    if RCB_score > KXIP_score:
      print('winner : RCB')
    else:
      print('winner : KXIP')
    print()

  elif row['team1'] == 'Punjab Kings' and row['team2'] == 'Chennai Super Kings' or row['team2'] == 'Punjab Kings' and row['team1'] == 'Chennai Super Kings':
    KXIP_params = {key: 0 for key in list(KXIP_df.columns)}
    CSK_params = {key: 0 for key in list(CSK_df.columns)}
    KXIP_params['Opponent_Team_Chennai Super Kings'] = 1
    CSK_params['Opponent_Team_Kings XI Punjab'] = 1
    if row['toss_winner'] == 'Punjab Kings':
      KXIP_params['toss_winner'] = 1
      if row['toss_choice'] == 'Field':
        KXIP_params['toss_choice_Field'] = 1
        CSK_params['toss_choice_Bat'] = 1
      else:
        KXIP_params['toss_choice_Bat'] = 1
        CSK_params['toss_choice_Field'] = 1
    else:
      CSK_params['toss_winner'] = 1
      if row['toss_choice'] == 'Field':
        CSK_params['toss_choice_Field'] = 1
        KXIP_params['toss_choice_Bat'] = 1
      else:
        CSK_params['toss_choice_Bat'] = 1
        KXIP_params['toss_choice_Field'] = 1
    if 'stadium_' + str(row['stadium']) in CSK_params:
      CSK_params['stadium_' + str(row['stadium'])] = 1
    if 'stadium_' + str(row['stadium']) in KXIP_params:
      KXIP_params['stadium_'+ str(row['stadium'])] = 1
    KXIP_params = np.array(list(KXIP_params.values()))
    KXIP_params = np.reshape(KXIP_params, (len(KXIP_params),1))
    KXIP_score = np.dot(weights['KXIP'], KXIP_params) + biases['KXIP']
    print('KXIP_score:', KXIP_score)
    CSK_params = np.array(list(CSK_params.values()))
    CSK_params = np.reshape(CSK_params, (len(CSK_params),1))
    CSK_score = np.dot(weights['CSK'],CSK_params) + biases['CSK']
    print('CSK_score :', CSK_score)
    if CSK_score > KXIP_score:
      print('winner : CSK')
    else:
      print('winner : KXIP')
    print()
    
  elif row['team1'] == 'Punjab Kings' and row['team2'] == 'Mumbai Indians' or row['team2'] == 'Punjab Kings' and row['team1'] == 'Mumbai Indians':
    KXIP_params = {key: 0 for key in list(KXIP_df.columns)}
    MI_params = {key: 0 for key in list(MI_df.columns)}
    KXIP_params['Opponent_Team_Mumbai Indians'] = 1
    MI_params['Opponent_Team_Kings XI Punjab'] = 1
    if row['toss_winner'] == 'Punjab Kings':
      KXIP_params['toss_winner'] = 1
      if row['toss_choice'] == 'Field':
        KXIP_params['toss_choice_Field'] = 1
        MI_params['toss_choice_Bat'] = 1
      else:
        KXIP_params['toss_choice_Bat'] = 1
        MI_params['toss_choice_Field'] = 1
    else:
      MI_params['toss_winner'] = 1
      if row['toss_choice'] == 'Field':
        MI_params['toss_choice_Field'] = 1
        KXIP_params['toss_choice_Bat'] = 1
      else:
        MI_params['toss_choice_Bat'] = 1
        KXIP_params['toss_choice_Field'] = 1
    if 'stadium_' + str(row['stadium']) in MI_params:
      MI_params['stadium_' + str(row['stadium'])] = 1
    if 'stadium_' + str(row['stadium']) in KXIP_params:
      KXIP_params['stadium_'+ str(row['stadium'])] = 1
    KXIP_params = np.array(list(KXIP_params.values()))
    KXIP_params = np.reshape(KXIP_params, (len(KXIP_params),1))
    KXIP_score = np.dot(weights['KXIP'], KXIP_params) + biases['KXIP']
    print('KXIP_score:', KXIP_score)
    MI_params = np.array(list(MI_params.values()))
    MI_params = np.reshape(MI_params, (len(MI_params),1))
    MI_score = np.dot(weights['MI'],MI_params) + biases['MI']
    print('MI_score :', MI_score)
    if MI_score > KXIP_score:
      print('winner : MI')
    else:
      print('winner : KXIP')
    print()

  elif row['team1'] == 'Punjab Kings' and row['team2'] == 'Sunrisers Hyderabad' or row['team2'] == 'Punjab Kings' and row['team1'] == 'Sunrisers Hyderabad':
    KXIP_params = {key: 0 for key in list(KXIP_df.columns)}
    SRH_params = {key: 0 for key in list(SRH_df.columns)}
    KXIP_params['Opponent_Team_Sunrisers Hyderabad'] = 1
    SRH_params['Opponent_Team_Kings XI Punjab'] = 1
    if row['toss_winner'] == 'Punjab Kings':
      KXIP_params['toss_winner'] = 1
      if row['toss_choice'] == 'Field':
        KXIP_params['toss_choice_Field'] = 1
        SRH_params['toss_choice_Bat'] = 1
      else:
        KXIP_params['toss_choice_Bat'] = 1
        SRH_params['toss_choice_Field'] = 1
    else:
      SRH_params['toss_winner'] = 1
      if row['toss_choice'] == 'Field':
        SRH_params['toss_choice_Field'] = 1
        KXIP_params['toss_choice_Bat'] = 1
      else:
        SRH_params['toss_choice_Bat'] = 1
        KXIP_params['toss_choice_Field'] = 1
    if 'stadium_' + str(row['stadium']) in SRH_params:
      SRH_params['stadium_' + str(row['stadium'])] = 1
    if 'stadium_' + str(row['stadium']) in KXIP_params:
      KXIP_params['stadium_'+ str(row['stadium'])] = 1
    KXIP_params = np.array(list(KXIP_params.values()))
    KXIP_params = np.reshape(KXIP_params, (len(KXIP_params),1))
    KXIP_score = np.dot(weights['KXIP'], KXIP_params) + biases['KXIP']
    print('KXIP_score:', KXIP_score)
    SRH_params = np.array(list(SRH_params.values()))
    SRH_params = np.reshape(SRH_params, (len(SRH_params),1))
    SRH_score = np.dot(weights['SRH'],SRH_params) + biases['SRH']
    print('SRH_score :', SRH_score)
    if SRH_score > KXIP_score:
      print('winner : SRH')
    else:
      print('winner : KXIP')
    print()

  elif row['team1'] == 'Punjab Kings' and row['team2'] == 'Delhi Capitals' or row['team2'] == 'Punjab Kings' and row['team1'] == 'Delhi Capitals':
    KXIP_params = {key: 0 for key in list(KXIP_df.columns)}
    DC_params = {key: 0 for key in list(DC_df.columns)}
    KXIP_params['Opponent_Team_Delhi Capitals'] = 1
    DC_params['Opponent_Team_Kings XI Punjab'] = 1
    if row['toss_winner'] == 'Punjab Kings':
      KXIP_params['toss_winner'] = 1
      if row['toss_choice'] == 'Field':
        KXIP_params['toss_choice_Field'] = 1
        DC_params['toss_choice_Bat'] = 1
      else:
        KXIP_params['toss_choice_Bat'] = 1
        DC_params['toss_choice_Field'] = 1
    else:
      DC_params['toss_winner'] = 1
      if row['toss_choice'] == 'Field':
        DC_params['toss_choice_Field'] = 1
        KXIP_params['toss_choice_Bat'] = 1
      else:
        DC_params['toss_choice_Bat'] = 1
        KXIP_params['toss_choice_Field'] = 1
    if 'stadium_' + str(row['stadium']) in DC_params:
      DC_params['stadium_' + str(row['stadium'])] = 1
    if 'stadium_' + str(row['stadium']) in KXIP_params:
      KXIP_params['stadium_'+ str(row['stadium'])] = 1
    KXIP_params = np.array(list(KXIP_params.values()))
    KXIP_params = np.reshape(KXIP_params, (len(KXIP_params),1))
    KXIP_score = np.dot(weights['KXIP'], KXIP_params) + biases['KXIP']
    print('KXIP_score:', KXIP_score)
    DC_params = np.array(list(DC_params.values()))
    DC_params = np.reshape(DC_params, (len(DC_params),1))
    DC_score = np.dot(weights['DC'],DC_params) + biases['DC']
    print('DC_score :', DC_score)
    if DC_score > KXIP_score:
      print('winner : DC')
    else:
      print('winner : KXIP')
    print()

  elif row['team1'] == 'Punjab Kings' and row['team2'] == 'Kolkata Knight Riders' or row['team2'] == 'Punjab Kings' and row['team1'] == 'Kolkata Knight Riders':
    KXIP_params = {key: 0 for key in list(KXIP_df.columns)}
    KKR_params = {key: 0 for key in list(KKR_df.columns)}
    KXIP_params['Opponent_Team_Kolkata Knight Riders'] = 1
    KKR_params['Opponent_Team_Kings XI Punjab'] = 1
    if row['toss_winner'] == 'Punjab Kings':
      KXIP_params['toss_winner'] = 1
      if row['toss_choice'] == 'Field':
        KXIP_params['toss_choice_Field'] = 1
        KKR_params['toss_choice_Bat'] = 1
      else:
        KXIP_params['toss_choice_Bat'] = 1
        KKR_params['toss_choice_Field'] = 1
    else:
      KKR_params['toss_winner'] = 1
      if row['toss_choice'] == 'Field':
        KKR_params['toss_choice_Field'] = 1
        KXIP_params['toss_choice_Bat'] = 1
      else:
        KKR_params['toss_choice_Bat'] = 1
        KXIP_params['toss_choice_Field'] = 1
    if 'stadium_' + str(row['stadium']) in KKR_params:
      KKR_params['stadium_' + str(row['stadium'])] = 1
    if 'stadium_' + str(row['stadium']) in KXIP_params:
      KXIP_params['stadium_'+ str(row['stadium'])] = 1
    KXIP_params = np.array(list(KXIP_params.values()))
    KXIP_params = np.reshape(KXIP_params, (len(KXIP_params),1))
    KXIP_score = np.dot(weights['KXIP'], KXIP_params) + biases['KXIP']
    print('KXIP_score:', KXIP_score)
    KKR_params = np.array(list(KKR_params.values()))
    KKR_params = np.reshape(KKR_params, (len(KKR_params),1))
    KKR_score = np.dot(weights['KKR'],KKR_params) + biases['KKR']
    print('KKR_score :', KKR_score)
    if KKR_score > KXIP_score:
      print('winner : KKR')
    else:
      print('winner : KXIP')
    print()

  elif row['team1'] == 'Punjab Kings' and row['team2'] == 'Rajasthan Royals' or row['team2'] == 'Punjab Kings' and row['team1'] == 'Rajasthan Royals':
    KXIP_params = {key: 0 for key in list(KXIP_df.columns)}
    RR_params = {key: 0 for key in list(RR_df.columns)}
    KXIP_params['Opponent_Team_Rajasthan Royals'] = 1
    RR_params['Opponent_Team_Kings XI Punjab'] = 1
    if row['toss_winner'] == 'Punjab Kings':
      KXIP_params['toss_winner'] = 1
      if row['toss_choice'] == 'Field':
        KXIP_params['toss_choice_Field'] = 1
        RR_params['toss_choice_Bat'] = 1
      else:
        KXIP_params['toss_choice_Bat'] = 1
        RR_params['toss_choice_Field'] = 1
    else:
      RR_params['toss_winner'] = 1
      if row['toss_choice'] == 'Field':
        RR_params['toss_choice_Field'] = 1
        KXIP_params['toss_choice_Bat'] = 1
      else:
        RR_params['toss_choice_Bat'] = 1
        KXIP_params['toss_choice_Field'] = 1
    if 'stadium_' + str(row['stadium']) in RR_params:
      RR_params['stadium_' + str(row['stadium'])] = 1
    if 'stadium_' + str(row['stadium']) in KXIP_params:
      KXIP_params['stadium_'+ str(row['stadium'])] = 1
    KXIP_params = np.array(list(KXIP_params.values()))
    KXIP_params = np.reshape(KXIP_params, (len(KXIP_params),1))
    KXIP_score = np.dot(weights['KXIP'], KXIP_params) + biases['KXIP']
    print('KXIP_score:', KXIP_score)
    RR_params = np.array(list(RR_params.values()))
    RR_params = np.reshape(RR_params, (len(RR_params),1))
    RR_score = np.dot(weights['RR'],RR_params) + biases['RR']
    print('RR_score :', RR_score)
    if RR_score > KXIP_score:
      print('winner : RR')
    else:
      print('winner : KXIP')
    print()

  elif row['team1'] == 'Chennai Super Kings' and row['team2'] == 'Rajasthan Royals' or row['team2'] == 'Chennai Super Kings' and row['team1'] == 'Rajasthan Royals':
    CSK_params = {key: 0 for key in list(CSK_df.columns)}
    RR_params = {key: 0 for key in list(RR_df.columns)}
    CSK_params['Opponent_Team_Rajasthan Royals'] = 1
    RR_params['Opponent_Team_Kings XI Punjab'] = 1
    if row['toss_winner'] == 'Chennai Super Kings':
      CSK_params['toss_winner'] = 1
      if row['toss_choice'] == 'Field':
        CSK_params['toss_choice_Field'] = 1
        RR_params['toss_choice_Bat'] = 1
      else:
        CSK_params['toss_choice_Bat'] = 1
        RR_params['toss_choice_Field'] = 1
    else:
      RR_params['toss_winner'] = 1
      if row['toss_choice'] == 'Field':
        RR_params['toss_choice_Field'] = 1
        CSK_params['toss_choice_Bat'] = 1
      else:
        RR_params['toss_choice_Bat'] = 1
        CSK_params['toss_choice_Field'] = 1
    if 'stadium_' + str(row['stadium']) in RR_params:
      RR_params['stadium_' + str(row['stadium'])] = 1
    if 'stadium_' + str(row['stadium']) in CSK_params:
      CSK_params['stadium_'+ str(row['stadium'])] = 1
    CSK_params = np.array(list(CSK_params.values()))
    CSK_params = np.reshape(CSK_params, (len(CSK_params),1))
    CSK_score = np.dot(weights['CSK'], CSK_params) + biases['CSK']
    print('CSK_score:', CSK_score)
    RR_params = np.array(list(RR_params.values()))
    RR_params = np.reshape(RR_params, (len(RR_params),1))
    RR_score = np.dot(weights['RR'],RR_params) + biases['RR']
    print('RR_score :', RR_score)
    if RR_score > CSK_score:
      print('winner : RR')
    else:
      print('winner : CSK')
    print()

  elif row['team1'] == 'Mumbai Indians' and row['team2'] == 'Rajasthan Royals' or row['team2'] == 'Mumbai Indians' and row['team1'] == 'Rajasthan Royals':
    MI_params = {key: 0 for key in list(MI_df.columns)}
    RR_params = {key: 0 for key in list(RR_df.columns)}
    MI_params['Opponent_Team_Rajasthan Royals'] = 1
    RR_params['Opponent_Team_Kings XI Punjab'] = 1
    if row['toss_winner'] == 'Mumbai Indians':
      MI_params['toss_winner'] = 1
      if row['toss_choice'] == 'Field':
        MI_params['toss_choice_Field'] = 1
        RR_params['toss_choice_Bat'] = 1
      else:
        MI_params['toss_choice_Bat'] = 1
        RR_params['toss_choice_Field'] = 1
    else:
      RR_params['toss_winner'] = 1
      if row['toss_choice'] == 'Field':
        RR_params['toss_choice_Field'] = 1
        MI_params['toss_choice_Bat'] = 1
      else:
        RR_params['toss_choice_Bat'] = 1
        MI_params['toss_choice_Field'] = 1
    if 'stadium_' + str(row['stadium']) in RR_params:
      RR_params['stadium_' + str(row['stadium'])] = 1
    if 'stadium_' + str(row['stadium']) in MI_params:
      MI_params['stadium_'+ str(row['stadium'])] = 1
    MI_params = np.array(list(MI_params.values()))
    MI_params = np.reshape(MI_params, (len(MI_params),1))
    MI_score = np.dot(weights['MI'], MI_params) + biases['MI']
    print('MI_score:', MI_score)
    RR_params = np.array(list(RR_params.values()))
    RR_params = np.reshape(RR_params, (len(RR_params),1))
    RR_score = np.dot(weights['RR'],RR_params) + biases['RR']
    print('RR_score :', RR_score)
    if RR_score > MI_score:
      print('winner : RR')
    else:
      print('winner : MI')
    print()

  elif row['team1'] == 'Royal Challengers Bangalore' and row['team2'] == 'Rajasthan Royals' or row['team2'] == 'Royal Challengers Bangalore' and row['team1'] == 'Rajasthan Royals':
    RCB_params = {key: 0 for key in list(RCB_df.columns)}
    RR_params = {key: 0 for key in list(RR_df.columns)}
    RCB_params['Opponent_Team_Rajasthan Royals'] = 1
    RR_params['Opponent_Team_Kings XI Punjab'] = 1
    if row['toss_winner'] == 'Royal Challengers Bangalore':
      RCB_params['toss_winner'] = 1
      if row['toss_choice'] == 'Field':
        RCB_params['toss_choice_Field'] = 1
        RR_params['toss_choice_Bat'] = 1
      else:
        RCB_params['toss_choice_Bat'] = 1
        RR_params['toss_choice_Field'] = 1
    else:
      RR_params['toss_winner'] = 1
      if row['toss_choice'] == 'Field':
        RR_params['toss_choice_Field'] = 1
        RCB_params['toss_choice_Bat'] = 1
      else:
        RR_params['toss_choice_Bat'] = 1
        RCB_params['toss_choice_Field'] = 1
    if 'stadium_' + str(row['stadium']) in RR_params:
      RR_params['stadium_' + str(row['stadium'])] = 1
    if 'stadium_' + str(row['stadium']) in RCB_params:
      RCB_params['stadium_'+ str(row['stadium'])] = 1
    RCB_params = np.array(list(RCB_params.values()))
    RCB_params = np.reshape(RCB_params, (len(RCB_params),1))
    RCB_score = np.dot(weights['RCB'], RCB_params) + biases['RCB']
    print('RCB_score:', RCB_score)
    RR_params = np.array(list(RR_params.values()))
    RR_params = np.reshape(RR_params, (len(RR_params),1))
    RR_score = np.dot(weights['RR'],RR_params) + biases['RR']
    print('RR_score :', RR_score)
    if RR_score > RCB_score:
      print('winner : RR')
    else:
      print('winner : RCB')
    print()

  elif row['team1'] == 'Kolkata Knight Riders' and row['team2'] == 'Rajasthan Royals' or row['team2'] == 'Kolkata Knight Riders' and row['team1'] == 'Rajasthan Royals':
    KKR_params = {key: 0 for key in list(KKR_df.columns)}
    RR_params = {key: 0 for key in list(RR_df.columns)}
    KKR_params['Opponent_Team_Rajasthan Royals'] = 1
    RR_params['Opponent_Team_Kings XI Punjab'] = 1
    if row['toss_winner'] == 'Kolkata Knight Riders':
      KKR_params['toss_winner'] = 1
      if row['toss_choice'] == 'Field':
        KKR_params['toss_choice_Field'] = 1
        RR_params['toss_choice_Bat'] = 1
      else:
        KKR_params['toss_choice_Bat'] = 1
        RR_params['toss_choice_Field'] = 1
    else:
      RR_params['toss_winner'] = 1
      if row['toss_choice'] == 'Field':
        RR_params['toss_choice_Field'] = 1
        KKR_params['toss_choice_Bat'] = 1
      else:
        RR_params['toss_choice_Bat'] = 1
        KKR_params['toss_choice_Field'] = 1
    if 'stadium_' + str(row['stadium']) in RR_params:
      RR_params['stadium_' + str(row['stadium'])] = 1
    if 'stadium_' + str(row['stadium']) in KKR_params:
      KKR_params['stadium_'+ str(row['stadium'])] = 1
    KKR_params = np.array(list(KKR_params.values()))
    KKR_params = np.reshape(KKR_params, (len(KKR_params),1))
    KKR_score = np.dot(weights['KKR'], KKR_params) + biases['KKR']
    print('KKR_score:', KKR_score)
    RR_params = np.array(list(RR_params.values()))
    RR_params = np.reshape(RR_params, (len(RR_params),1))
    RR_score = np.dot(weights['RR'],RR_params) + biases['RR']
    print('RR_score :', RR_score)
    if RR_score > KKR_score:
      print('winner : RR')
    else:
      print('winner : KKR')
    print()

  elif row['team1'] == 'Sunrisers Hyderabad' and row['team2'] == 'Rajasthan Royals' or row['team2'] == 'Sunrisers Hyderabad' and row['team1'] == 'Rajasthan Royals':
    SRH_params = {key: 0 for key in list(SRH_df.columns)}
    RR_params = {key: 0 for key in list(RR_df.columns)}
    SRH_params['Opponent_Team_Rajasthan Royals'] = 1
    RR_params['Opponent_Team_Kings XI Punjab'] = 1
    if row['toss_winner'] == 'Sunrisers Hyderabad':
      SRH_params['toss_winner'] = 1
      if row['toss_choice'] == 'Field':
        SRH_params['toss_choice_Field'] = 1
        RR_params['toss_choice_Bat'] = 1
      else:
        SRH_params['toss_choice_Bat'] = 1
        RR_params['toss_choice_Field'] = 1
    else:
      RR_params['toss_winner'] = 1
      if row['toss_choice'] == 'Field':
        RR_params['toss_choice_Field'] = 1
        SRH_params['toss_choice_Bat'] = 1
      else:
        RR_params['toss_choice_Bat'] = 1
        SRH_params['toss_choice_Field'] = 1
    if 'stadium_' + str(row['stadium']) in RR_params:
      RR_params['stadium_' + str(row['stadium'])] = 1
    if 'stadium_' + str(row['stadium']) in SRH_params:
      SRH_params['stadium_'+ str(row['stadium'])] = 1
    SRH_params = np.array(list(SRH_params.values()))
    SRH_params = np.reshape(SRH_params, (len(SRH_params),1))
    SRH_score = np.dot(weights['SRH'], SRH_params) + biases['SRH']
    print('SRH_score:', SRH_score)
    RR_params = np.array(list(RR_params.values()))
    RR_params = np.reshape(RR_params, (len(RR_params),1))
    RR_score = np.dot(weights['RR'],RR_params) + biases['RR']
    print('RR_score :', RR_score)
    if RR_score > SRH_score:
      print('winner : RR')
    else:
      print('winner : SRH')
    print()

  elif row['team1'] == 'Delhi Capitals' and row['team2'] == 'Rajasthan Royals' or row['team2'] == 'Delhi Capitals' and row['team1'] == 'Rajasthan Royals':
    DC_params = {key: 0 for key in list(DC_df.columns)}
    RR_params = {key: 0 for key in list(RR_df.columns)}
    DC_params['Opponent_Team_Rajasthan Royals'] = 1
    RR_params['Opponent_Team_Kings XI Punjab'] = 1
    if row['toss_winner'] == 'Delhi Capitals':
      DC_params['toss_winner'] = 1
      if row['toss_choice'] == 'Field':
        DC_params['toss_choice_Field'] = 1
        RR_params['toss_choice_Bat'] = 1
      else:
        DC_params['toss_choice_Bat'] = 1
        RR_params['toss_choice_Field'] = 1
    else:
      RR_params['toss_winner'] = 1
      if row['toss_choice'] == 'Field':
        RR_params['toss_choice_Field'] = 1
        DC_params['toss_choice_Bat'] = 1
      else:
        RR_params['toss_choice_Bat'] = 1
        DC_params['toss_choice_Field'] = 1
    if 'stadium_' + str(row['stadium']) in RR_params:
      RR_params['stadium_' + str(row['stadium'])] = 1
    if 'stadium_' + str(row['stadium']) in DC_params:
      DC_params['stadium_'+ str(row['stadium'])] = 1
    DC_params = np.array(list(DC_params.values()))
    DC_params = np.reshape(DC_params, (len(DC_params),1))
    DC_score = np.dot(weights['DC'], DC_params) + biases['DC']
    print('DC_score:', DC_score)
    RR_params = np.array(list(RR_params.values()))
    RR_params = np.reshape(RR_params, (len(RR_params),1))
    RR_score = np.dot(weights['RR'],RR_params) + biases['RR']
    print('RR_score :', RR_score)
    if RR_score > DC_score:
      print('winner : RR')
    else:
      print('winner : DC')
    print()

  elif row['team1'] == 'Delhi Capitals' and row['team2'] == 'Chennai Super Kings' or row['team2'] == 'Delhi Capitals' and row['team1'] == 'Chennai Super Kings':
    DC_params = {key: 0 for key in list(DC_df.columns)}
    CSK_params = {key: 0 for key in list(CSK_df.columns)}
    DC_params['Opponent_Team_Chennai Super Kings'] = 1
    CSK_params['Opponent_Team_Kings XI Punjab'] = 1
    if row['toss_winner'] == 'Delhi Capitals':
      DC_params['toss_winner'] = 1
      if row['toss_choice'] == 'Field':
        DC_params['toss_choice_Field'] = 1
        CSK_params['toss_choice_Bat'] = 1
      else:
        DC_params['toss_choice_Bat'] = 1
        CSK_params['toss_choice_Field'] = 1
    else:
      CSK_params['toss_winner'] = 1
      if row['toss_choice'] == 'Field':
        CSK_params['toss_choice_Field'] = 1
        DC_params['toss_choice_Bat'] = 1
      else:
        CSK_params['toss_choice_Bat'] = 1
        DC_params['toss_choice_Field'] = 1
    if 'stadium_' + str(row['stadium']) in CSK_params:
      CSK_params['stadium_' + str(row['stadium'])] = 1
    if 'stadium_' + str(row['stadium']) in DC_params:
      DC_params['stadium_'+ str(row['stadium'])] = 1
    DC_params = np.array(list(DC_params.values()))
    DC_params = np.reshape(DC_params, (len(DC_params),1))
    DC_score = np.dot(weights['DC'], DC_params) + biases['DC']
    print('DC_score:', DC_score)
    CSK_params = np.array(list(CSK_params.values()))
    CSK_params = np.reshape(CSK_params, (len(CSK_params),1))
    CSK_score = np.dot(weights['CSK'],CSK_params) + biases['CSK']
    print('CSK_score :', CSK_score)
    if CSK_score > DC_score:
      print('winner : CSK')
    else:
      print('winner : DC')
    print()

  elif row['team1'] == 'Delhi Capitals' and row['team2'] == 'Mumbai Indians' or row['team2'] == 'Delhi Capitals' and row['team1'] == 'Mumbai Indians':
    DC_params = {key: 0 for key in list(DC_df.columns)}
    MI_params = {key: 0 for key in list(MI_df.columns)}
    DC_params['Opponent_Team_Mumbai Indians'] = 1
    MI_params['Opponent_Team_Kings XI Punjab'] = 1
    if row['toss_winner'] == 'Delhi Capitals':
      DC_params['toss_winner'] = 1
      if row['toss_choice'] == 'Field':
        DC_params['toss_choice_Field'] = 1
        MI_params['toss_choice_Bat'] = 1
      else:
        DC_params['toss_choice_Bat'] = 1
        MI_params['toss_choice_Field'] = 1
    else:
      MI_params['toss_winner'] = 1
      if row['toss_choice'] == 'Field':
        MI_params['toss_choice_Field'] = 1
        DC_params['toss_choice_Bat'] = 1
      else:
        MI_params['toss_choice_Bat'] = 1
        DC_params['toss_choice_Field'] = 1
    if 'stadium_' + str(row['stadium']) in MI_params:
      MI_params['stadium_' + str(row['stadium'])] = 1
    if 'stadium_' + str(row['stadium']) in DC_params:
      DC_params['stadium_'+ str(row['stadium'])] = 1
    DC_params = np.array(list(DC_params.values()))
    DC_params = np.reshape(DC_params, (len(DC_params),1))
    DC_score = np.dot(weights['DC'], DC_params) + biases['DC']
    print('DC_score:', DC_score)
    MI_params = np.array(list(MI_params.values()))
    MI_params = np.reshape(MI_params, (len(MI_params),1))
    MI_score = np.dot(weights['MI'],MI_params) + biases['MI']
    print('MI_score :', MI_score)
    if MI_score > DC_score:
      print('winner : MI')
    else:
      print('winner : DC')
    print()

  elif row['team1'] == 'Delhi Capitals' and row['team2'] == 'Kolkata Knight Riders' or row['team2'] == 'Delhi Capitals' and row['team1'] == 'Kolkata Knight Riders':
    DC_params = {key: 0 for key in list(DC_df.columns)}
    KKR_params = {key: 0 for key in list(KKR_df.columns)}
    DC_params['Opponent_Team_Kolkata Knight Riders'] = 1
    KKR_params['Opponent_Team_Kings XI Punjab'] = 1
    if row['toss_winner'] == 'Delhi Capitals':
      DC_params['toss_winner'] = 1
      if row['toss_choice'] == 'Field':
        DC_params['toss_choice_Field'] = 1
        KKR_params['toss_choice_Bat'] = 1
      else:
        DC_params['toss_choice_Bat'] = 1
        KKR_params['toss_choice_Field'] = 1
    else:
      KKR_params['toss_winner'] = 1
      if row['toss_choice'] == 'Field':
        KKR_params['toss_choice_Field'] = 1
        DC_params['toss_choice_Bat'] = 1
      else:
        KKR_params['toss_choice_Bat'] = 1
        DC_params['toss_choice_Field'] = 1
    if 'stadium_' + str(row['stadium']) in KKR_params:
      KKR_params['stadium_' + str(row['stadium'])] = 1
    if 'stadium_' + str(row['stadium']) in DC_params:
      DC_params['stadium_'+ str(row['stadium'])] = 1
    DC_params = np.array(list(DC_params.values()))
    DC_params = np.reshape(DC_params, (len(DC_params),1))
    DC_score = np.dot(weights['DC'], DC_params) + biases['DC']
    print('DC_score:', DC_score)
    KKR_params = np.array(list(KKR_params.values()))
    KKR_params = np.reshape(KKR_params, (len(KKR_params),1))
    KKR_score = np.dot(weights['KKR'],KKR_params) + biases['KKR']
    print('KKR_score :', KKR_score)
    if KKR_score > DC_score:
      print('winner : KKR')
    else:
      print('winner : DC')
    print()

  elif row['team1'] == 'Delhi Capitals' and row['team2'] == 'Royal Challengers Bangalore' or row['team2'] == 'Delhi Capitals' and row['team1'] == 'Royal Challengers Bangalore':
    DC_params = {key: 0 for key in list(DC_df.columns)}
    RCB_params = {key: 0 for key in list(RCB_df.columns)}
    DC_params['Opponent_Team_Royal Challengers Bangalore'] = 1
    RCB_params['Opponent_Team_Kings XI Punjab'] = 1
    if row['toss_winner'] == 'Delhi Capitals':
      DC_params['toss_winner'] = 1
      if row['toss_choice'] == 'Field':
        DC_params['toss_choice_Field'] = 1
        RCB_params['toss_choice_Bat'] = 1
      else:
        DC_params['toss_choice_Bat'] = 1
        RCB_params['toss_choice_Field'] = 1
    else:
      RCB_params['toss_winner'] = 1
      if row['toss_choice'] == 'Field':
        RCB_params['toss_choice_Field'] = 1
        DC_params['toss_choice_Bat'] = 1
      else:
        RCB_params['toss_choice_Bat'] = 1
        DC_params['toss_choice_Field'] = 1
    if 'stadium_' + str(row['stadium']) in RCB_params:
      RCB_params['stadium_' + str(row['stadium'])] = 1
    if 'stadium_' + str(row['stadium']) in DC_params:
      DC_params['stadium_'+ str(row['stadium'])] = 1
    DC_params = np.array(list(DC_params.values()))
    DC_params = np.reshape(DC_params, (len(DC_params),1))
    DC_score = np.dot(weights['DC'], DC_params) + biases['DC']
    print('DC_score:', DC_score)
    RCB_params = np.array(list(RCB_params.values()))
    RCB_params = np.reshape(RCB_params, (len(RCB_params),1))
    RCB_score = np.dot(weights['RCB'],RCB_params) + biases['RCB']
    print('RCB_score :', RCB_score)
    if RCB_score > DC_score:
      print('winner : RCB')
    else:
      print('winner : DC')
    print()

  elif row['team1'] == 'Delhi Capitals' and row['team2'] == 'Sunrisers Hyderabad' or row['team2'] == 'Delhi Capitals' and row['team1'] == 'Sunrisers Hyderabad':
    DC_params = {key: 0 for key in list(DC_df.columns)}
    SRH_params = {key: 0 for key in list(SRH_df.columns)}
    DC_params['Opponent_Team_Sunrisers Hyderabad'] = 1
    SRH_params['Opponent_Team_Kings XI Punjab'] = 1
    if row['toss_winner'] == 'Delhi Capitals':
      DC_params['toss_winner'] = 1
      if row['toss_choice'] == 'Field':
        DC_params['toss_choice_Field'] = 1
        SRH_params['toss_choice_Bat'] = 1
      else:
        DC_params['toss_choice_Bat'] = 1
        SRH_params['toss_choice_Field'] = 1
    else:
      SRH_params['toss_winner'] = 1
      if row['toss_choice'] == 'Field':
        SRH_params['toss_choice_Field'] = 1
        DC_params['toss_choice_Bat'] = 1
      else:
        SRH_params['toss_choice_Bat'] = 1
        DC_params['toss_choice_Field'] = 1
    if 'stadium_' + str(row['stadium']) in SRH_params:
      SRH_params['stadium_' + str(row['stadium'])] = 1
    if 'stadium_' + str(row['stadium']) in DC_params:
      DC_params['stadium_'+ str(row['stadium'])] = 1
    DC_params = np.array(list(DC_params.values()))
    DC_params = np.reshape(DC_params, (len(DC_params),1))
    DC_score = np.dot(weights['DC'], DC_params) + biases['DC']
    print('DC_score:', DC_score)
    SRH_params = np.array(list(SRH_params.values()))
    SRH_params = np.reshape(SRH_params, (len(SRH_params),1))
    SRH_score = np.dot(weights['SRH'],SRH_params) + biases['SRH']
    print('SRH_score :', SRH_score)
    if SRH_score > DC_score:
      print('winner : SRH')
    else:
      print('winner : DC')
    print()

  elif row['team1'] == 'Chennai Super Kings' and row['team2'] == 'Sunrisers Hyderabad' or row['team2'] == 'Chennai Super Kings' and row['team1'] == 'Sunrisers Hyderabad':
    CSK_params = {key: 0 for key in list(CSK_df.columns)}
    SRH_params = {key: 0 for key in list(SRH_df.columns)}
    CSK_params['Opponent_Team_Sunrisers Hyderabad'] = 1
    SRH_params['Opponent_Team_Kings XI Punjab'] = 1
    if row['toss_winner'] == 'Chennai Super Kings':
      CSK_params['toss_winner'] = 1
      if row['toss_choice'] == 'Field':
        CSK_params['toss_choice_Field'] = 1
        SRH_params['toss_choice_Bat'] = 1
      else:
        CSK_params['toss_choice_Bat'] = 1
        SRH_params['toss_choice_Field'] = 1
    else:
      SRH_params['toss_winner'] = 1
      if row['toss_choice'] == 'Field':
        SRH_params['toss_choice_Field'] = 1
        CSK_params['toss_choice_Bat'] = 1
      else:
        SRH_params['toss_choice_Bat'] = 1
        CSK_params['toss_choice_Field'] = 1
    if 'stadium_' + str(row['stadium']) in SRH_params:
      SRH_params['stadium_' + str(row['stadium'])] = 1
    if 'stadium_' + str(row['stadium']) in CSK_params:
      CSK_params['stadium_'+ str(row['stadium'])] = 1
    CSK_params = np.array(list(CSK_params.values()))
    CSK_params = np.reshape(CSK_params, (len(CSK_params),1))
    CSK_score = np.dot(weights['CSK'], CSK_params) + biases['CSK']
    print('CSK_score:', CSK_score)
    SRH_params = np.array(list(SRH_params.values()))
    SRH_params = np.reshape(SRH_params, (len(SRH_params),1))
    SRH_score = np.dot(weights['SRH'],SRH_params) + biases['SRH']
    print('SRH_score :', SRH_score)
    if SRH_score > CSK_score:
      print('winner : SRH')
    else:
      print('winner : CSK')
    print()

  elif row['team1'] == 'Mumbai Indians' and row['team2'] == 'Sunrisers Hyderabad' or row['team2'] == 'Mumbai Indians' and row['team1'] == 'Sunrisers Hyderabad':
    MI_params = {key: 0 for key in list(MI_df.columns)}
    SRH_params = {key: 0 for key in list(SRH_df.columns)}
    MI_params['Opponent_Team_Sunrisers Hyderabad'] = 1
    SRH_params['Opponent_Team_Kings XI Punjab'] = 1
    if row['toss_winner'] == 'Mumbai Indians':
      MI_params['toss_winner'] = 1
      if row['toss_choice'] == 'Field':
        MI_params['toss_choice_Field'] = 1
        SRH_params['toss_choice_Bat'] = 1
      else:
        MI_params['toss_choice_Bat'] = 1
        SRH_params['toss_choice_Field'] = 1
    else:
      SRH_params['toss_winner'] = 1
      if row['toss_choice'] == 'Field':
        SRH_params['toss_choice_Field'] = 1
        MI_params['toss_choice_Bat'] = 1
      else:
        SRH_params['toss_choice_Bat'] = 1
        MI_params['toss_choice_Field'] = 1
    if 'stadium_' + str(row['stadium']) in SRH_params:
      SRH_params['stadium_' + str(row['stadium'])] = 1
    if 'stadium_' + str(row['stadium']) in MI_params:
      MI_params['stadium_'+ str(row['stadium'])] = 1
    MI_params = np.array(list(MI_params.values()))
    MI_params = np.reshape(MI_params, (len(MI_params),1))
    MI_score = np.dot(weights['MI'], MI_params) + biases['MI']
    print('MI_score:', MI_score)
    SRH_params = np.array(list(SRH_params.values()))
    SRH_params = np.reshape(SRH_params, (len(SRH_params),1))
    SRH_score = np.dot(weights['SRH'],SRH_params) + biases['SRH']
    print('SRH_score :', SRH_score)
    if SRH_score > MI_score:
      print('winner : SRH')
    else:
      print('winner : MI')
    print()

  elif row['team1'] == 'Royal Challengers Bangalore' and row['team2'] == 'Sunrisers Hyderabad' or row['team2'] == 'Royal Challengers Bangalore' and row['team1'] == 'Sunrisers Hyderabad':
    RCB_params = {key: 0 for key in list(RCB_df.columns)}
    SRH_params = {key: 0 for key in list(SRH_df.columns)}
    RCB_params['Opponent_Team_Sunrisers Hyderabad'] = 1
    SRH_params['Opponent_Team_Kings XI Punjab'] = 1
    if row['toss_winner'] == 'Royal Challengers Bangalore':
      RCB_params['toss_winner'] = 1
      if row['toss_choice'] == 'Field':
        RCB_params['toss_choice_Field'] = 1
        SRH_params['toss_choice_Bat'] = 1
      else:
        RCB_params['toss_choice_Bat'] = 1
        SRH_params['toss_choice_Field'] = 1
    else:
      SRH_params['toss_winner'] = 1
      if row['toss_choice'] == 'Field':
        SRH_params['toss_choice_Field'] = 1
        RCB_params['toss_choice_Bat'] = 1
      else:
        SRH_params['toss_choice_Bat'] = 1
        RCB_params['toss_choice_Field'] = 1
    if 'stadium_' + str(row['stadium']) in SRH_params:
      SRH_params['stadium_' + str(row['stadium'])] = 1
    if 'stadium_' + str(row['stadium']) in RCB_params:
      RCB_params['stadium_'+ str(row['stadium'])] = 1
    RCB_params = np.array(list(RCB_params.values()))
    RCB_params = np.reshape(RCB_params, (len(RCB_params),1))
    RCB_score = np.dot(weights['RCB'], RCB_params) + biases['RCB']
    print('RCB_score:', RCB_score)
    SRH_params = np.array(list(SRH_params.values()))
    SRH_params = np.reshape(SRH_params, (len(SRH_params),1))
    SRH_score = np.dot(weights['SRH'],SRH_params) + biases['SRH']
    print('SRH_score :', SRH_score)
    if SRH_score > RCB_score:
      print('winner : SRH')
    else:
      print('winner : RCB')
    print()

  elif row['team1'] == 'Kolkata Knight Riders' and row['team2'] == 'Sunrisers Hyderabad' or row['team2'] == 'Kolkata Knight Riders' and row['team1'] == 'Sunrisers Hyderabad':
    KKR_params = {key: 0 for key in list(KKR_df.columns)}
    SRH_params = {key: 0 for key in list(SRH_df.columns)}
    KKR_params['Opponent_Team_Sunrisers Hyderabad'] = 1
    SRH_params['Opponent_Team_Kings XI Punjab'] = 1
    if row['toss_winner'] == 'Kolkata Knight Riders':
      KKR_params['toss_winner'] = 1
      if row['toss_choice'] == 'Field':
        KKR_params['toss_choice_Field'] = 1
        SRH_params['toss_choice_Bat'] = 1
      else:
        KKR_params['toss_choice_Bat'] = 1
        SRH_params['toss_choice_Field'] = 1
    else:
      SRH_params['toss_winner'] = 1
      if row['toss_choice'] == 'Field':
        SRH_params['toss_choice_Field'] = 1
        KKR_params['toss_choice_Bat'] = 1
      else:
        SRH_params['toss_choice_Bat'] = 1
        KKR_params['toss_choice_Field'] = 1
    if 'stadium_' + str(row['stadium']) in SRH_params:
      SRH_params['stadium_' + str(row['stadium'])] = 1
    if 'stadium_' + str(row['stadium']) in KKR_params:
      KKR_params['stadium_'+ str(row['stadium'])] = 1
    KKR_params = np.array(list(KKR_params.values()))
    KKR_params = np.reshape(KKR_params, (len(KKR_params),1))
    KKR_score = np.dot(weights['KKR'], KKR_params) + biases['KKR']
    print('KKR_score:', KKR_score)
    SRH_params = np.array(list(SRH_params.values()))
    SRH_params = np.reshape(SRH_params, (len(SRH_params),1))
    SRH_score = np.dot(weights['SRH'],SRH_params) + biases['SRH']
    print('SRH_score :', SRH_score)
    if SRH_score > KKR_score:
      print('winner : SRH')
    else:
      print('winner : KKR')
    print()

  elif row['team1'] == 'Chennai Super Kings' and row['team2'] == 'Kolkata Knight Riders' or row['team2'] == 'Chennai Super Kings' and row['team1'] == 'Kolkata Knight Riders':
    CSK_params = {key: 0 for key in list(CSK_df.columns)}
    KKR_params = {key: 0 for key in list(KKR_df.columns)}
    CSK_params['Opponent_Team_Kolkata Knight Riders'] = 1
    KKR_params['Opponent_Team_Kings XI Punjab'] = 1
    if row['toss_winner'] == 'Chennai Super Kings':
      CSK_params['toss_winner'] = 1
      if row['toss_choice'] == 'Field':
        CSK_params['toss_choice_Field'] = 1
        KKR_params['toss_choice_Bat'] = 1
      else:
        CSK_params['toss_choice_Bat'] = 1
        KKR_params['toss_choice_Field'] = 1
    else:
      KKR_params['toss_winner'] = 1
      if row['toss_choice'] == 'Field':
        KKR_params['toss_choice_Field'] = 1
        CSK_params['toss_choice_Bat'] = 1
      else:
        KKR_params['toss_choice_Bat'] = 1
        CSK_params['toss_choice_Field'] = 1
    if 'stadium_' + str(row['stadium']) in KKR_params:
      KKR_params['stadium_' + str(row['stadium'])] = 1
    if 'stadium_' + str(row['stadium']) in CSK_params:
      CSK_params['stadium_'+ str(row['stadium'])] = 1
    CSK_params = np.array(list(CSK_params.values()))
    CSK_params = np.reshape(CSK_params, (len(CSK_params),1))
    CSK_score = np.dot(weights['CSK'], CSK_params) + biases['CSK']
    print('CSK_score:', CSK_score)
    KKR_params = np.array(list(KKR_params.values()))
    KKR_params = np.reshape(KKR_params, (len(KKR_params),1))
    KKR_score = np.dot(weights['KKR'],KKR_params) + biases['KKR']
    print('KKR_score :', KKR_score)
    if KKR_score > CSK_score:
      print('winner : KKR')
    else:
      print('winner : CSK')
    print()

  elif row['team1'] == 'Mumbai Indians' and row['team2'] == 'Kolkata Knight Riders' or row['team2'] == 'Mumbai Indians' and row['team1'] == 'Kolkata Knight Riders':
    MI_params = {key: 0 for key in list(MI_df.columns)}
    KKR_params = {key: 0 for key in list(KKR_df.columns)}
    MI_params['Opponent_Team_Kolkata Knight Riders'] = 1
    KKR_params['Opponent_Team_Kings XI Punjab'] = 1
    if row['toss_winner'] == 'Mumbai Indians':
      MI_params['toss_winner'] = 1
      if row['toss_choice'] == 'Field':
        MI_params['toss_choice_Field'] = 1
        KKR_params['toss_choice_Bat'] = 1
      else:
        MI_params['toss_choice_Bat'] = 1
        KKR_params['toss_choice_Field'] = 1
    else:
      KKR_params['toss_winner'] = 1
      if row['toss_choice'] == 'Field':
        KKR_params['toss_choice_Field'] = 1
        MI_params['toss_choice_Bat'] = 1
      else:
        KKR_params['toss_choice_Bat'] = 1
        MI_params['toss_choice_Field'] = 1
    if 'stadium_' + str(row['stadium']) in KKR_params:
      KKR_params['stadium_' + str(row['stadium'])] = 1
    if 'stadium_' + str(row['stadium']) in MI_params:
      MI_params['stadium_'+ str(row['stadium'])] = 1
    MI_params = np.array(list(MI_params.values()))
    MI_params = np.reshape(MI_params, (len(MI_params),1))
    MI_score = np.dot(weights['MI'], MI_params) + biases['MI']
    print('MI_score:', MI_score)
    KKR_params = np.array(list(KKR_params.values()))
    KKR_params = np.reshape(KKR_params, (len(KKR_params),1))
    KKR_score = np.dot(weights['KKR'],KKR_params) + biases['KKR']
    print('KKR_score :', KKR_score)
    if KKR_score > MI_score:
      print('winner : KKR')
    else:
      print('winner : MI')
    print()

  elif row['team1'] == 'Royal Challengers Bangalore' and row['team2'] == 'Kolkata Knight Riders' or row['team2'] == 'Royal Challengers Bangalore' and row['team1'] == 'Kolkata Knight Riders':
    RCB_params = {key: 0 for key in list(RCB_df.columns)}
    KKR_params = {key: 0 for key in list(KKR_df.columns)}
    RCB_params['Opponent_Team_Kolkata Knight Riders'] = 1
    KKR_params['Opponent_Team_Kings XI Punjab'] = 1
    if row['toss_winner'] == 'Royal Challengers Bangalore':
      RCB_params['toss_winner'] = 1
      if row['toss_choice'] == 'Field':
        RCB_params['toss_choice_Field'] = 1
        KKR_params['toss_choice_Bat'] = 1
      else:
        RCB_params['toss_choice_Bat'] = 1
        KKR_params['toss_choice_Field'] = 1
    else:
      KKR_params['toss_winner'] = 1
      if row['toss_choice'] == 'Field':
        KKR_params['toss_choice_Field'] = 1
        RCB_params['toss_choice_Bat'] = 1
      else:
        KKR_params['toss_choice_Bat'] = 1
        RCB_params['toss_choice_Field'] = 1
    if 'stadium_' + str(row['stadium']) in KKR_params:
      KKR_params['stadium_' + str(row['stadium'])] = 1
    if 'stadium_' + str(row['stadium']) in RCB_params:
      RCB_params['stadium_'+ str(row['stadium'])] = 1
    RCB_params = np.array(list(RCB_params.values()))
    RCB_params = np.reshape(RCB_params, (len(RCB_params),1))
    RCB_score = np.dot(weights['RCB'], RCB_params) + biases['RCB']
    print('RCB_score:', RCB_score)
    KKR_params = np.array(list(KKR_params.values()))
    KKR_params = np.reshape(KKR_params, (len(KKR_params),1))
    KKR_score = np.dot(weights['KKR'],KKR_params) + biases['KKR']
    print('KKR_score :', KKR_score)
    if KKR_score > RCB_score:
      print('winner : KKR')
    else:
      print('winner : RCB')
    print()

  elif row['team1'] == 'Royal Challengers Bangalore' and row['team2'] == 'Chennai Super Kings' or row['team2'] == 'Royal Challengers Bangalore' and row['team1'] == 'Chennai Super Kings':
    RCB_params = {key: 0 for key in list(RCB_df.columns)}
    CSK_params = {key: 0 for key in list(CSK_df.columns)}
    RCB_params['Opponent_Team_Chennai Super Kings'] = 1
    CSK_params['Opponent_Team_Kings XI Punjab'] = 1
    if row['toss_winner'] == 'Royal Challengers Bangalore':
      RCB_params['toss_winner'] = 1
      if row['toss_choice'] == 'Field':
        RCB_params['toss_choice_Field'] = 1
        CSK_params['toss_choice_Bat'] = 1
      else:
        RCB_params['toss_choice_Bat'] = 1
        CSK_params['toss_choice_Field'] = 1
    else:
      CSK_params['toss_winner'] = 1
      if row['toss_choice'] == 'Field':
        CSK_params['toss_choice_Field'] = 1
        RCB_params['toss_choice_Bat'] = 1
      else:
        CSK_params['toss_choice_Bat'] = 1
        RCB_params['toss_choice_Field'] = 1
    if 'stadium_' + str(row['stadium']) in CSK_params:
      CSK_params['stadium_' + str(row['stadium'])] = 1
    if 'stadium_' + str(row['stadium']) in RCB_params:
      RCB_params['stadium_'+ str(row['stadium'])] = 1
    RCB_params = np.array(list(RCB_params.values()))
    RCB_params = np.reshape(RCB_params, (len(RCB_params),1))
    RCB_score = np.dot(weights['RCB'], RCB_params) + biases['RCB']
    print('RCB_score:', RCB_score)
    CSK_params = np.array(list(CSK_params.values()))
    CSK_params = np.reshape(CSK_params, (len(CSK_params),1))
    CSK_score = np.dot(weights['CSK'],CSK_params) + biases['CSK']
    print('CSK_score :', CSK_score)
    if CSK_score > RCB_score:
      print('winner : CSK')
    else:
      print('winner : RCB')
    print()

  elif row['team1'] == 'Royal Challengers Bangalore' and row['team2'] == 'Mumbai Indians' or row['team2'] == 'Royal Challengers Bangalore' and row['team1'] == 'Mumbai Indians':
    RCB_params = {key: 0 for key in list(RCB_df.columns)}
    MI_params = {key: 0 for key in list(MI_df.columns)}
    RCB_params['Opponent_Team_Mumbai Indians'] = 1
    MI_params['Opponent_Team_Kings XI Punjab'] = 1
    if row['toss_winner'] == 'Royal Challengers Bangalore':
      RCB_params['toss_winner'] = 1
      if row['toss_choice'] == 'Field':
        RCB_params['toss_choice_Field'] = 1
        MI_params['toss_choice_Bat'] = 1
      else:
        RCB_params['toss_choice_Bat'] = 1
        MI_params['toss_choice_Field'] = 1
    else:
      MI_params['toss_winner'] = 1
      if row['toss_choice'] == 'Field':
        MI_params['toss_choice_Field'] = 1
        RCB_params['toss_choice_Bat'] = 1
      else:
        MI_params['toss_choice_Bat'] = 1
        RCB_params['toss_choice_Field'] = 1
    if 'stadium_' + str(row['stadium']) in MI_params:
      MI_params['stadium_' + str(row['stadium'])] = 1
    if 'stadium_' + str(row['stadium']) in RCB_params:
      RCB_params['stadium_'+ str(row['stadium'])] = 1
    RCB_params = np.array(list(RCB_params.values()))
    RCB_params = np.reshape(RCB_params, (len(RCB_params),1))
    RCB_score = np.dot(weights['RCB'], RCB_params) + biases['RCB']
    print('RCB_score:', RCB_score)
    MI_params = np.array(list(MI_params.values()))
    MI_params = np.reshape(MI_params, (len(MI_params),1))
    MI_score = np.dot(weights['MI'],MI_params) + biases['MI']
    print('MI_score :', MI_score)
    if MI_score > RCB_score:
      print('winner : MI')
    else:
      print('winner : RCB')
    print()

  elif row['team1'] == 'Chennai Super Kings' and row['team2'] == 'Mumbai Indians' or row['team2'] == 'Chennai Super Kings' and row['team1'] == 'Mumbai Indians':
    CSK_params = {key: 0 for key in list(CSK_df.columns)}
    MI_params = {key: 0 for key in list(MI_df.columns)}
    CSK_params['Opponent_Team_Mumbai Indians'] = 1
    MI_params['Opponent_Team_Kings XI Punjab'] = 1
    if row['toss_winner'] == 'Chennai Super Kings':
      CSK_params['toss_winner'] = 1
      if row['toss_choice'] == 'Field':
        CSK_params['toss_choice_Field'] = 1
        MI_params['toss_choice_Bat'] = 1
      else:
        CSK_params['toss_choice_Bat'] = 1
        MI_params['toss_choice_Field'] = 1
    else:
      MI_params['toss_winner'] = 1
      if row['toss_choice'] == 'Field':
        MI_params['toss_choice_Field'] = 1
        CSK_params['toss_choice_Bat'] = 1
      else:
        MI_params['toss_choice_Bat'] = 1
        CSK_params['toss_choice_Field'] = 1
    if 'stadium_' + str(row['stadium']) in MI_params:
      MI_params['stadium_' + str(row['stadium'])] = 1
    if 'stadium_' + str(row['stadium']) in CSK_params:
      CSK_params['stadium_'+ str(row['stadium'])] = 1
    CSK_params = np.array(list(CSK_params.values()))
    CSK_params = np.reshape(CSK_params, (len(CSK_params),1))
    CSK_score = np.dot(weights['CSK'], CSK_params) + biases['CSK']
    print('CSK_score:', CSK_score)
    MI_params = np.array(list(MI_params.values()))
    MI_params = np.reshape(MI_params, (len(MI_params),1))
    MI_score = np.dot(weights['MI'],MI_params) + biases['MI']
    print('MI_score :', MI_score)
    if MI_score > CSK_score:
      print('winner : MI')
    else:
      print('winner : CSK')
    print()
# Out:
# 19 Kolkata Knight Riders
# CSK_score: [[164.49947482788843]]
# KKR_score : [[158.9528036322805]]
# winner : CSK
#
# 14 Delhi Capitals
# DC_score: [[161.00320499838557]]
# MI_score : [[178.90512292357727]]
# winner : MI
#
# 27 Punjab Kings
# KXIP_score: [[120.27145092885145]]
# RCB_score : [[156.84309242002243]]
# winner : RCB
#
# 16 Sunrisers Hyderabad
# SRH_score: [[150.5817524798216]]
# RR_score : [[157.55059376049445]]
# winner : RR
#
# 21 Royal Challengers Bangalore
# RCB_score: [[132.73324278287365]]
# KKR_score : [[118.02065471305403]]
# winner : RCB
#
# 12 Kolkata Knight Riders
# KXIP_score: [[175.007295378921]]
# KKR_score : [[158.9528036322805]]
# winner : KXIP
#
# 16 Mumbai Indians
# MI_score: [[147.5403250863073]]
# RR_score : [[162.5967270613151]]
# winner : RR
#
# 12 Chennai Super Kings
# KXIP_score: [[162.42031093409202]]
# CSK_score : [[181.0322316981244]]
# winner : CSK
#
# 16 Royal Challengers Bangalore
# RCB_score: [[154.09961811181714]]
# ...

# %%
print(len(raw_df))
# Out:
# 589

# %%
KXIP_params = {key: 0 for key in list(KXIP_df.columns)}
RCB_params = {key: 0 for key in list(RCB_df.columns)}
KKR_params = {key: 0 for key in list(KKR_df.columns)}
RR_params = {key: 0 for key in list(RR_df.columns)}
CSK_params = {key: 0 for key in list(CSK_df.columns)}
DC_params = {key: 0 for key in list(DC_df.columns)}
MI_params = {key: 0 for key in list(MI_df.columns)}
SRH_params = {key: 0 for key in list(SRH_df.columns)}
count = 0

for index, row in raw_df.iterrows():
  print(len(row['team1']), row['team2'])
  if row['team1'] == 'Kings XI Punjab' and row['team2'] == 'Royal Challengers Bangalore' or row['team2'] == 'Kings XI Punjab' and row['team1'] == 'Royal Challengers Bangalore':
    KXIP_params = {key: 0 for key in list(KXIP_df.columns)}
    RCB_params = {key: 0 for key in list(RCB_df.columns)}
    KXIP_params['Opponent_Team_Royal Challengers Bangalore'] = 1
    RCB_params['Opponent_Team_Kings XI Punjab'] = 1
    if row['toss_winner'] == 'Kings XI Punjab':
      KXIP_params['toss_winner'] = 1
      if row['toss_choice'] == 'Field':
        KXIP_params['toss_choice_Field'] = 1
        RCB_params['toss_choice_Bat'] = 1
      else:
        KXIP_params['toss_choice_Bat'] = 1
        RCB_params['toss_choice_Field'] = 1
    else:
      RCB_params['toss_winner'] = 1
      if row['toss_choice'] == 'Field':
        RCB_params['toss_choice_Field'] = 1
        KXIP_params['toss_choice_Bat'] = 1
      else:
        RCB_params['toss_choice_Bat'] = 1
        KXIP_params['toss_choice_Field'] = 1
    if 'stadium_' + str(row['stadium']) in RCB_params:
      RCB_params['stadium_' + str(row['stadium'])] = 1
    if 'stadium_' + str(row['stadium']) in KXIP_params:
      KXIP_params['stadium_'+ str(row['stadium'])] = 1
    KXIP_params = np.array(list(KXIP_params.values()))
    KXIP_params = np.reshape(KXIP_params, (len(KXIP_params),1))
    KXIP_score = np.dot(weights['KXIP'], KXIP_params) + biases['KXIP']
    print('KXIP_score:', KXIP_score)
    RCB_params = np.array(list(RCB_params.values()))
    RCB_params = np.reshape(RCB_params, (len(RCB_params),1))
    RCB_score = np.dot(weights['RCB'],RCB_params) + biases['RCB']
    print('RCB_score :', RCB_score)
    if RCB_score > KXIP_score:
      print('winner : RCB')
      if row['winner'] == 'Royal Challengers Bangalore':
        count += 1
    else:
      print('winner : KXIP')
      if row['winner'] == 'Kings XI Punjab':
        count += 1
    print()

  elif row['team1'] == 'Kings XI Punjab' and row['team2'] == 'Chennai Super Kings' or row['team2'] == 'Kings XI Punjab' and row['team1'] == 'Chennai Super Kings':
    KXIP_params = {key: 0 for key in list(KXIP_df.columns)}
    CSK_params = {key: 0 for key in list(CSK_df.columns)}
    KXIP_params['Opponent_Team_Chennai Super Kings'] = 1
    CSK_params['Opponent_Team_Kings XI Punjab'] = 1
    if row['toss_winner'] == 'Kings XI Punjab':
      KXIP_params['toss_winner'] = 1
      if row['toss_choice'] == 'Field':
        KXIP_params['toss_choice_Field'] = 1
        CSK_params['toss_choice_Bat'] = 1
      else:
        KXIP_params['toss_choice_Bat'] = 1
        CSK_params['toss_choice_Field'] = 1
    else:
      CSK_params['toss_winner'] = 1
      if row['toss_choice'] == 'Field':
        CSK_params['toss_choice_Field'] = 1
        KXIP_params['toss_choice_Bat'] = 1
      else:
        CSK_params['toss_choice_Bat'] = 1
        KXIP_params['toss_choice_Field'] = 1
    if 'stadium_' + str(row['stadium']) in CSK_params:
      CSK_params['stadium_' + str(row['stadium'])] = 1
    if 'stadium_' + str(row['stadium']) in KXIP_params:
      KXIP_params['stadium_'+ str(row['stadium'])] = 1
    KXIP_params = np.array(list(KXIP_params.values()))
    KXIP_params = np.reshape(KXIP_params, (len(KXIP_params),1))
    KXIP_score = np.dot(weights['KXIP'], KXIP_params) + biases['KXIP']
    print('KXIP_score:', KXIP_score)
    CSK_params = np.array(list(CSK_params.values()))
    CSK_params = np.reshape(CSK_params, (len(CSK_params),1))
    CSK_score = np.dot(weights['CSK'],CSK_params) + biases['CSK']
    print('CSK_score :', CSK_score)
    if CSK_score > KXIP_score:
      print('winner : CSK')
      if row['winner'] == 'Chennai Super Kings':
        count += 1
    else:
      if row['winner'] == 'Kings XI Punjab':
        count += 1
    print()
    
  elif row['team1'] == 'Kings XI Punjab' and row['team2'] == 'Mumbai Indians' or row['team2'] == 'Kings XI Punjab' and row['team1'] == 'Mumbai Indians':
    KXIP_params = {key: 0 for key in list(KXIP_df.columns)}
    MI_params = {key: 0 for key in list(MI_df.columns)}
    KXIP_params['Opponent_Team_Mumbai Indians'] = 1
    MI_params['Opponent_Team_Kings XI Punjab'] = 1
    if row['toss_winner'] == 'Kings XI Punjab':
      KXIP_params['toss_winner'] = 1
      if row['toss_choice'] == 'Field':
        KXIP_params['toss_choice_Field'] = 1
        MI_params['toss_choice_Bat'] = 1
      else:
        KXIP_params['toss_choice_Bat'] = 1
        MI_params['toss_choice_Field'] = 1
    else:
      MI_params['toss_winner'] = 1
      if row['toss_choice'] == 'Field':
        MI_params['toss_choice_Field'] = 1
        KXIP_params['toss_choice_Bat'] = 1
      else:
        MI_params['toss_choice_Bat'] = 1
        KXIP_params['toss_choice_Field'] = 1
    if 'stadium_' + str(row['stadium']) in MI_params:
      MI_params['stadium_' + str(row['stadium'])] = 1
    if 'stadium_' + str(row['stadium']) in KXIP_params:
      KXIP_params['stadium_'+ str(row['stadium'])] = 1
    KXIP_params = np.array(list(KXIP_params.values()))
    KXIP_params = np.reshape(KXIP_params, (len(KXIP_params),1))
    KXIP_score = np.dot(weights['KXIP'], KXIP_params) + biases['KXIP']
    print('KXIP_score:', KXIP_score)
    MI_params = np.array(list(MI_params.values()))
    MI_params = np.reshape(MI_params, (len(MI_params),1))
    MI_score = np.dot(weights['MI'],MI_params) + biases['MI']
    print('MI_score :', MI_score)
    if MI_score > KXIP_score:
      print('winner : MI')
      if row['winner'] == 'Mumbai Indians':
        count += 1
    else:
      print('winner : KXIP')
      if row['winner'] == 'Kings XI Punjab':
        count += 1
    print()

  elif row['team1'] == 'Kings XI Punjab' and row['team2'] == 'Sunrisers Hyderabad' or row['team2'] == 'Kings XI Punjab' and row['team1'] == 'Sunrisers Hyderabad':
    KXIP_params = {key: 0 for key in list(KXIP_df.columns)}
    SRH_params = {key: 0 for key in list(SRH_df.columns)}
    KXIP_params['Opponent_Team_Sunrisers Hyderabad'] = 1
    SRH_params['Opponent_Team_Kings XI Punjab'] = 1
    if row['toss_winner'] == 'Kings XI Punjab':
      KXIP_params['toss_winner'] = 1
      if row['toss_choice'] == 'Field':
        KXIP_params['toss_choice_Field'] = 1
        SRH_params['toss_choice_Bat'] = 1
      else:
        KXIP_params['toss_choice_Bat'] = 1
        SRH_params['toss_choice_Field'] = 1
    else:
      SRH_params['toss_winner'] = 1
      if row['toss_choice'] == 'Field':
        SRH_params['toss_choice_Field'] = 1
        KXIP_params['toss_choice_Bat'] = 1
      else:
        SRH_params['toss_choice_Bat'] = 1
        KXIP_params['toss_choice_Field'] = 1
    if 'stadium_' + str(row['stadium']) in SRH_params:
      SRH_params['stadium_' + str(row['stadium'])] = 1
    if 'stadium_' + str(row['stadium']) in KXIP_params:
      KXIP_params['stadium_'+ str(row['stadium'])] = 1
    KXIP_params = np.array(list(KXIP_params.values()))
    KXIP_params = np.reshape(KXIP_params, (len(KXIP_params),1))
    KXIP_score = np.dot(weights['KXIP'], KXIP_params) + biases['KXIP']
    print('KXIP_score:', KXIP_score)
    SRH_params = np.array(list(SRH_params.values()))
    SRH_params = np.reshape(SRH_params, (len(SRH_params),1))
    SRH_score = np.dot(weights['SRH'],SRH_params) + biases['SRH']
    print('SRH_score :', SRH_score)
    if SRH_score > KXIP_score:
      print('winner : SRH')
      if row['winner'] == 'Sunrisers Hyderabad':
        count += 1
    else:
      print('winner : KXIP')
      if row['winner'] == 'Kings XI Punjab':
        count += 1
    print()

  elif row['team1'] == 'Kings XI Punjab' and row['team2'] == 'Delhi Capitals' or row['team2'] == 'Kings XI Punjab' and row['team1'] == 'Delhi Capitals':
    KXIP_params = {key: 0 for key in list(KXIP_df.columns)}
    DC_params = {key: 0 for key in list(DC_df.columns)}
    KXIP_params['Opponent_Team_Delhi Capitals'] = 1
    DC_params['Opponent_Team_Kings XI Punjab'] = 1
    if row['toss_winner'] == 'Kings XI Punjab':
      KXIP_params['toss_winner'] = 1
      if row['toss_choice'] == 'Field':
        KXIP_params['toss_choice_Field'] = 1
        DC_params['toss_choice_Bat'] = 1
      else:
        KXIP_params['toss_choice_Bat'] = 1
        DC_params['toss_choice_Field'] = 1
    else:
      DC_params['toss_winner'] = 1
      if row['toss_choice'] == 'Field':
        DC_params['toss_choice_Field'] = 1
        KXIP_params['toss_choice_Bat'] = 1
      else:
        DC_params['toss_choice_Bat'] = 1
        KXIP_params['toss_choice_Field'] = 1
    if 'stadium_' + str(row['stadium']) in DC_params:
      DC_params['stadium_' + str(row['stadium'])] = 1
    if 'stadium_' + str(row['stadium']) in KXIP_params:
      KXIP_params['stadium_'+ str(row['stadium'])] = 1
    KXIP_params = np.array(list(KXIP_params.values()))
    KXIP_params = np.reshape(KXIP_params, (len(KXIP_params),1))
    KXIP_score = np.dot(weights['KXIP'], KXIP_params) + biases['KXIP']
    print('KXIP_score:', KXIP_score)
    DC_params = np.array(list(DC_params.values()))
    DC_params = np.reshape(DC_params, (len(DC_params),1))
    DC_score = np.dot(weights['DC'],DC_params) + biases['DC']
    print('DC_score :', DC_score)
    if DC_score > KXIP_score:
      print('winner : DC')
      if row['winner'] == 'Delhi Capitalse':
        count += 1
    else:
      print('winner : KXIP')
      if row['winner'] == 'Kings XI Punjab':
        count += 1
    print()

  elif row['team1'] == 'Kings XI Punjab' and row['team2'] == 'Kolkata Knight Riders' or row['team2'] == 'Kings XI Punjab' and row['team1'] == 'Kolkata Knight Riders':
    KXIP_params = {key: 0 for key in list(KXIP_df.columns)}
    KKR_params = {key: 0 for key in list(KKR_df.columns)}
    KXIP_params['Opponent_Team_Kolkata Knight Riders'] = 1
    KKR_params['Opponent_Team_Kings XI Punjab'] = 1
    if row['toss_winner'] == 'Kings XI Punjab':
      KXIP_params['toss_winner'] = 1
      if row['toss_choice'] == 'Field':
        KXIP_params['toss_choice_Field'] = 1
        KKR_params['toss_choice_Bat'] = 1
      else:
        KXIP_params['toss_choice_Bat'] = 1
        KKR_params['toss_choice_Field'] = 1
    else:
      KKR_params['toss_winner'] = 1
      if row['toss_choice'] == 'Field':
        KKR_params['toss_choice_Field'] = 1
        KXIP_params['toss_choice_Bat'] = 1
      else:
        KKR_params['toss_choice_Bat'] = 1
        KXIP_params['toss_choice_Field'] = 1
    if 'stadium_' + str(row['stadium']) in KKR_params:
      KKR_params['stadium_' + str(row['stadium'])] = 1
    if 'stadium_' + str(row['stadium']) in KXIP_params:
      KXIP_params['stadium_'+ str(row['stadium'])] = 1
    KXIP_params = np.array(list(KXIP_params.values()))
    KXIP_params = np.reshape(KXIP_params, (len(KXIP_params),1))
    KXIP_score = np.dot(weights['KXIP'], KXIP_params) + biases['KXIP']
    print('KXIP_score:', KXIP_score)
    KKR_params = np.array(list(KKR_params.values()))
    KKR_params = np.reshape(KKR_params, (len(KKR_params),1))
    KKR_score = np.dot(weights['KKR'],KKR_params) + biases['KKR']
    print('KKR_score :', KKR_score)
    if KKR_score > KXIP_score:
      print('winner : KKR')
      if row['winner'] == 'Kolkata Knight Riders':
        count += 1
    else:
      print('winner : KXIP')
      if row['winner'] == 'Kings XI Punjab':
        count += 1
    print()

  elif row['team1'] == 'Kings XI Punjab' and row['team2'] == 'Rajasthan Royals' or row['team2'] == 'Kings XI Punjab' and row['team1'] == 'Rajasthan Royals':
    KXIP_params = {key: 0 for key in list(KXIP_df.columns)}
    RR_params = {key: 0 for key in list(RR_df.columns)}
    KXIP_params['Opponent_Team_Rajasthan Royals'] = 1
    RR_params['Opponent_Team_Kings XI Punjab'] = 1
    if row['toss_winner'] == 'Kings XI Punjab':
      KXIP_params['toss_winner'] = 1
      if row['toss_choice'] == 'Field':
        KXIP_params['toss_choice_Field'] = 1
        RR_params['toss_choice_Bat'] = 1
      else:
        KXIP_params['toss_choice_Bat'] = 1
        RR_params['toss_choice_Field'] = 1
    else:
      RR_params['toss_winner'] = 1
      if row['toss_choice'] == 'Field':
        RR_params['toss_choice_Field'] = 1
        KXIP_params['toss_choice_Bat'] = 1
      else:
        RR_params['toss_choice_Bat'] = 1
        KXIP_params['toss_choice_Field'] = 1
    if 'stadium_' + str(row['stadium']) in RR_params:
      RR_params['stadium_' + str(row['stadium'])] = 1
    if 'stadium_' + str(row['stadium']) in KXIP_params:
      KXIP_params['stadium_'+ str(row['stadium'])] = 1
    KXIP_params = np.array(list(KXIP_params.values()))
    KXIP_params = np.reshape(KXIP_params, (len(KXIP_params),1))
    KXIP_score = np.dot(weights['KXIP'], KXIP_params) + biases['KXIP']
    print('KXIP_score:', KXIP_score)
    RR_params = np.array(list(RR_params.values()))
    RR_params = np.reshape(RR_params, (len(RR_params),1))
    RR_score = np.dot(weights['RR'],RR_params) + biases['RR']
    print('RR_score :', RR_score)
    if RR_score > KXIP_score:
      print('winner : RR')
      if row['winner'] == 'Rajasthan Royals':
        count += 1
    else:
      print('winner : KXIP')
      if row['winner'] == 'Kings XI Punjab':
        count += 1
    print()

  elif row['team1'] == 'Chennai Super Kings' and row['team2'] == 'Rajasthan Royals' or row['team2'] == 'Chennai Super Kings' and row['team1'] == 'Rajasthan Royals':
    CSK_params = {key: 0 for key in list(CSK_df.columns)}
    RR_params = {key: 0 for key in list(RR_df.columns)}
    CSK_params['Opponent_Team_Rajasthan Royals'] = 1
    RR_params['Opponent_Team_Kings XI Punjab'] = 1
    if row['toss_winner'] == 'Chennai Super Kings':
      CSK_params['toss_winner'] = 1
      if row['toss_choice'] == 'Field':
        CSK_params['toss_choice_Field'] = 1
        RR_params['toss_choice_Bat'] = 1
      else:
        CSK_params['toss_choice_Bat'] = 1
        RR_params['toss_choice_Field'] = 1
    else:
      RR_params['toss_winner'] = 1
      if row['toss_choice'] == 'Field':
        RR_params['toss_choice_Field'] = 1
        CSK_params['toss_choice_Bat'] = 1
      else:
        RR_params['toss_choice_Bat'] = 1
        CSK_params['toss_choice_Field'] = 1
    if 'stadium_' + str(row['stadium']) in RR_params:
      RR_params['stadium_' + str(row['stadium'])] = 1
    if 'stadium_' + str(row['stadium']) in CSK_params:
      CSK_params['stadium_'+ str(row['stadium'])] = 1
    CSK_params = np.array(list(CSK_params.values()))
    CSK_params = np.reshape(CSK_params, (len(CSK_params),1))
    CSK_score = np.dot(weights['CSK'], CSK_params) + biases['CSK']
    print('CSK_score:', CSK_score)
    RR_params = np.array(list(RR_params.values()))
    RR_params = np.reshape(RR_params, (len(RR_params),1))
    RR_score = np.dot(weights['RR'],RR_params) + biases['RR']
    print('RR_score :', RR_score)
    if RR_score > CSK_score:
      print('winner : RR')
      if row['winner'] == 'Rajasthan Royals':
        count += 1
    else:
      print('winner : CSK')
      if row['winner'] == 'Chennai Super Kings':
        count += 1
    print()

  elif row['team1'] == 'Mumbai Indians' and row['team2'] == 'Rajasthan Royals' or row['team2'] == 'Mumbai Indians' and row['team1'] == 'Rajasthan Royals':
    MI_params = {key: 0 for key in list(MI_df.columns)}
    RR_params = {key: 0 for key in list(RR_df.columns)}
    MI_params['Opponent_Team_Rajasthan Royals'] = 1
    RR_params['Opponent_Team_Kings XI Punjab'] = 1
    if row['toss_winner'] == 'Mumbai Indians':
      MI_params['toss_winner'] = 1
      if row['toss_choice'] == 'Field':
        MI_params['toss_choice_Field'] = 1
        RR_params['toss_choice_Bat'] = 1
      else:
        MI_params['toss_choice_Bat'] = 1
        RR_params['toss_choice_Field'] = 1
    else:
      RR_params['toss_winner'] = 1
      if row['toss_choice'] == 'Field':
        RR_params['toss_choice_Field'] = 1
        MI_params['toss_choice_Bat'] = 1
      else:
        RR_params['toss_choice_Bat'] = 1
        MI_params['toss_choice_Field'] = 1
    if 'stadium_' + str(row['stadium']) in RR_params:
      RR_params['stadium_' + str(row['stadium'])] = 1
    if 'stadium_' + str(row['stadium']) in MI_params:
      MI_params['stadium_'+ str(row['stadium'])] = 1
    MI_params = np.array(list(MI_params.values()))
    MI_params = np.reshape(MI_params, (len(MI_params),1))
    MI_score = np.dot(weights['MI'], MI_params) + biases['MI']
    print('MI_score:', MI_score)
    RR_params = np.array(list(RR_params.values()))
    RR_params = np.reshape(RR_params, (len(RR_params),1))
    RR_score = np.dot(weights['RR'],RR_params) + biases['RR']
    print('RR_score :', RR_score)
    if RR_score > MI_score:
      print('winner : RR')
      if row['winner'] == 'Rajathan Royals':
        count += 1
    else:
      print('winner : MI')
      if row['winner'] == 'Mumbai Indians':
        count += 1
    print()

  elif row['team1'] == 'Royal Challengers Bangalore' and row['team2'] == 'Rajasthan Royals' or row['team2'] == 'Royal Challengers Bangalore' and row['team1'] == 'Rajasthan Royals':
    RCB_params = {key: 0 for key in list(RCB_df.columns)}
    RR_params = {key: 0 for key in list(RR_df.columns)}
    RCB_params['Opponent_Team_Rajasthan Royals'] = 1
    RR_params['Opponent_Team_Kings XI Punjab'] = 1
    if row['toss_winner'] == 'Royal Challengers Bangalore':
      RCB_params['toss_winner'] = 1
      if row['toss_choice'] == 'Field':
        RCB_params['toss_choice_Field'] = 1
        RR_params['toss_choice_Bat'] = 1
      else:
        RCB_params['toss_choice_Bat'] = 1
        RR_params['toss_choice_Field'] = 1
    else:
      RR_params['toss_winner'] = 1
      if row['toss_choice'] == 'Field':
        RR_params['toss_choice_Field'] = 1
        RCB_params['toss_choice_Bat'] = 1
      else:
        RR_params['toss_choice_Bat'] = 1
        RCB_params['toss_choice_Field'] = 1
    if 'stadium_' + str(row['stadium']) in RR_params:
      RR_params['stadium_' + str(row['stadium'])] = 1
    if 'stadium_' + str(row['stadium']) in RCB_params:
      RCB_params['stadium_'+ str(row['stadium'])] = 1
    RCB_params = np.array(list(RCB_params.values()))
    RCB_params = np.reshape(RCB_params, (len(RCB_params),1))
    RCB_score = np.dot(weights['RCB'], RCB_params) + biases['RCB']
    print('RCB_score:', RCB_score)
    RR_params = np.array(list(RR_params.values()))
    RR_params = np.reshape(RR_params, (len(RR_params),1))
    RR_score = np.dot(weights['RR'],RR_params) + biases['RR']
    print('RR_score :', RR_score)
    if RR_score > RCB_score:
      print('winner : RR')
      if row['winner'] == 'Rajasthan Royals':
        count += 1
    else:
      print('winner : RCB')
      if row['winner'] == 'Royal Challengers Bangalore':
        count += 1
    print()

  elif row['team1'] == 'Kolkata Knight Riders' and row['team2'] == 'Rajasthan Royals' or row['team2'] == 'Kolkata Knight Riders' and row['team1'] == 'Rajasthan Royals':
    KKR_params = {key: 0 for key in list(KKR_df.columns)}
    RR_params = {key: 0 for key in list(RR_df.columns)}
    KKR_params['Opponent_Team_Rajasthan Royals'] = 1
    RR_params['Opponent_Team_Kings XI Punjab'] = 1
    if row['toss_winner'] == 'Kolkata Knight Riders':
      KKR_params['toss_winner'] = 1
      if row['toss_choice'] == 'Field':
        KKR_params['toss_choice_Field'] = 1
        RR_params['toss_choice_Bat'] = 1
      else:
        KKR_params['toss_choice_Bat'] = 1
        RR_params['toss_choice_Field'] = 1
    else:
      RR_params['toss_winner'] = 1
      if row['toss_choice'] == 'Field':
        RR_params['toss_choice_Field'] = 1
        KKR_params['toss_choice_Bat'] = 1
      else:
        RR_params['toss_choice_Bat'] = 1
        KKR_params['toss_choice_Field'] = 1
    if 'stadium_' + str(row['stadium']) in RR_params:
      RR_params['stadium_' + str(row['stadium'])] = 1
    if 'stadium_' + str(row['stadium']) in KKR_params:
      KKR_params['stadium_'+ str(row['stadium'])] = 1
    KKR_params = np.array(list(KKR_params.values()))
    KKR_params = np.reshape(KKR_params, (len(KKR_params),1))
    KKR_score = np.dot(weights['KKR'], KKR_params) + biases['KKR']
    print('KKR_score:', KKR_score)
    RR_params = np.array(list(RR_params.values()))
    RR_params = np.reshape(RR_params, (len(RR_params),1))
    RR_score = np.dot(weights['RR'],RR_params) + biases['RR']
    print('RR_score :', RR_score)
    if RR_score > KKR_score:
      print('winner : RR')
      if row['winner'] == 'Rajasthan Royals':
        count += 1
    else:
      print('winner : KKR')
      if row['winner'] == 'Kolkata Knight Riders':
        count += 1
    print()

  elif row['team1'] == 'Sunrisers Hyderabad' and row['team2'] == 'Rajasthan Royals' or row['team2'] == 'Sunrisers Hyderabad' and row['team1'] == 'Rajasthan Royals':
    SRH_params = {key: 0 for key in list(SRH_df.columns)}
    RR_params = {key: 0 for key in list(RR_df.columns)}
    SRH_params['Opponent_Team_Rajasthan Royals'] = 1
    RR_params['Opponent_Team_Kings XI Punjab'] = 1
    if row['toss_winner'] == 'Sunrisers Hyderabad':
      SRH_params['toss_winner'] = 1
      if row['toss_choice'] == 'Field':
        SRH_params['toss_choice_Field'] = 1
        RR_params['toss_choice_Bat'] = 1
      else:
        SRH_params['toss_choice_Bat'] = 1
        RR_params['toss_choice_Field'] = 1
    else:
      RR_params['toss_winner'] = 1
      if row['toss_choice'] == 'Field':
        RR_params['toss_choice_Field'] = 1
        SRH_params['toss_choice_Bat'] = 1
      else:
        RR_params['toss_choice_Bat'] = 1
        SRH_params['toss_choice_Field'] = 1
    if 'stadium_' + str(row['stadium']) in RR_params:
      RR_params['stadium_' + str(row['stadium'])] = 1
    if 'stadium_' + str(row['stadium']) in SRH_params:
      SRH_params['stadium_'+ str(row['stadium'])] = 1
    SRH_params = np.array(list(SRH_params.values()))
    SRH_params = np.reshape(SRH_params, (len(SRH_params),1))
    SRH_score = np.dot(weights['SRH'], SRH_params) + biases['SRH']
    print('SRH_score:', SRH_score)
    RR_params = np.array(list(RR_params.values()))
    RR_params = np.reshape(RR_params, (len(RR_params),1))
    RR_score = np.dot(weights['RR'],RR_params) + biases['RR']
    print('RR_score :', RR_score)
    if RR_score > SRH_score:
      print('winner : RR')
      if row['winner'] == 'Rajasthan Royals':
        count += 1
    else:
      print('winner : SRH')
      if row['winner'] == 'Sunrisers Hyderabad':
        count += 1
    print()

  elif row['team1'] == 'Delhi Capitals' and row['team2'] == 'Rajasthan Royals' or row['team2'] == 'Delhi Capitals' and row['team1'] == 'Rajasthan Royals':
    DC_params = {key: 0 for key in list(DC_df.columns)}
    RR_params = {key: 0 for key in list(RR_df.columns)}
    DC_params['Opponent_Team_Rajasthan Royals'] = 1
    RR_params['Opponent_Team_Kings XI Punjab'] = 1
    if row['toss_winner'] == 'Delhi Capitals':
      DC_params['toss_winner'] = 1
      if row['toss_choice'] == 'Field':
        DC_params['toss_choice_Field'] = 1
        RR_params['toss_choice_Bat'] = 1
      else:
        DC_params['toss_choice_Bat'] = 1
        RR_params['toss_choice_Field'] = 1
    else:
      RR_params['toss_winner'] = 1
      if row['toss_choice'] == 'Field':
        RR_params['toss_choice_Field'] = 1
        DC_params['toss_choice_Bat'] = 1
      else:
        RR_params['toss_choice_Bat'] = 1
        DC_params['toss_choice_Field'] = 1
    if 'stadium_' + str(row['stadium']) in RR_params:
      RR_params['stadium_' + str(row['stadium'])] = 1
    if 'stadium_' + str(row['stadium']) in DC_params:
      DC_params['stadium_'+ str(row['stadium'])] = 1
    DC_params = np.array(list(DC_params.values()))
    DC_params = np.reshape(DC_params, (len(DC_params),1))
    DC_score = np.dot(weights['DC'], DC_params) + biases['DC']
    print('DC_score:', DC_score)
    RR_params = np.array(list(RR_params.values()))
    RR_params = np.reshape(RR_params, (len(RR_params),1))
    RR_score = np.dot(weights['RR'],RR_params) + biases['RR']
    print('RR_score :', RR_score)
    if RR_score > DC_score:
      print('winner : RR')
      if row['winner'] == 'Rajasthan Royals':
        count += 1
    else:
      print('winner : DC')
      if row['winner'] == 'Delhi Capitals':
        count += 1
    print()

  elif row['team1'] == 'Delhi Capitals' and row['team2'] == 'Chennai Super Kings' or row['team2'] == 'Delhi Capitals' and row['team1'] == 'Chennai Super Kings':
    DC_params = {key: 0 for key in list(DC_df.columns)}
    CSK_params = {key: 0 for key in list(CSK_df.columns)}
    DC_params['Opponent_Team_Chennai Super Kings'] = 1
    CSK_params['Opponent_Team_Kings XI Punjab'] = 1
    if row['toss_winner'] == 'Delhi Capitals':
      DC_params['toss_winner'] = 1
      if row['toss_choice'] == 'Field':
        DC_params['toss_choice_Field'] = 1
        CSK_params['toss_choice_Bat'] = 1
      else:
        DC_params['toss_choice_Bat'] = 1
        CSK_params['toss_choice_Field'] = 1
    else:
      CSK_params['toss_winner'] = 1
      if row['toss_choice'] == 'Field':
        CSK_params['toss_choice_Field'] = 1
        DC_params['toss_choice_Bat'] = 1
      else:
        CSK_params['toss_choice_Bat'] = 1
        DC_params['toss_choice_Field'] = 1
    if 'stadium_' + str(row['stadium']) in CSK_params:
      CSK_params['stadium_' + str(row['stadium'])] = 1
    if 'stadium_' + str(row['stadium']) in DC_params:
      DC_params['stadium_'+ str(row['stadium'])] = 1
    DC_params = np.array(list(DC_params.values()))
    DC_params = np.reshape(DC_params, (len(DC_params),1))
    DC_score = np.dot(weights['DC'], DC_params) + biases['DC']
    print('DC_score:', DC_score)
    CSK_params = np.array(list(CSK_params.values()))
    CSK_params = np.reshape(CSK_params, (len(CSK_params),1))
    CSK_score = np.dot(weights['CSK'],CSK_params) + biases['CSK']
    print('CSK_score :', CSK_score)
    if CSK_score > DC_score:
      print('winner : CSK')
      if row['winner'] == 'Chennai Super Kings':
        count += 1
    else:
      print('winner : DC')
      if row['winner'] == 'Delhi Capitals':
        count += 1
    print()

  elif row['team1'] == 'Delhi Capitals' and row['team2'] == 'Mumbai Indians' or row['team2'] == 'Delhi Capitals' and row['team1'] == 'Mumbai Indians':
    DC_params = {key: 0 for key in list(DC_df.columns)}
    MI_params = {key: 0 for key in list(MI_df.columns)}
    DC_params['Opponent_Team_Mumbai Indians'] = 1
    MI_params['Opponent_Team_Kings XI Punjab'] = 1
    if row['toss_winner'] == 'Delhi Capitals':
      DC_params['toss_winner'] = 1
      if row['toss_choice'] == 'Field':
        DC_params['toss_choice_Field'] = 1
        MI_params['toss_choice_Bat'] = 1
      else:
        DC_params['toss_choice_Bat'] = 1
        MI_params['toss_choice_Field'] = 1
    else:
      MI_params['toss_winner'] = 1
      if row['toss_choice'] == 'Field':
        MI_params['toss_choice_Field'] = 1
        DC_params['toss_choice_Bat'] = 1
      else:
        MI_params['toss_choice_Bat'] = 1
        DC_params['toss_choice_Field'] = 1
    if 'stadium_' + str(row['stadium']) in MI_params:
      MI_params['stadium_' + str(row['stadium'])] = 1
    if 'stadium_' + str(row['stadium']) in DC_params:
      DC_params['stadium_'+ str(row['stadium'])] = 1
    DC_params = np.array(list(DC_params.values()))
    DC_params = np.reshape(DC_params, (len(DC_params),1))
    DC_score = np.dot(weights['DC'], DC_params) + biases['DC']
    print('DC_score:', DC_score)
    MI_params = np.array(list(MI_params.values()))
    MI_params = np.reshape(MI_params, (len(MI_params),1))
    MI_score = np.dot(weights['MI'],MI_params) + biases['MI']
    print('MI_score :', MI_score)
    if MI_score > DC_score:
      print('winner : MI')
      if row['winner'] == 'Mumbai Indians':
        count += 1
    else:
      print('winner : DC')
      if row['winner'] == 'Delhi Capitals':
        count += 1
    print()

  elif row['team1'] == 'Delhi Capitals' and row['team2'] == 'Kolkata Knight Riders' or row['team2'] == 'Delhi Capitals' and row['team1'] == 'Kolkata Knight Riders':
    DC_params = {key: 0 for key in list(DC_df.columns)}
    KKR_params = {key: 0 for key in list(KKR_df.columns)}
    DC_params['Opponent_Team_Kolkata Knight Riders'] = 1
    KKR_params['Opponent_Team_Kings XI Punjab'] = 1
    if row['toss_winner'] == 'Delhi Capitals':
      DC_params['toss_winner'] = 1
      if row['toss_choice'] == 'Field':
        DC_params['toss_choice_Field'] = 1
        KKR_params['toss_choice_Bat'] = 1
      else:
        DC_params['toss_choice_Bat'] = 1
        KKR_params['toss_choice_Field'] = 1
    else:
      KKR_params['toss_winner'] = 1
      if row['toss_choice'] == 'Field':
        KKR_params['toss_choice_Field'] = 1
        DC_params['toss_choice_Bat'] = 1
      else:
        KKR_params['toss_choice_Bat'] = 1
        DC_params['toss_choice_Field'] = 1
    if 'stadium_' + str(row['stadium']) in KKR_params:
      KKR_params['stadium_' + str(row['stadium'])] = 1
    if 'stadium_' + str(row['stadium']) in DC_params:
      DC_params['stadium_'+ str(row['stadium'])] = 1
    DC_params = np.array(list(DC_params.values()))
    DC_params = np.reshape(DC_params, (len(DC_params),1))
    DC_score = np.dot(weights['DC'], DC_params) + biases['DC']
    print('DC_score:', DC_score)
    KKR_params = np.array(list(KKR_params.values()))
    KKR_params = np.reshape(KKR_params, (len(KKR_params),1))
    KKR_score = np.dot(weights['KKR'],KKR_params) + biases['KKR']
    print('KKR_score :', KKR_score)
    if KKR_score > DC_score:
      print('winner : KKR')
      if row['winner'] == 'Kolkata Knight Riders':
        count += 1
    else:
      print('winner : DC')
      if row['winner'] == 'Delhi Capitals':
        count += 1
    print()

  elif row['team1'] == 'Delhi Capitals' and row['team2'] == 'Royal Challengers Bangalore' or row['team2'] == 'Delhi Capitals' and row['team1'] == 'Royal Challengers Bangalore':
    DC_params = {key: 0 for key in list(DC_df.columns)}
    RCB_params = {key: 0 for key in list(RCB_df.columns)}
    DC_params['Opponent_Team_Royal Challengers Bangalore'] = 1
    RCB_params['Opponent_Team_Kings XI Punjab'] = 1
    if row['toss_winner'] == 'Delhi Capitals':
      DC_params['toss_winner'] = 1
      if row['toss_choice'] == 'Field':
        DC_params['toss_choice_Field'] = 1
        RCB_params['toss_choice_Bat'] = 1
      else:
        DC_params['toss_choice_Bat'] = 1
        RCB_params['toss_choice_Field'] = 1
    else:
      RCB_params['toss_winner'] = 1
      if row['toss_choice'] == 'Field':
        RCB_params['toss_choice_Field'] = 1
        DC_params['toss_choice_Bat'] = 1
      else:
        RCB_params['toss_choice_Bat'] = 1
        DC_params['toss_choice_Field'] = 1
    if 'stadium_' + str(row['stadium']) in RCB_params:
      RCB_params['stadium_' + str(row['stadium'])] = 1
    if 'stadium_' + str(row['stadium']) in DC_params:
      DC_params['stadium_'+ str(row['stadium'])] = 1
    DC_params = np.array(list(DC_params.values()))
    DC_params = np.reshape(DC_params, (len(DC_params),1))
    DC_score = np.dot(weights['DC'], DC_params) + biases['DC']
    print('DC_score:', DC_score)
    RCB_params = np.array(list(RCB_params.values()))
    RCB_params = np.reshape(RCB_params, (len(RCB_params),1))
    RCB_score = np.dot(weights['RCB'],RCB_params) + biases['RCB']
    print('RCB_score :', RCB_score)
    if RCB_score > DC_score:
      print('winner : RCB')
      if row['winner'] == 'Royal Challengers Bangalore':
        count += 1
    else:
      print('winner : DC')
      if row['winner'] == 'Delhi Capitals':
        count += 1
    print()

  elif row['team1'] == 'Delhi Capitals' and row['team2'] == 'Sunrisers Hyderabad' or row['team2'] == 'Delhi Capitals' and row['team1'] == 'Sunrisers Hyderabad':
    DC_params = {key: 0 for key in list(DC_df.columns)}
    SRH_params = {key: 0 for key in list(SRH_df.columns)}
    DC_params['Opponent_Team_Sunrisers Hyderabad'] = 1
    SRH_params['Opponent_Team_Kings XI Punjab'] = 1
    if row['toss_winner'] == 'Delhi Capitals':
      DC_params['toss_winner'] = 1
      if row['toss_choice'] == 'Field':
        DC_params['toss_choice_Field'] = 1
        SRH_params['toss_choice_Bat'] = 1
      else:
        DC_params['toss_choice_Bat'] = 1
        SRH_params['toss_choice_Field'] = 1
    else:
      SRH_params['toss_winner'] = 1
      if row['toss_choice'] == 'Field':
        SRH_params['toss_choice_Field'] = 1
        DC_params['toss_choice_Bat'] = 1
      else:
        SRH_params['toss_choice_Bat'] = 1
        DC_params['toss_choice_Field'] = 1
    if 'stadium_' + str(row['stadium']) in SRH_params:
      SRH_params['stadium_' + str(row['stadium'])] = 1
    if 'stadium_' + str(row['stadium']) in DC_params:
      DC_params['stadium_'+ str(row['stadium'])] = 1
    DC_params = np.array(list(DC_params.values()))
    DC_params = np.reshape(DC_params, (len(DC_params),1))
    DC_score = np.dot(weights['DC'], DC_params) + biases['DC']
    print('DC_score:', DC_score)
    SRH_params = np.array(list(SRH_params.values()))
    SRH_params = np.reshape(SRH_params, (len(SRH_params),1))
    SRH_score = np.dot(weights['SRH'],SRH_params) + biases['SRH']
    print('SRH_score :', SRH_score)
    if SRH_score > DC_score:
      print('winner : SRH')
      if row['winner'] == 'Sunrisers Hyderabad':
        count += 1
    else:
      print('winner : DC')
      if row['winner'] == 'Delhi Capitals':
        count += 1
    print()

  elif row['team1'] == 'Chennai Super Kings' and row['team2'] == 'Sunrisers Hyderabad' or row['team2'] == 'Chennai Super Kings' and row['team1'] == 'Sunrisers Hyderabad':
    CSK_params = {key: 0 for key in list(CSK_df.columns)}
    SRH_params = {key: 0 for key in list(SRH_df.columns)}
    CSK_params['Opponent_Team_Sunrisers Hyderabad'] = 1
    SRH_params['Opponent_Team_Kings XI Punjab'] = 1
    if row['toss_winner'] == 'Chennai Super Kings':
      CSK_params['toss_winner'] = 1
      if row['toss_choice'] == 'Field':
        CSK_params['toss_choice_Field'] = 1
        SRH_params['toss_choice_Bat'] = 1
      else:
        CSK_params['toss_choice_Bat'] = 1
        SRH_params['toss_choice_Field'] = 1
    else:
      SRH_params['toss_winner'] = 1
      if row['toss_choice'] == 'Field':
        SRH_params['toss_choice_Field'] = 1
        CSK_params['toss_choice_Bat'] = 1
      else:
        SRH_params['toss_choice_Bat'] = 1
        CSK_params['toss_choice_Field'] = 1
    if 'stadium_' + str(row['stadium']) in SRH_params:
      SRH_params['stadium_' + str(row['stadium'])] = 1
    if 'stadium_' + str(row['stadium']) in CSK_params:
      CSK_params['stadium_'+ str(row['stadium'])] = 1
    CSK_params = np.array(list(CSK_params.values()))
    CSK_params = np.reshape(CSK_params, (len(CSK_params),1))
    CSK_score = np.dot(weights['CSK'], CSK_params) + biases['CSK']
    print('CSK_score:', CSK_score)
    SRH_params = np.array(list(SRH_params.values()))
    SRH_params = np.reshape(SRH_params, (len(SRH_params),1))
    SRH_score = np.dot(weights['SRH'],SRH_params) + biases['SRH']
    print('SRH_score :', SRH_score)
    if SRH_score > CSK_score:
      print('winner : SRH')
      if row['winner'] == 'Sunrisers Hyderabad':
        count += 1
    else:
      print('winner : CSK')
      if row['winner'] == 'Chennai Super Kings':
        count += 1
    print()

  elif row['team1'] == 'Mumbai Indians' and row['team2'] == 'Sunrisers Hyderabad' or row['team2'] == 'Mumbai Indians' and row['team1'] == 'Sunrisers Hyderabad':
    MI_params = {key: 0 for key in list(MI_df.columns)}
    SRH_params = {key: 0 for key in list(SRH_df.columns)}
    MI_params['Opponent_Team_Sunrisers Hyderabad'] = 1
    SRH_params['Opponent_Team_Kings XI Punjab'] = 1
    if row['toss_winner'] == 'Mumbai Indians':
      MI_params['toss_winner'] = 1
      if row['toss_choice'] == 'Field':
        MI_params['toss_choice_Field'] = 1
        SRH_params['toss_choice_Bat'] = 1
      else:
        MI_params['toss_choice_Bat'] = 1
        SRH_params['toss_choice_Field'] = 1
    else:
      SRH_params['toss_winner'] = 1
      if row['toss_choice'] == 'Field':
        SRH_params['toss_choice_Field'] = 1
        MI_params['toss_choice_Bat'] = 1
      else:
        SRH_params['toss_choice_Bat'] = 1
        MI_params['toss_choice_Field'] = 1
    if 'stadium_' + str(row['stadium']) in SRH_params:
      SRH_params['stadium_' + str(row['stadium'])] = 1
    if 'stadium_' + str(row['stadium']) in MI_params:
      MI_params['stadium_'+ str(row['stadium'])] = 1
    MI_params = np.array(list(MI_params.values()))
    MI_params = np.reshape(MI_params, (len(MI_params),1))
    MI_score = np.dot(weights['MI'], MI_params) + biases['MI']
    print('MI_score:', MI_score)
    SRH_params = np.array(list(SRH_params.values()))
    SRH_params = np.reshape(SRH_params, (len(SRH_params),1))
    SRH_score = np.dot(weights['SRH'],SRH_params) + biases['SRH']
    print('SRH_score :', SRH_score)
    if SRH_score > MI_score:
      print('winner : SRH')
      if row['winner'] == 'Sunrisers Hyderabad':
        count += 1
    else:
      print('winner : MI')
      if row['winner'] == 'Mumbai Indians':
        count += 1
    print()

  elif row['team1'] == 'Royal Challengers Bangalore' and row['team2'] == 'Sunrisers Hyderabad' or row['team2'] == 'Royal Challengers Bangalore' and row['team1'] == 'Sunrisers Hyderabad':
    RCB_params = {key: 0 for key in list(RCB_df.columns)}
    SRH_params = {key: 0 for key in list(SRH_df.columns)}
    RCB_params['Opponent_Team_Sunrisers Hyderabad'] = 1
    SRH_params['Opponent_Team_Kings XI Punjab'] = 1
    if row['toss_winner'] == 'Royal Challengers Bangalore':
      RCB_params['toss_winner'] = 1
      if row['toss_choice'] == 'Field':
        RCB_params['toss_choice_Field'] = 1
        SRH_params['toss_choice_Bat'] = 1
      else:
        RCB_params['toss_choice_Bat'] = 1
        SRH_params['toss_choice_Field'] = 1
    else:
      SRH_params['toss_winner'] = 1
      if row['toss_choice'] == 'Field':
        SRH_params['toss_choice_Field'] = 1
        RCB_params['toss_choice_Bat'] = 1
      else:
        SRH_params['toss_choice_Bat'] = 1
        RCB_params['toss_choice_Field'] = 1
    if 'stadium_' + str(row['stadium']) in SRH_params:
      SRH_params['stadium_' + str(row['stadium'])] = 1
    if 'stadium_' + str(row['stadium']) in RCB_params:
      RCB_params['stadium_'+ str(row['stadium'])] = 1
    RCB_params = np.array(list(RCB_params.values()))
    RCB_params = np.reshape(RCB_params, (len(RCB_params),1))
    RCB_score = np.dot(weights['RCB'], RCB_params) + biases['RCB']
    print('RCB_score:', RCB_score)
    SRH_params = np.array(list(SRH_params.values()))
    SRH_params = np.reshape(SRH_params, (len(SRH_params),1))
    SRH_score = np.dot(weights['SRH'],SRH_params) + biases['SRH']
    print('SRH_score :', SRH_score)
    if SRH_score > RCB_score:
      print('winner : SRH')
      if row['winner'] == 'Sunrisers Hyderabad':
        count += 1
    else:
      print('winner : RCB')
      if row['winner'] == 'Royal Challengers Bangalore':
        count += 1
    print()

  elif row['team1'] == 'Kolkata Knight Riders' and row['team2'] == 'Sunrisers Hyderabad' or row['team2'] == 'Kolkata Knight Riders' and row['team1'] == 'Sunrisers Hyderabad':
    KKR_params = {key: 0 for key in list(KKR_df.columns)}
    SRH_params = {key: 0 for key in list(SRH_df.columns)}
    KKR_params['Opponent_Team_Sunrisers Hyderabad'] = 1
    SRH_params['Opponent_Team_Kings XI Punjab'] = 1
    if row['toss_winner'] == 'Kolkata Knight Riders':
      KKR_params['toss_winner'] = 1
      if row['toss_choice'] == 'Field':
        KKR_params['toss_choice_Field'] = 1
        SRH_params['toss_choice_Bat'] = 1
      else:
        KKR_params['toss_choice_Bat'] = 1
        SRH_params['toss_choice_Field'] = 1
    else:
      SRH_params['toss_winner'] = 1
      if row['toss_choice'] == 'Field':
        SRH_params['toss_choice_Field'] = 1
        KKR_params['toss_choice_Bat'] = 1
      else:
        SRH_params['toss_choice_Bat'] = 1
        KKR_params['toss_choice_Field'] = 1
    if 'stadium_' + str(row['stadium']) in SRH_params:
      SRH_params['stadium_' + str(row['stadium'])] = 1
    if 'stadium_' + str(row['stadium']) in KKR_params:
      KKR_params['stadium_'+ str(row['stadium'])] = 1
    KKR_params = np.array(list(KKR_params.values()))
    KKR_params = np.reshape(KKR_params, (len(KKR_params),1))
    KKR_score = np.dot(weights['KKR'], KKR_params) + biases['KKR']
    print('KKR_score:', KKR_score)
    SRH_params = np.array(list(SRH_params.values()))
    SRH_params = np.reshape(SRH_params, (len(SRH_params),1))
    SRH_score = np.dot(weights['SRH'],SRH_params) + biases['SRH']
    print('SRH_score :', SRH_score)
    if SRH_score > KKR_score:
      print('winner : SRH')
      if row['winner'] == 'Sunrisers Hyderabad':
        count += 1
    else:
      print('winner : KKR')
      if row['winner'] == 'Kolkata Knight Riders':
        count += 1
    print()

  elif row['team1'] == 'Chennai Super Kings' and row['team2'] == 'Kolkata Knight Riders' or row['team2'] == 'Chennai Super Kings' and row['team1'] == 'Kolkata Knight Riders':
    CSK_params = {key: 0 for key in list(CSK_df.columns)}
    KKR_params = {key: 0 for key in list(KKR_df.columns)}
    CSK_params['Opponent_Team_Kolkata Knight Riders'] = 1
    KKR_params['Opponent_Team_Kings XI Punjab'] = 1
    if row['toss_winner'] == 'Chennai Super Kings':
      CSK_params['toss_winner'] = 1
      if row['toss_choice'] == 'Field':
        CSK_params['toss_choice_Field'] = 1
        KKR_params['toss_choice_Bat'] = 1
      else:
        CSK_params['toss_choice_Bat'] = 1
        KKR_params['toss_choice_Field'] = 1
    else:
      KKR_params['toss_winner'] = 1
      if row['toss_choice'] == 'Field':
        KKR_params['toss_choice_Field'] = 1
        CSK_params['toss_choice_Bat'] = 1
      else:
        KKR_params['toss_choice_Bat'] = 1
        CSK_params['toss_choice_Field'] = 1
    if 'stadium_' + str(row['stadium']) in KKR_params:
      KKR_params['stadium_' + str(row['stadium'])] = 1
    if 'stadium_' + str(row['stadium']) in CSK_params:
      CSK_params['stadium_'+ str(row['stadium'])] = 1
    CSK_params = np.array(list(CSK_params.values()))
    CSK_params = np.reshape(CSK_params, (len(CSK_params),1))
    CSK_score = np.dot(weights['CSK'], CSK_params) + biases['CSK']
    print('CSK_score:', CSK_score)
    KKR_params = np.array(list(KKR_params.values()))
    KKR_params = np.reshape(KKR_params, (len(KKR_params),1))
    KKR_score = np.dot(weights['KKR'],KKR_params) + biases['KKR']
    print('KKR_score :', KKR_score)
    if KKR_score > CSK_score:
      print('winner : KKR')
      if row['winner'] == 'Kolkata Knight Riders':
        count += 1
    else:
      print('winner : CSK')
      if row['winner'] == 'Chennai Super Kings':
        count += 1
    print()

  elif row['team1'] == 'Mumbai Indians' and row['team2'] == 'Kolkata Knight Riders' or row['team2'] == 'Mumbai Indians' and row['team1'] == 'Kolkata Knight Riders':
    MI_params = {key: 0 for key in list(MI_df.columns)}
    KKR_params = {key: 0 for key in list(KKR_df.columns)}
    MI_params['Opponent_Team_Kolkata Knight Riders'] = 1
    KKR_params['Opponent_Team_Kings XI Punjab'] = 1
    if row['toss_winner'] == 'Mumbai Indians':
      MI_params['toss_winner'] = 1
      if row['toss_choice'] == 'Field':
        MI_params['toss_choice_Field'] = 1
        KKR_params['toss_choice_Bat'] = 1
      else:
        MI_params['toss_choice_Bat'] = 1
        KKR_params['toss_choice_Field'] = 1
    else:
      KKR_params['toss_winner'] = 1
      if row['toss_choice'] == 'Field':
        KKR_params['toss_choice_Field'] = 1
        MI_params['toss_choice_Bat'] = 1
      else:
        KKR_params['toss_choice_Bat'] = 1
        MI_params['toss_choice_Field'] = 1
    if 'stadium_' + str(row['stadium']) in KKR_params:
      KKR_params['stadium_' + str(row['stadium'])] = 1
    if 'stadium_' + str(row['stadium']) in MI_params:
      MI_params['stadium_'+ str(row['stadium'])] = 1
    MI_params = np.array(list(MI_params.values()))
    MI_params = np.reshape(MI_params, (len(MI_params),1))
    MI_score = np.dot(weights['MI'], MI_params) + biases['MI']
    print('MI_score:', MI_score)
    KKR_params = np.array(list(KKR_params.values()))
    KKR_params = np.reshape(KKR_params, (len(KKR_params),1))
    KKR_score = np.dot(weights['KKR'],KKR_params) + biases['KKR']
    print('KKR_score :', KKR_score)
    if KKR_score > MI_score:
      print('winner : KKR')
      if row['winner'] == 'Kolkata Knight Riders':
        count += 1
    else:
      print('winner : MI')
      if row['winner'] == 'Mumbai Indians':
        count += 1
    print()

  elif row['team1'] == 'Royal Challengers Bangalore' and row['team2'] == 'Kolkata Knight Riders' or row['team2'] == 'Royal Challengers Bangalore' and row['team1'] == 'Kolkata Knight Riders':
    RCB_params = {key: 0 for key in list(RCB_df.columns)}
    KKR_params = {key: 0 for key in list(KKR_df.columns)}
    RCB_params['Opponent_Team_Kolkata Knight Riders'] = 1
    KKR_params['Opponent_Team_Kings XI Punjab'] = 1
    if row['toss_winner'] == 'Royal Challengers Bangalore':
      RCB_params['toss_winner'] = 1
      if row['toss_choice'] == 'Field':
        RCB_params['toss_choice_Field'] = 1
        KKR_params['toss_choice_Bat'] = 1
      else:
        RCB_params['toss_choice_Bat'] = 1
        KKR_params['toss_choice_Field'] = 1
    else:
      KKR_params['toss_winner'] = 1
      if row['toss_choice'] == 'Field':
        KKR_params['toss_choice_Field'] = 1
        RCB_params['toss_choice_Bat'] = 1
      else:
        KKR_params['toss_choice_Bat'] = 1
        RCB_params['toss_choice_Field'] = 1
    if 'stadium_' + str(row['stadium']) in KKR_params:
      KKR_params['stadium_' + str(row['stadium'])] = 1
    if 'stadium_' + str(row['stadium']) in RCB_params:
      RCB_params['stadium_'+ str(row['stadium'])] = 1
    RCB_params = np.array(list(RCB_params.values()))
    RCB_params = np.reshape(RCB_params, (len(RCB_params),1))
    RCB_score = np.dot(weights['RCB'], RCB_params) + biases['RCB']
    print('RCB_score:', RCB_score)
    KKR_params = np.array(list(KKR_params.values()))
    KKR_params = np.reshape(KKR_params, (len(KKR_params),1))
    KKR_score = np.dot(weights['KKR'],KKR_params) + biases['KKR']
    print('KKR_score :', KKR_score)
    if KKR_score > RCB_score:
      print('winner : KKR')
      if row['winner'] == 'Kolkata Knight Riders':
        count += 1
    else:
      print('winner : RCB')
      if row['winner'] == 'Royal Challengers Bangalore':
        count += 1
    print()

  elif row['team1'] == 'Royal Challengers Bangalore' and row['team2'] == 'Chennai Super Kings' or row['team2'] == 'Royal Challengers Bangalore' and row['team1'] == 'Chennai Super Kings':
    RCB_params = {key: 0 for key in list(RCB_df.columns)}
    CSK_params = {key: 0 for key in list(CSK_df.columns)}
    RCB_params['Opponent_Team_Chennai Super Kings'] = 1
    CSK_params['Opponent_Team_Kings XI Punjab'] = 1
    if row['toss_winner'] == 'Royal Challengers Bangalore':
      RCB_params['toss_winner'] = 1
      if row['toss_choice'] == 'Field':
        RCB_params['toss_choice_Field'] = 1
        CSK_params['toss_choice_Bat'] = 1
      else:
        RCB_params['toss_choice_Bat'] = 1
        CSK_params['toss_choice_Field'] = 1
    else:
      CSK_params['toss_winner'] = 1
      if row['toss_choice'] == 'Field':
        CSK_params['toss_choice_Field'] = 1
        RCB_params['toss_choice_Bat'] = 1
      else:
        CSK_params['toss_choice_Bat'] = 1
        RCB_params['toss_choice_Field'] = 1
    if 'stadium_' + str(row['stadium']) in CSK_params:
      CSK_params['stadium_' + str(row['stadium'])] = 1
    if 'stadium_' + str(row['stadium']) in RCB_params:
      RCB_params['stadium_'+ str(row['stadium'])] = 1
    RCB_params = np.array(list(RCB_params.values()))
    RCB_params = np.reshape(RCB_params, (len(RCB_params),1))
    RCB_score = np.dot(weights['RCB'], RCB_params) + biases['RCB']
    print('RCB_score:', RCB_score)
    CSK_params = np.array(list(CSK_params.values()))
    CSK_params = np.reshape(CSK_params, (len(CSK_params),1))
    CSK_score = np.dot(weights['CSK'],CSK_params) + biases['CSK']
    print('CSK_score :', CSK_score)
    if CSK_score > RCB_score:
      print('winner : CSK')
      if row['winner'] == 'Chennai Super Kings':
        count += 1
    else:
      print('winner : RCB')
      if row['winner'] == 'Royal Challengers Bangalore':
        count += 1
    print()

  elif row['team1'] == 'Royal Challengers Bangalore' and row['team2'] == 'Mumbai Indians' or row['team2'] == 'Royal Challengers Bangalore' and row['team1'] == 'Mumbai Indians':
    RCB_params = {key: 0 for key in list(RCB_df.columns)}
    MI_params = {key: 0 for key in list(MI_df.columns)}
    RCB_params['Opponent_Team_Mumbai Indians'] = 1
    MI_params['Opponent_Team_Kings XI Punjab'] = 1
    if row['toss_winner'] == 'Royal Challengers Bangalore':
      RCB_params['toss_winner'] = 1
      if row['toss_choice'] == 'Field':
        RCB_params['toss_choice_Field'] = 1
        MI_params['toss_choice_Bat'] = 1
      else:
        RCB_params['toss_choice_Bat'] = 1
        MI_params['toss_choice_Field'] = 1
    else:
      MI_params['toss_winner'] = 1
      if row['toss_choice'] == 'Field':
        MI_params['toss_choice_Field'] = 1
        RCB_params['toss_choice_Bat'] = 1
      else:
        MI_params['toss_choice_Bat'] = 1
        RCB_params['toss_choice_Field'] = 1
    if 'stadium_' + str(row['stadium']) in MI_params:
      MI_params['stadium_' + str(row['stadium'])] = 1
    if 'stadium_' + str(row['stadium']) in RCB_params:
      RCB_params['stadium_'+ str(row['stadium'])] = 1
    RCB_params = np.array(list(RCB_params.values()))
    RCB_params = np.reshape(RCB_params, (len(RCB_params),1))
    RCB_score = np.dot(weights['RCB'], RCB_params) + biases['RCB']
    print('RCB_score:', RCB_score)
    MI_params = np.array(list(MI_params.values()))
    MI_params = np.reshape(MI_params, (len(MI_params),1))
    MI_score = np.dot(weights['MI'],MI_params) + biases['MI']
    print('MI_score :', MI_score)
    if MI_score > RCB_score:
      print('winner : MI')
      if row['winner'] == 'Mumbai Indians':
        count += 1
    else:
      print('winner : RCB')
      if row['winner'] == 'Royal Challengers Bangalore':
        count += 1
    print()

  elif row['team1'] == 'Chennai Super Kings' and row['team2'] == 'Mumbai Indians' or row['team2'] == 'Chennai Super Kings' and row['team1'] == 'Mumbai Indians':
    CSK_params = {key: 0 for key in list(CSK_df.columns)}
    MI_params = {key: 0 for key in list(MI_df.columns)}
    CSK_params['Opponent_Team_Mumbai Indians'] = 1
    MI_params['Opponent_Team_Kings XI Punjab'] = 1
    if row['toss_winner'] == 'Chennai Super Kings':
      CSK_params['toss_winner'] = 1
      if row['toss_choice'] == 'Field':
        CSK_params['toss_choice_Field'] = 1
        MI_params['toss_choice_Bat'] = 1
      else:
        CSK_params['toss_choice_Bat'] = 1
        MI_params['toss_choice_Field'] = 1
    else:
      MI_params['toss_winner'] = 1
      if row['toss_choice'] == 'Field':
        MI_params['toss_choice_Field'] = 1
        CSK_params['toss_choice_Bat'] = 1
      else:
        MI_params['toss_choice_Bat'] = 1
        CSK_params['toss_choice_Field'] = 1
    if 'stadium_' + str(row['stadium']) in MI_params:
      MI_params['stadium_' + str(row['stadium'])] = 1
    if 'stadium_' + str(row['stadium']) in CSK_params:
      CSK_params['stadium_'+ str(row['stadium'])] = 1
    CSK_params = np.array(list(CSK_params.values()))
    CSK_params = np.reshape(CSK_params, (len(CSK_params),1))
    CSK_score = np.dot(weights['CSK'], CSK_params) + biases['CSK']
    print('CSK_score:', CSK_score)
    MI_params = np.array(list(MI_params.values()))
    MI_params = np.reshape(MI_params, (len(MI_params),1))
    MI_score = np.dot(weights['MI'],MI_params) + biases['MI']
    print('MI_score :', MI_score)
    if MI_score > CSK_score:
      print('winner : MI')
      if row['winner'] == 'Mumbai Indians':
        count += 1
    else:
      print('winner : CSK')
      if row['winner'] == 'Chennai Super Kings':
        count += 1
print('accuracy =', count/5.89, '%')
